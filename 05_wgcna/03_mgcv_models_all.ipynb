# %% [markdown]
# # Testing for modules impacted by diet

# %%
#load packages
pkgs <- c("mgcv", "lme4", "ggplot2", "vroom", "dplyr", "forcats", "tidyr", "Seurat", "SingleCellExperiment", "gratia", "MASS", "fitdistrplus", "furrr", "tidyverse")
vapply(pkgs, library, logical(1), character.only = TRUE, logical.return = TRUE,
       quietly = TRUE)
# Out:
# This is mgcv 1.8-42. For overview type 'help("mgcv-package")'.
#
#
# Attaching package: ‘lme4’
#
#
# The following object is masked from ‘package:nlme’:
#
#     lmList
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following object is masked from ‘package:nlme’:
#
#     collapse
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘tidyr’
#
#
# The following objects are masked from ‘package:Matrix’:
#
#     expand, pack, unpack
#
#
# The legacy packages maptools, rgdal, and rgeos, underpinning the sp package,
# which was just loaded, will retire in October 2023.
# Please refer to R-spatial evolution reports for details, especially
# https://r-spatial.org/r/2023/05/15/evolution4.html.
# It may be desirable to make the sf package available;
# package maintainers should consider adding sf to Suggests:.
# The sp package is now running under evolution status 2
#      (status 2 uses the sf package in place of rgdal)
#
# Attaching SeuratObject
#
#
# Attaching package: ‘matrixStats’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     count
#
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     expand
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     first, rename
#
#
# The following objects are masked from ‘package:Matrix’:
#
#     expand, unname
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
#
# Attaching package: ‘IRanges’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, slice
#
#
# The following object is masked from ‘package:nlme’:
#
#     collapse
#
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘Biobase’
#
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
#
#
# Attaching package: ‘SummarizedExperiment’
#
#
# The following object is masked from ‘package:SeuratObject’:
#
#     Assays
#
#
# The following object is masked from ‘package:Seurat’:
#
#     Assays
#
#
#
# Attaching package: ‘MASS’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     select
#
#
#
# Attaching package: ‘future’
#
#
# The following object is masked from ‘package:survival’:
#
#     cluster
#
#
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ lubridate 1.9.2     ✔ stringr   1.5.0
# ✔ purrr     1.0.1     ✔ tibble    3.2.1
# ✔ readr     2.1.4
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ lubridate::%within%()    masks IRanges::%within%()
# ✖ readr::col_character()   masks vroom::col_character()
# ✖ readr::col_date()        masks vroom::col_date()
# ✖ readr::col_datetime()    masks vroom::col_datetime()
# ✖ readr::col_double()      masks vroom::col_double()
# ✖ readr::col_factor()      masks vroom::col_factor()
# ✖ readr::col_guess()       masks vroom::col_guess()
# ✖ readr::col_integer()     masks vroom::col_integer()
# ✖ readr::col_logical()     masks vroom::col_logical()
# ✖ readr::col_number()      masks vroom::col_number()
# ✖ readr::col_skip()        masks vroom::col_skip()
# ✖ readr::col_time()        masks vroom::col_time()
# ✖ IRanges::collapse()      masks dplyr::collapse(), nlme::collapse()
# ✖ readr::cols()            masks vroom::cols()
# ✖ Biobase::combine()       masks BiocGenerics::combine(), dplyr::combine()
# ✖ matrixStats::count()     masks dplyr::count()
# ✖ readr::date_names_lang() masks vroom::date_names_lang()
# ✖ readr::default_locale()  masks vroom::default_locale()
# ✖ IRanges::desc()          masks dplyr::desc()
# ✖ S4Vectors::expand()      masks tidyr::expand(), Matrix::expand()
# ✖ dplyr::filter()          masks stats::filter()
# ✖ S4Vectors::first()       masks dplyr::first()
# ✖ readr::fwf_cols()        masks vroom::fwf_cols()
# ✖ readr::fwf_empty()       masks vroom::fwf_empty()
# ✖ readr::fwf_positions()   masks vroom::fwf_positions()
# ✖ readr::fwf_widths()      masks vroom::fwf_widths()
# ✖ dplyr::lag()             masks stats::lag()
# ✖ readr::locale()          masks vroom::locale()
# ✖ readr::output_column()   masks vroom::output_column()
# ✖ tidyr::pack()            masks Matrix::pack()
# ✖ BiocGenerics::Position() masks ggplot2::Position(), base::Position()
# ✖ readr::problems()        masks vroom::problems()
# ✖ purrr::reduce()          masks GenomicRanges::reduce(), IRanges::reduce()
# ✖ S4Vectors::rename()      masks dplyr::rename()
# ✖ lubridate::second()      masks S4Vectors::second()
# ✖ lubridate::second<-()    masks S4Vectors::second<-()
# ✖ MASS::select()           masks dplyr::select()
# ✖ IRanges::slice()         masks dplyr::slice()
# ✖ tidyr::unpack()          masks Matrix::unpack()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#                 mgcv                 lme4              ggplot2
#                 TRUE                 TRUE                 TRUE
#                vroom                dplyr              forcats
#                 TRUE                 TRUE                 TRUE
#                tidyr               Seurat SingleCellExperiment
#                 TRUE                 TRUE                 TRUE
#               gratia                 MASS         fitdistrplus
#                 TRUE                 TRUE                 TRUE
#                furrr            tidyverse
#                 TRUE                 TRUE

# %%
# settings for the run
me_dir <- 'wgcna_output/renamed_tables/' #where to find the WGCNA MEs
run_name <- 'ds4_mcs20_pF_kME_cellModEmbed' #the run prefix
group_col <- "diet" # group that will be modelled
cluster_col <- "region" # sample region
mgcv_dir <- paste0(me_dir, 'mgcv/') # where to save the mgcv results
dir.create(mgcv_dir, recursive = TRUE) # creates the mgcv results folder if it doesn't exist
summaries_path <- paste0(mgcv_dir, run_name, '_summaries_f.rds') #save summaries here
models_path <- paste0(mgcv_dir, run_name, '_models.rds') #save models here
memfs_path <- paste0(mgcv_dir, run_name, '_memfs.rds') #save intermediate memfs objects here (only for debugging)
significant_modules <- paste0(mgcv_dir, run_name, '_significant_modules.csv')#where to save the table summarizing significant modules
# Out:
# Warning message in dir.create(mgcv_dir, recursive = TRUE):
# “'wgcna_output/renamed_tables/mgcv' already exists”

# %%
me = read_csv(paste0(me_dir, 'kME_cellModEmbed.csv')) #read the MEs and inspect them
me %>% head
# Out:
# Rows: 144 Columns: 386
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr   (3): data, region, sample
# dbl (383): HPF__01, HPF__02, HPF__03, HPF__04, HPF__05, HPF__06, HPF__07, HP...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   data region sample           HPF__01    HPF__02    HPF__03   HPF__04
# 1 dmb  HY     S0010_01_chow_HY 0.05197933 0.03023810 0.1824172 0.1229980
# 2 dmb  HY     S0010_02_chow_HY 0.08876762 0.08017922 0.1459963 0.1170462
# 3 dmb  HY     S0010_03_chow_HY 0.07109426 0.02853630 0.1832191 0.1384336
# 4 dmb  HY     S0010_04_chow_HY 0.02948085 0.06371331 0.1535754 0.1107229
# 5 dmb  HY     S0010_05_chow_HY 0.11411558 0.03807216 0.1615871 0.1345847
# 6 dmb  HY     S0010_06_chow_HY 0.02021261 0.07189122 0.1562818 0.1019575
#   HPF__05     HPF__06      HPF__07     ⋯ ZI__39      ZI__40     ZI__41
# 1 -0.05775205  0.019439584 -0.06125762 ⋯ -0.08595527 0.05252190 -0.05822008
# 2 -0.03252780 -0.004745673 -0.05191100 ⋯ -0.11281907 0.02927096 -0.02412367
# 3 -0.06336754 -0.032457115 -0.06025051 ⋯ -0.10252465 0.06811403 -0.04506138
# 4 -0.03764149  0.025134355 -0.05945944 ⋯ -0.05751049 0.03972461 -0.01765908
# 5 -0.06702112  0.007702094 -0.05492529 ⋯ -0.15425467 0.03670603 -0.01827709
# 6 -0.03508683 -0.025868732 -0.07505565 ⋯ -0.09517898 0.05157318 -0.02545144
#   ZI__42     ZI__43       ZI__44        ZI__45     ZI__46     ZI__47
# 1 0.06567769  0.036785185  0.0102144634 0.10537119 0.11220870 -0.04791984
# 2 0.02603893  0.007287426 -0.0017344272 0.10817653 0.11961064 -0.04316019
# 3 0.01064958  0.021634418 -0.0002412614 0.07374108 0.10598614 -0.02872247
# 4 0.05303416 -0.004217487  0.0049177488 0.06565093 0.01816232 -0.03737867
# 5 0.01769293 -0.020943932 -0.0073797921 0.09252465 0.09507013 -0.02601267
# 6 0.02872648 -0.025390663  0.0255168968 0.07634631 0.05995981 -0.04782112
#   ZI__48
# 1 0.020875004
# 2 0.006892997
# 3 0.025098740
# 4 0.014236332
# 5 0.019362943
# 6 0.008990742

# %%
meta = read_csv('vsd_meta.csv') # read the metadata and reformat some columns
meta = meta %>%
mutate(diet = factor(diet, levels=c('chow', 'HFD', 'fast'))) %>%
mutate(animal_id = as.character(animal_id)) %>%
mutate(region = factor(region, levels=c("HY", 'HPF', 'SC', 'IC', 'PFC', 'ZI'))) %>%
filter(seq_run %in% c('0010', '0037')) %>%
mutate(seq_run = factor(seq_run, levels=c('0010', '0037')))

meta %>% head
# Out:
# Rows: 144 Columns: 26
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr   (9): name, filename, seq_run, seq_sample, diet, region, hemisphere, no...
# dbl  (15): rna_conc_qbit, box_id, animal_id, diet_kcal, experiment_duration,...
# dttm  (2): experiment_start, time_of_euthanasia
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   name             filename            seq_run seq_sample rna_conc_qbit box_id
# 1 S0010_01_chow_HY 1_Chow_Hyp_both_S80 0010    S80        73.60         34
# 2 S0010_02_chow_HY 2_Chow_Hyp_both_S44 0010    S44        27.20         34
# 3 S0010_03_chow_HY 3_Chow_Hyp_both_S78 0010    S78         6.36         35
# 4 S0010_04_chow_HY 4_Chow_Hyp_both_S25 0010    S25        20.80         35
# 5 S0010_05_chow_HY 5_Chow_Hyp_both_S84 0010    S84        20.40         36
# 6 S0010_06_chow_HY 6_Chow_Hyp_both_S66 0010    S66        10.60         36
#   animal_id diet diet_kcal region ⋯ bw_f bw_change bw_change_pct
# 1 1         chow 3227      HY     ⋯ 24.6  1.2       0.051282051
# 2 2         chow 3227      HY     ⋯ 26.0  0.1       0.003861004
# 3 3         chow 3227      HY     ⋯ 26.4  0.2       0.007633588
# 4 4         chow 3227      HY     ⋯ 24.0  0.5       0.021276596
# 5 5         chow 3227      HY     ⋯ 24.4 -0.3      -0.012145749
# 6 6         chow 3227      HY     ⋯ 27.0  1.1       0.042471042
#   bw_change_pct_ph fw_i  fw_f  kcal_intake power_intake notes qc
# 1  0.0032051282    741.7 734.4 11778.55    736.1594     NA    ok
# 2  0.0002388250    741.7 734.4 11778.55    728.5701     NA    ok
# 3  0.0004770992    743.5 735.3 13230.70    826.9188     NA    ok
# 4  0.0013160781    743.5 735.3 13230.70    818.3938     NA    ok
# 5 -0.0007591093    713.6 706.4 11617.20    726.0750     NA    ok
# 6  0.0026379529    713.6 706.4 11617.20    721.5652     NA    ok

# %%
# filters the meta down
# meta is the meta dataframe
# group_col is the perturbation column e.g. - Diet
# groups is a vector with conditions for comparison e.g. - c("chow", "HFD")
# cluster_col is the column encoding clusters in the meta. e.g. - region
# clusters is a vector with clusters to filter to. e.g. - HY
filter_meta <- function (meta, group_col, groups, cluster_col, clusters){
    meta_f <- meta %>% 
        filter(
            get(group_col) %in% groups,
            get(cluster_col) %in% clusters
        )
    return (meta_f)
}

# %%
make_sp <- function (me_df) {
    sp <- stringr::str_split_fixed(colnames(me)[4:length(colnames(me))], pattern='__', n=2)
    sp <- as.data.frame(sp)
    sp <- apply(sp, 1, function(x) as.vector(c(x[1], x[2], paste0(x[1], '__', x[2]))))
    sp <- t(sp)
    sp <- as.data.frame(sp)
    colnames(sp)[colnames(sp) == 'V1'] <- 'cluster'
    colnames(sp)[colnames(sp) == 'V2'] <- 'module'
    colnames(sp)[colnames(sp) == 'V3'] <- 'ME_col'
    return (sp)
}

# %%
# a simple model
# models the diet (group_col)
# fit_mgcv <- function(memf){
#     model <- bam(ME ~ get(group_col),
#                  data = memf, method = "fREML", discrete = T
#                 )
#     return (model)
# }


# a more complex model
# accounts for sequencing run as a random effect
fit_mgcv <- function(memf){
    model <- bam(ME ~ get(group_col) +
                 s(seq_run, bs = "re"), # could also model cages if known
                 data = memf, method = "fREML", discrete = T
                )
    return (model)
}

safe_fit_mgcv <- purrr::safely(fit_mgcv) #necessary for parallelization, in case we hit errors

# %%
# this is what make_sp produces
sp <- make_sp(me)
head(sp)
# Out:
#   cluster module ME_col
# 1 HPF     01     HPF__01
# 2 HPF     02     HPF__02
# 3 HPF     03     HPF__03
# 4 HPF     04     HPF__04
# 5 HPF     05     HPF__05
# 6 HPF     06     HPF__06

# %%
#this is what filter_meta produces
filter_meta(meta, "diet", c('chow', 'HFD'), "region", c("HY"))
# Out:
#    name               filename                    seq_run seq_sample
# 1  S0010_01_chow_HY   1_Chow_Hyp_both_S80         0010    S80
# 2  S0010_02_chow_HY   2_Chow_Hyp_both_S44         0010    S44
# 3  S0010_03_chow_HY   3_Chow_Hyp_both_S78         0010    S78
# 4  S0010_04_chow_HY   4_Chow_Hyp_both_S25         0010    S25
# 5  S0010_05_chow_HY   5_Chow_Hyp_both_S84         0010    S84
# 6  S0010_06_chow_HY   6_Chow_Hyp_both_S66         0010    S66
# 7  S0010_14_HFD_HY    14_Highfatdiet_Hyp_both_S28 0010    S28
# 8  S0010_15_HFD_HY    15_Highfatdiet_Hyp_both_S18 0010    S18
# 9  S0010_16_HFD_HY    16_Highfatdiet_Hyp_both_S85 0010    S85
# 10 S0010_17_HFD_HY    17_Highfatdiet_Hyp_both_S26 0010    S26
# 11 S0010_18_HFD_HY    18_Highfatdiet_Hyp_both_S13 0010    S13
# 12 S0037_1431_chow_HY 143_1_Hyp_chow_S7           0037    S7
# 13 S0037_1432_chow_HY 143_2_Hyp_chow_S25          0037    S25
# 14 S0037_1442_chow_HY 144_2_Hyp_chow_S2           0037    S2
# 15 S0037_1452_chow_HY 145_2_Hyp_chow_S41          0037    S41
# 16 S0037_1423_chow_HY 142_3_Hyp_chow_S38          0037    S38
# 17 S0037_1443_chow_HY 144_3_Hyp_chow_S40          0037    S40
#    rna_conc_qbit box_id animal_id diet diet_kcal region ⋯ bw_f bw_change
# 1   73.60          34   1         chow 3227      HY     ⋯ 24.6  1.2
# 2   27.20          34   2         chow 3227      HY     ⋯ 26.0  0.1
# 3    6.36          35   3         chow 3227      HY     ⋯ 26.4  0.2
# 4   20.80          35   4         chow 3227      HY     ⋯ 24.0  0.5
# 5   20.40          36   5         chow 3227      HY     ⋯ 24.4 -0.3
# 6   10.60          36   6         chow 3227      HY     ⋯ 27.0  1.1
# 7   24.40          40   14        HFD  5560      HY     ⋯ 26.5  0.4
# 8   12.30          41   15        HFD  5560      HY     ⋯ 26.3 -0.2
# 9   29.40          41   16        HFD  5560      HY     ⋯ 24.3  0.1
# 10  24.60          42   17        HFD  5560      HY     ⋯ 26.3  0.0
# 11  21.40          42   18        HFD  5560      HY     ⋯ 25.3 -0.2
# 12 330.00        1431   1431      chow 3227      HY     ⋯ 23.0  0.3
# 13 312.00        1432   1432      chow 3227      HY     ⋯ 25.5  0.4
# 14 233.40        1442   1442      chow 3227      HY     ⋯ 28.4 -0.1
# 15  92.40        1452   1452      chow 3227      HY     ⋯ 26.7  0.1
# 16 366.00        1423   1423      chow 3227      HY     ⋯ 25.8 -0.1
# 17 171.00        1443   1443      chow 3227      HY     ⋯ 24.8  0.0
#    bw_change_pct bw_change_pct_ph fw_i  fw_f  kcal_intake power_intake
# 1   0.051282051   0.0032051282    741.7 734.4 11778.55    736.1594
# 2   0.003861004   0.0002388250    741.7 734.4 11778.55    728.5701
# 3   0.007633588   0.0004770992    743.5 735.3 13230.70    826.9188
# 4   0.021276596   0.0013160781    743.5 735.3 13230.70    818.3938
# 5  -0.012145749  -0.0007591093    713.6 706.4 11617.20    726.0750
# 6   0.042471042   0.0026379529    713.6 706.4 11617.20    721.5652
# 7   0.015325670   0.0009450568    495.1 489.4 15846.00    977.1429
# 8  -0.007547170  -0.0004716981    495.0 490.1 13622.00    851.3750
# 9   0.004132231   0.0002556019    495.0 490.1 13622.00    842.5979
# 10  0.000000000   0.0000000000    482.9 477.3 15568.00    973.0000
# 11 -0.007843137  -0.0004841443    482.9 477.3 15568.00    960.9877
# 12  0.013215859   0.0005506608    663.5 660.1 10971.80    457.1583
# 13  0.015936255   0.0006640106    634.2 630.0 13553.40    564.7250
# 14 -0.003508772  -0.0001461988    656.7 652.4 13876.10    578.1708
# 15  0.003759398   0.0001566416    683.0 679.5 11294.50    470.6042
# 16 -0.003861004  -0.0001608752    593.1 589.1 12908.00    537.8333
# 17  0.000000000   0.0000000000    642.8 638.7 13230.70    551.2792
#    notes                                      qc
# 1  NA                                         ok
# 2  NA                                         ok
# 3  NA                                         ok
# 4  NA                                         ok
# 5  NA                                         ok
# 6  NA                                         ok
# 7  NA                                         ok
# 8  OBS. Lost weight.                          ok
# 9  NA                                         ok
# 10 NA                                         ok
# 11 OBS. Lost weight.                          ok
# 12 NA                                         ok
# 13 NA                                         ok
# 14 NA                                         ok
# 15 NA                                         ok
# 16 Sup. Colliculus for 142.3 is in tube 145.4 ok
# 17 NA                                         ok

# %%
# creating splits of the data for parallelization

splits <- list(c('chow', 'fast'),
               c('chow', 'HFD'))

memfs <- c()

for (s in splits){
    for (i in 1:nrow(sp)){
        cluster <- sp[i,]$cluster
        module <- sp[i,]$module
        me_col <- sp[i,]$ME_col
        me_keep_cols <- c('sample', me_col)
        me_f <- me[me_keep_cols]
        colnames(me_f)[2] <- 'ME'
        mf <- filter_meta(meta, group_col, s, cluster_col, c(cluster))
        mf$sample <- mf$name #need to give this same column as data
        mf_cols <- c('sample', 'diet', 'region', 'seq_run') 
        mf_f <- mf[mf_cols]
        mf_f <- mf_f %>%
            mutate(
                diet = droplevels(diet),
                region = droplevels(region),
                seq_run = droplevels(seq_run)
            )
        memf <- plyr::join(me_f, mf_f, by = c('sample'), type='right')
        memf_name <- paste0(s[1], '_', s[2], '-', me_col)
        memfs[[memf_name]] <- memf
    }
}

# %%
# what the splicts look like
memfs[1]
# Out:
# $`chow_fast-HPF__01`
#                 sample           ME diet region seq_run
# 1    S0010_01_chow_HPF  0.068131606 chow    HPF    0010
# 2    S0010_02_chow_HPF -0.004494135 chow    HPF    0010
# 3    S0010_03_chow_HPF  0.040145488 chow    HPF    0010
# 4    S0010_05_chow_HPF  0.042448492 chow    HPF    0010
# 5    S0010_06_chow_HPF  0.143176854 chow    HPF    0010
# 6    S0010_07_fast_HPF  0.133601161 fast    HPF    0010
# 7    S0010_08_fast_HPF  0.144179144 fast    HPF    0010
# 8    S0010_09_fast_HPF  0.082292832 fast    HPF    0010
# 9    S0010_10_fast_HPF -0.306421403 fast    HPF    0010
# 10   S0010_12_fast_HPF  0.041825708 fast    HPF    0010
# 11 S0037_1422_chow_HPF -0.020050925 chow    HPF    0037
# 12 S0037_1432_chow_HPF -0.093873241 chow    HPF    0037
# 13 S0037_1442_chow_HPF -0.042760299 chow    HPF    0037
# 14 S0037_1423_chow_HPF  0.090086062 chow    HPF    0037
# 15 S0037_1443_chow_HPF -0.047589244 chow    HPF    0037
# 16 S0037_1433_fast_HPF -0.066038583 fast    HPF    0037
# 17 S0037_1434_fast_HPF  0.048904749 fast    HPF    0037
# 18 S0037_1435_fast_HPF -0.413098283 fast    HPF    0037
# 19 S0037_1445_fast_HPF  0.108898208 fast    HPF    0037
# 20 S0037_1453_fast_HPF -0.043329551 fast    HPF    0037
# 21 S0037_1454_fast_HPF -0.016410911 fast    HPF    0037
# 22 S0037_1455_fast_HPF -0.062931268 fast    HPF    0037

# %%
# saveRDS(memfs, memfs_path)

# %%
# This does run in parallel! adjust workers accordingly
plan(multisession, workers = 20)
models <- future_map(memfs, ~safe_fit_mgcv(.x), .options = furrr_options(seed = T))

# %%
# function to drop models that error
filter_errored_models <- function(models){
    models_f <- c()
    models_error <-c()
    for (m in names(models)){
        model <- models[[m]]
        if (is.null(model$error)){
            models_f[[m]] <- model$result
        }
        else {
            models_error[[m]] <- model
        }
    }
    return (models_f)
}

# %%
# filter down models
models <- filter_errored_models(models)
length(models)
# Out:
# [1] 512

# %%
# lets see what models look like
models[1]
# Out:
# $`chow_fast-HPF__01`
#
# Family: gaussian
# Link function: identity
#
# Formula:
# ME ~ get(group_col) + s(seq_run, bs = "re")
#
# Estimated degrees of freedom:
# 0.509  total = 2.51
#
# fREML score: -9.190393

# %%
# summarize models
plan(multisession, workers = 20)
summaries <- future_map(models, ~summary(.x))

# %%
length(summaries)
# Out:
# [1] 512

# %%
# make a vector of summaries
mgcv_summaries_f <- c()
for (s in names(summaries)){
    summary <- summaries[[s]]
    p.pv <- summary$p.pv[[2]]
    mgcv_summaries_f[[s]] <-summary
}

# %%
# save vector just in case
saveRDS(mgcv_summaries_f, summaries_path)

# %%
# save models
saveRDS(models, models_path)

# %%
# data structure for export
ym_export <- c()
for (n in names(mgcv_summaries_f)){
    s <- mgcv_summaries_f[[n]]
    pval <- s$p.pv[2]
    coef <- s$p.coeff[2]
    ym_export[[n]] <- list('pvalue' = pval, "coef" = coef)
}

# %%
# what does it look like
ym_export
# Out:
# $`chow_fast-HPF__01`
# $`chow_fast-HPF__01`$pvalue
# get(group_col)fast
#           0.459638
#
# $`chow_fast-HPF__01`$coef
# get(group_col)fast
#        -0.04309954
#
#
# $`chow_fast-HPF__02`
# $`chow_fast-HPF__02`$pvalue
# get(group_col)fast
#          0.7216289
#
# $`chow_fast-HPF__02`$coef
# get(group_col)fast
#         0.02264421
#
#
# $`chow_fast-HPF__03`
# $`chow_fast-HPF__03`$pvalue
# get(group_col)fast
#          0.8188216
#
# $`chow_fast-HPF__03`$coef
# get(group_col)fast
#        0.006488202
#
#
# $`chow_fast-HPF__04`
# $`chow_fast-HPF__04`$pvalue
# get(group_col)fast
#          0.8363525
#
# $`chow_fast-HPF__04`$coef
# get(group_col)fast
#       -0.008617781
#
#
# $`chow_fast-HPF__05`
# $`chow_fast-HPF__05`$pvalue
# get(group_col)fast
#          0.1792122
#
# $`chow_fast-HPF__05`$coef
# get(group_col)fast
#         0.06191348
#
#
# $`chow_fast-HPF__06`
# $`chow_fast-HPF__06`$pvalue
# get(group_col)fast
#           0.832396
#
# $`chow_fast-HPF__06`$coef
# get(group_col)fast
#        0.006479312
#
#
# $`chow_fast-HPF__07`
# $`chow_fast-HPF__07`$pvalue
# get(group_col)fast
#           0.452136
#
# $`chow_fast-HPF__07`$coef
# get(group_col)fast
#        -0.02263942
#
#
# $`chow_fast-HPF__08`
# $`chow_fast-HPF__08`$pvalue
# get(group_col)fast
#          0.4575263
#
# $`chow_fast-HPF__08`$coef
# get(group_col)fast
#        -0.05420718
#
#
# $`chow_fast-HPF__09`
# $`chow_fast-HPF__09`$pvalue
# get(group_col)fast
#          0.8822309
#
# $`chow_fast-HPF__09`$coef
# get(group_col)fast
#        0.005698835
#
#
# $`chow_fast-HPF__10`
# $`chow_fast-HPF__10`$pvalue
# get(group_col)fast
#          0.5967076
#
# $`chow_fast-HPF__10`$coef
# get(group_col)fast
#        -0.04472901
#
#
# $`chow_fast-HPF__11`
# $`chow_fast-HPF__11`$pvalue
# get(group_col)fast
#          0.1039878
#
# $`chow_fast-HPF__11`$coef
# get(group_col)fast
#        -0.08005117
#
#
# $`chow_fast-HPF__12`
# $`chow_fast-HPF__12`$pvalue
# get(group_col)fast
#          0.0488106
#
# $`chow_fast-HPF__12`$coef
# get(group_col)fast
#        -0.09989685
#
#
# $`chow_fast-HPF__13`
# $`chow_fast-HPF__13`$pvalue
# get(group_col)fast
#          0.7246625
#
# $`chow_fast-HPF__13`$coef
# get(group_col)fast
#        0.007312263
#
#
# $`chow_fast-HPF__14`
# $`chow_fast-HPF__14`$pvalue
# get(group_col)fast
#          0.3549914
#
# $`chow_fast-HPF__14`$coef
# get(group_col)fast
#          0.0541456
#
#
# $`chow_fast-HPF__15`
# $`chow_fast-HPF__15`$pvalue
# get(group_col)fast
#          0.9302019
#
# $`chow_fast-HPF__15`$coef
# get(group_col)fast
#        0.003147707
#
#
# $`chow_fast-HPF__16`
# $`chow_fast-HPF__16`$pvalue
# get(group_col)fast
#          0.4312119
#
# $`chow_fast-HPF__16`$coef
# get(group_col)fast
#           0.052835
#
#
# $`chow_fast-HPF__17`
# $`chow_fast-HPF__17`$pvalue
# get(group_col)fast
#          0.1678202
#
# $`chow_fast-HPF__17`$coef
# get(group_col)fast
#        -0.01631544
#
#
# $`chow_fast-HPF__18`
# $`chow_fast-HPF__18`$pvalue
# get(group_col)fast
#          0.6292996
#
# $`chow_fast-HPF__18`$coef
# get(group_col)fast
#         0.03659817
#
#
# $`chow_fast-HPF__19`
# $`chow_fast-HPF__19`$pvalue
# get(group_col)fast
#          0.1451703
#
# $`chow_fast-HPF__19`$coef
# get(group_col)fast
#         0.02658715
#
#
# $`chow_fast-HPF__20`
# $`chow_fast-HPF__20`$pvalue
# get(group_col)fast
#          0.6744477
#
# $`chow_fast-HPF__20`$coef
# get(group_col)fast
#         0.01148897
#
#
# $`chow_fast-HPF__21`
# $`chow_fast-HPF__21`$pvalue
# get(group_col)fast
#          0.8786582
#
# $`chow_fast-HPF__21`$coef
# get(group_col)fast
#       -0.004288175
#
#
# $`chow_fast-HPF__22`
# $`chow_fast-HPF__22`$pvalue
# get(group_col)fast
#          0.6478488
#
# $`chow_fast-HPF__22`$coef
# get(group_col)fast
#         0.01926723
#
#
# $`chow_fast-HPF__23`
# $`chow_fast-HPF__23`$pvalue
# get(group_col)fast
#          0.6489021
#
# $`chow_fast-HPF__23`$coef
# get(group_col)fast
#         0.02154827
#
#
# $`chow_fast-HPF__24`
# $`chow_fast-HPF__24`$pvalue
# get(group_col)fast
#          0.6320331
#
# $`chow_fast-HPF__24`$coef
# get(group_col)fast
#        -0.01222566
#
#
# $`chow_fast-HPF__25`
# $`chow_fast-HPF__25`$pvalue
# get(group_col)fast
#         0.01290131
#
# $`chow_fast-HPF__25`$coef
# get(group_col)fast
#        -0.06035137
#
#
# $`chow_fast-HPF__26`
# $`chow_fast-HPF__26`$pvalue
# get(group_col)fast
#         0.07551488
#
# $`chow_fast-HPF__26`$coef
# get(group_col)fast
#        -0.05791413
#
#
# $`chow_fast-HPF__27`
# $`chow_fast-HPF__27`$pvalue
# get(group_col)fast
#          0.8067509
#
# $`chow_fast-HPF__27`$coef
# get(group_col)fast
#       -0.008749402
#
#
# $`chow_fast-HPF__28`
# $`chow_fast-HPF__28`$pvalue
# get(group_col)fast
#          0.1669446
#
# $`chow_fast-HPF__28`$coef
# get(group_col)fast
#         0.06353888
#
#
# $`chow_fast-HPF__29`
# $`chow_fast-HPF__29`$pvalue
# get(group_col)fast
#          0.2007239
#
# $`chow_fast-HPF__29`$coef
# get(group_col)fast
#         0.09193774
#
#
# $`chow_fast-HPF__30`
# $`chow_fast-HPF__30`$pvalue
# get(group_col)fast
#          0.2221206
#
# $`chow_fast-HPF__30`$coef
# get(group_col)fast
#        -0.01754707
#
#
# $`chow_fast-HPF__31`
# $`chow_fast-HPF__31`$pvalue
# get(group_col)fast
#          0.1855476
#
# $`chow_fast-HPF__31`$coef
# get(group_col)fast
#         0.04512381
#
#
# $`chow_fast-HPF__32`
# $`chow_fast-HPF__32`$pvalue
# get(group_col)fast
#          0.1690585
#
# $`chow_fast-HPF__32`$coef
# get(group_col)fast
#         0.03821272
#
#
# $`chow_fast-HPF__33`
# $`chow_fast-HPF__33`$pvalue
# get(group_col)fast
#         0.01064173
#
# $`chow_fast-HPF__33`$coef
# get(group_col)fast
#         0.07410378
#
#
# $`chow_fast-HPF__34`
# $`chow_fast-HPF__34`$pvalue
# get(group_col)fast
#          0.1698689
#
# $`chow_fast-HPF__34`$coef
# get(group_col)fast
#         0.05319162
#
#
# $`chow_fast-HPF__35`
# $`chow_fast-HPF__35`$pvalue
# get(group_col)fast
#          0.5463825
#
# $`chow_fast-HPF__35`$coef
# get(group_col)fast
#        -0.04250459
#
#
# $`chow_fast-HPF__36`
# $`chow_fast-HPF__36`$pvalue
# get(group_col)fast
#          0.1199922
#
# $`chow_fast-HPF__36`$coef
# get(group_col)fast
#         0.03468632
#
#
# $`chow_fast-HPF__37`
# $`chow_fast-HPF__37`$pvalue
# get(group_col)fast
#          0.6544165
#
# $`chow_fast-HPF__37`$coef
# get(group_col)fast
#         0.03046596
#
#
# $`chow_fast-HPF__38`
# $`chow_fast-HPF__38`$pvalue
# get(group_col)fast
#          0.1627018
#
# $`chow_fast-HPF__38`$coef
# get(group_col)fast
#        -0.05019856
#
#
# $`chow_fast-HY__01`
# $`chow_fast-HY__01`$pvalue
# get(group_col)fast
#          0.4277989
#
# $`chow_fast-HY__01`$coef
# get(group_col)fast
#        -0.03095621
#
#
# $`chow_fast-HY__02`
# $`chow_fast-HY__02`$pvalue
# get(group_col)fast
#          0.5801433
#
# $`chow_fast-HY__02`$coef
# get(group_col)fast
#       -0.001965771
#
#
# $`chow_fast-HY__03`
# $`chow_fast-HY__03`$pvalue
# get(group_col)fast
#          0.3112006
#
# $`chow_fast-HY__03`$coef
# get(group_col)fast
#        -0.01466109
#
#
# $`chow_fast-HY__04`
# $`chow_fast-HY__04`$pvalue
# get(group_col)fast
#          0.9043835
#
# $`chow_fast-HY__04`$coef
# get(group_col)fast
#         -0.0012444
#
#
# $`chow_fast-HY__05`
# $`chow_fast-HY__05`$pvalue
# get(group_col)fast
#          0.8704444
#
# $`chow_fast-HY__05`$coef
# get(group_col)fast
#        0.004742323
#
#
# $`chow_fast-HY__06`
# $`chow_fast-HY__06`$pvalue
# get(group_col)fast
#         0.02157758
#
# $`chow_fast-HY__06`$coef
# get(group_col)fast
#         0.09807859
#
#
# $`chow_fast-HY__07`
# $`chow_fast-HY__07`$pvalue
# get(group_col)fast
#          0.7874538
#
# $`chow_fast-HY__07`$coef
# get(group_col)fast
#        0.003515939
#
#
# $`chow_fast-HY__08`
# $`chow_fast-HY__08`$pvalue
# get(group_col)fast
#          0.4548375
#
# $`chow_fast-HY__08`$coef
# get(group_col)fast
#         0.01047976
#
#
# $`chow_fast-HY__09`
# $`chow_fast-HY__09`$pvalue
# get(group_col)fast
#          0.9532362
#
# $`chow_fast-HY__09`$coef
# get(group_col)fast
#        0.002460682
#
#
# $`chow_fast-HY__10`
# $`chow_fast-HY__10`$pvalue
# get(group_col)fast
#          0.6070695
#
# $`chow_fast-HY__10`$coef
# get(group_col)fast
#        0.006642277
#
#
# $`chow_fast-HY__11`
# $`chow_fast-HY__11`$pvalue
# get(group_col)fast
#          0.5576505
#
# $`chow_fast-HY__11`$coef
# get(group_col)fast
#        -0.03428845
#
#
# $`chow_fast-HY__12`
# $`chow_fast-HY__12`$pvalue
# get(group_col)fast
#          0.5179134
#
# $`chow_fast-HY__12`$coef
# get(group_col)fast
#        0.006035294
#
#
# $`chow_fast-HY__13`
# $`chow_fast-HY__13`$pvalue
# get(group_col)fast
#          0.9499947
#
# $`chow_fast-HY__13`$coef
# get(group_col)fast
#       -0.003148217
#
#
# $`chow_fast-HY__14`
# $`chow_fast-HY__14`$pvalue
# get(group_col)fast
#          0.8321161
#
# $`chow_fast-HY__14`$coef
# get(group_col)fast
#        -0.01381128
#
#
# $`chow_fast-HY__15`
# $`chow_fast-HY__15`$pvalue
# get(group_col)fast
#          0.9691219
#
# $`chow_fast-HY__15`$coef
# get(group_col)fast
#        0.001851409
#
#
# $`chow_fast-HY__16`
# $`chow_fast-HY__16`$pvalue
# get(group_col)fast
#          0.7241492
#
# $`chow_fast-HY__16`$coef
# get(group_col)fast
#         0.01837174
#
#
# $`chow_fast-HY__17`
# $`chow_fast-HY__17`$pvalue
# get(group_col)fast
#          0.2209981
#
# $`chow_fast-HY__17`$coef
# get(group_col)fast
#        -0.05146707
#
#
# $`chow_fast-HY__18`
# $`chow_fast-HY__18`$pvalue
# get(group_col)fast
#           0.238641
#
# $`chow_fast-HY__18`$coef
# get(group_col)fast
#         0.03816969
#
#
# $`chow_fast-HY__19`
# $`chow_fast-HY__19`$pvalue
# get(group_col)fast
#        0.003598614
#
# $`chow_fast-HY__19`$coef
# get(group_col)fast
#          0.1395362
#
#
# $`chow_fast-HY__20`
# $`chow_fast-HY__20`$pvalue
# get(group_col)fast
#         0.01318281
#
# $`chow_fast-HY__20`$coef
# get(group_col)fast
#         0.01643295
#
#
# $`chow_fast-HY__21`
# $`chow_fast-HY__21`$pvalue
# get(group_col)fast
#          0.7128774
#
# $`chow_fast-HY__21`$coef
# get(group_col)fast
#        -0.01764932
#
#
# $`chow_fast-HY__22`
# $`chow_fast-HY__22`$pvalue
# get(group_col)fast
#          0.6678461
#
# $`chow_fast-HY__22`$coef
# get(group_col)fast
#       -0.002473342
#
#
# $`chow_fast-HY__23`
# $`chow_fast-HY__23`$pvalue
# get(group_col)fast
#           0.465591
#
# $`chow_fast-HY__23`$coef
# get(group_col)fast
#         0.03431266
#
#
# $`chow_fast-HY__24`
# $`chow_fast-HY__24`$pvalue
# get(group_col)fast
#           0.603278
#
# $`chow_fast-HY__24`$coef
# get(group_col)fast
#         0.01270011
#
#
# $`chow_fast-HY__25`
# $`chow_fast-HY__25`$pvalue
# get(group_col)fast
#          0.2578467
#
# $`chow_fast-HY__25`$coef
# get(group_col)fast
#          0.0475459
#
#
# $`chow_fast-HY__26`
# $`chow_fast-HY__26`$pvalue
# get(group_col)fast
#          0.5943542
#
# $`chow_fast-HY__26`$coef
# get(group_col)fast
#        -0.02299044
#
#
# $`chow_fast-HY__27`
# $`chow_fast-HY__27`$pvalue
# get(group_col)fast
#          0.7274787
#
# $`chow_fast-HY__27`$coef
# get(group_col)fast
#        0.008191511
#
#
# $`chow_fast-HY__28`
# $`chow_fast-HY__28`$pvalue
# get(group_col)fast
#          0.9385896
#
# $`chow_fast-HY__28`$coef
# get(group_col)fast
#       0.0005909602
#
#
# $`chow_fast-HY__29`
# $`chow_fast-HY__29`$pvalue
# get(group_col)fast
#          0.6180065
#
# $`chow_fast-HY__29`$coef
# get(group_col)fast
#        -0.01148745
#
#
# $`chow_fast-HY__30`
# $`chow_fast-HY__30`$pvalue
# get(group_col)fast
#          0.7368091
#
# $`chow_fast-HY__30`$coef
# get(group_col)fast
#         0.02345581
#
#
# $`chow_fast-HY__31`
# $`chow_fast-HY__31`$pvalue
# get(group_col)fast
#         0.04852757
#
# $`chow_fast-HY__31`$coef
# get(group_col)fast
#          0.1247653
#
#
# $`chow_fast-HY__32`
# $`chow_fast-HY__32`$pvalue
# get(group_col)fast
#          0.3999811
#
# $`chow_fast-HY__32`$coef
# get(group_col)fast
#        0.008694231
#
#
# $`chow_fast-HY__33`
# $`chow_fast-HY__33`$pvalue
# get(group_col)fast
#          0.2012595
#
# $`chow_fast-HY__33`$coef
# get(group_col)fast
#       -0.007948343
#
#
# $`chow_fast-HY__34`
# $`chow_fast-HY__34`$pvalue
# get(group_col)fast
#         0.02872653
#
# $`chow_fast-HY__34`$coef
# get(group_col)fast
#         0.01945364
#
#
# $`chow_fast-HY__35`
# $`chow_fast-HY__35`$pvalue
# get(group_col)fast
#         0.01757991
#
# $`chow_fast-HY__35`$coef
# get(group_col)fast
#          0.1363584
#
#
# $`chow_fast-HY__36`
# $`chow_fast-HY__36`$pvalue
# get(group_col)fast
#          0.2463071
#
# $`chow_fast-HY__36`$coef
# get(group_col)fast
#        -0.04387302
#
#
# $`chow_fast-HY__37`
# $`chow_fast-HY__37`$pvalue
# get(group_col)fast
#          0.2900205
#
# $`chow_fast-HY__37`$coef
# get(group_col)fast
#        -0.01243712
#
#
# $`chow_fast-HY__38`
# $`chow_fast-HY__38`$pvalue
# get(group_col)fast
#          0.6281416
#
# $`chow_fast-HY__38`$coef
# get(group_col)fast
#       -0.004579702
#
#
# $`chow_fast-HY__39`
# $`chow_fast-HY__39`$pvalue
# get(group_col)fast
#          0.6701187
#
# $`chow_fast-HY__39`$coef
# get(group_col)fast
#        0.007993754
#
#
# $`chow_fast-HY__40`
# $`chow_fast-HY__40`$pvalue
# get(group_col)fast
#          0.3288217
#
# $`chow_fast-HY__40`$coef
# get(group_col)fast
#         0.07177444
#
#
# $`chow_fast-HY__41`
# $`chow_fast-HY__41`$pvalue
# get(group_col)fast
#          0.3870883
#
# $`chow_fast-HY__41`$coef
# get(group_col)fast
#       -0.005034794
#
#
# $`chow_fast-HY__42`
# $`chow_fast-HY__42`$pvalue
# get(group_col)fast
#          0.3018599
#
# $`chow_fast-HY__42`$coef
# get(group_col)fast
#        -0.03966393
#
#
# $`chow_fast-HY__43`
# $`chow_fast-HY__43`$pvalue
# get(group_col)fast
#          0.5474781
#
# $`chow_fast-HY__43`$coef
# get(group_col)fast
#       -0.007551459
#
#
# $`chow_fast-HY__44`
# $`chow_fast-HY__44`$pvalue
# get(group_col)fast
#          0.3873623
#
# $`chow_fast-HY__44`$coef
# get(group_col)fast
#         0.04233037
#
#
# $`chow_fast-HY__45`
# $`chow_fast-HY__45`$pvalue
# get(group_col)fast
#          0.6534152
#
# $`chow_fast-HY__45`$coef
# get(group_col)fast
#        -0.01142309
#
#
# $`chow_fast-HY__46`
# $`chow_fast-HY__46`$pvalue
# get(group_col)fast
#          0.0482857
#
# $`chow_fast-HY__46`$coef
# get(group_col)fast
#        -0.04213874
#
#
# $`chow_fast-HY__47`
# $`chow_fast-HY__47`$pvalue
# get(group_col)fast
#          0.7168968
#
# $`chow_fast-HY__47`$coef
# get(group_col)fast
#        -0.01043923
#
#
# $`chow_fast-HY__48`
# $`chow_fast-HY__48`$pvalue
# get(group_col)fast
#          0.5183452
#
# $`chow_fast-HY__48`$coef
# get(group_col)fast
#         0.01022291
#
#
# $`chow_fast-HY__49`
# $`chow_fast-HY__49`$pvalue
# get(group_col)fast
#          0.6336764
#
# $`chow_fast-HY__49`$coef
# get(group_col)fast
#         -0.0306458
#
#
# $`chow_fast-HY__50`
# $`chow_fast-HY__50`$pvalue
# get(group_col)fast
#       4.625723e-06
#
# $`chow_fast-HY__50`$coef
# get(group_col)fast
#           0.133613
#
#
# $`chow_fast-HY__51`
# $`chow_fast-HY__51`$pvalue
# get(group_col)fast
#           0.252242
#
# $`chow_fast-HY__51`$coef
# get(group_col)fast
#         0.06070289
#
#
# $`chow_fast-HY__52`
# $`chow_fast-HY__52`$pvalue
# get(group_col)fast
#         0.02517276
#
# $`chow_fast-HY__52`$coef
# get(group_col)fast
#        -0.06483739
#
#
# $`chow_fast-HY__53`
# $`chow_fast-HY__53`$pvalue
# get(group_col)fast
#         0.02201791
#
# $`chow_fast-HY__53`$coef
# get(group_col)fast
#         0.07924574
#
#
# $`chow_fast-HY__54`
# $`chow_fast-HY__54`$pvalue
# get(group_col)fast
#          0.1092233
#
# $`chow_fast-HY__54`$coef
# get(group_col)fast
#        -0.06666495
#
#
# $`chow_fast-HY__55`
# $`chow_fast-HY__55`$pvalue
# get(group_col)fast
#          0.2418395
#
# $`chow_fast-HY__55`$coef
# get(group_col)fast
#        0.008109089
#
#
# $`chow_fast-HY__56`
# $`chow_fast-HY__56`$pvalue
# get(group_col)fast
#          0.2968021
#
# $`chow_fast-HY__56`$coef
# get(group_col)fast
#        -0.04366199
#
#
# $`chow_fast-HY__57`
# $`chow_fast-HY__57`$pvalue
# get(group_col)fast
#           0.224358
#
# $`chow_fast-HY__57`$coef
# get(group_col)fast
#        -0.04278798
#
#
# $`chow_fast-HY__58`
# $`chow_fast-HY__58`$pvalue
# get(group_col)fast
#          0.1493159
#
# $`chow_fast-HY__58`$coef
# get(group_col)fast
#         0.05340464
#
#
# $`chow_fast-HY__59`
# $`chow_fast-HY__59`$pvalue
# get(group_col)fast
#         0.07998744
#
# $`chow_fast-HY__59`$coef
# get(group_col)fast
#         0.02962016
#
#
# $`chow_fast-HY__60`
# $`chow_fast-HY__60`$pvalue
# get(group_col)fast
#           0.522562
#
# $`chow_fast-HY__60`$coef
# get(group_col)fast
#          0.0203906
#
#
# $`chow_fast-HY__61`
# $`chow_fast-HY__61`$pvalue
# get(group_col)fast
#          0.7664082
#
# $`chow_fast-HY__61`$coef
# get(group_col)fast
#        -0.01098598
#
#
# $`chow_fast-HY__62`
# $`chow_fast-HY__62`$pvalue
# get(group_col)fast
#          0.6942391
#
# $`chow_fast-HY__62`$coef
# get(group_col)fast
#        0.005327006
#
#
# $`chow_fast-HY__63`
# $`chow_fast-HY__63`$pvalue
# get(group_col)fast
#          0.1838238
#
# $`chow_fast-HY__63`$coef
# get(group_col)fast
#         0.06863581
#
#
# $`chow_fast-HY__64`
# $`chow_fast-HY__64`$pvalue
# get(group_col)fast
#          0.7417231
#
# $`chow_fast-HY__64`$coef
# get(group_col)fast
#       -0.002335638
#
#
# $`chow_fast-HY__65`
# $`chow_fast-HY__65`$pvalue
# get(group_col)fast
#          0.5153262
#
# $`chow_fast-HY__65`$coef
# get(group_col)fast
#        -0.03117132
#
#
# $`chow_fast-HY__66`
# $`chow_fast-HY__66`$pvalue
# get(group_col)fast
#         0.08870342
#
# $`chow_fast-HY__66`$coef
# get(group_col)fast
#        -0.01312664
#
#
# $`chow_fast-HY__67`
# $`chow_fast-HY__67`$pvalue
# get(group_col)fast
#         0.03921367
#
# $`chow_fast-HY__67`$coef
# get(group_col)fast
#         0.05534961
#
#
# $`chow_fast-HY__68`
# $`chow_fast-HY__68`$pvalue
# get(group_col)fast
#          0.1389135
#
# $`chow_fast-HY__68`$coef
# get(group_col)fast
#         0.06832301
#
#
# $`chow_fast-HY__69`
# $`chow_fast-HY__69`$pvalue
# get(group_col)fast
#          0.1657436
#
# $`chow_fast-HY__69`$coef
# get(group_col)fast
#          0.0334861
#
#
# $`chow_fast-HY__70`
# $`chow_fast-HY__70`$pvalue
# get(group_col)fast
#          0.3376512
#
# $`chow_fast-HY__70`$coef
# get(group_col)fast
#        -0.01542775
#
#
# $`chow_fast-HY__71`
# $`chow_fast-HY__71`$pvalue
# get(group_col)fast
#       3.188199e-05
#
# $`chow_fast-HY__71`$coef
# get(group_col)fast
#        -0.09588819
#
#
# $`chow_fast-HY__72`
# $`chow_fast-HY__72`$pvalue
# get(group_col)fast
#          0.8849643
#
# $`chow_fast-HY__72`$coef
# get(group_col)fast
#       -0.006786967
#
#
# $`chow_fast-HY__73`
# $`chow_fast-HY__73`$pvalue
# get(group_col)fast
#          0.6727089
#
# $`chow_fast-HY__73`$coef
# get(group_col)fast
#         0.02213049
#
#
# $`chow_fast-HY__74`
# $`chow_fast-HY__74`$pvalue
# get(group_col)fast
#           0.345739
#
# $`chow_fast-HY__74`$coef
# get(group_col)fast
#        -0.01858799
#
#
# $`chow_fast-HY__75`
# $`chow_fast-HY__75`$pvalue
# get(group_col)fast
#          0.1111087
#
# $`chow_fast-HY__75`$coef
# get(group_col)fast
#         0.09039591
#
#
# $`chow_fast-HY__76`
# $`chow_fast-HY__76`$pvalue
# get(group_col)fast
#          0.4404566
#
# $`chow_fast-HY__76`$coef
# get(group_col)fast
#        -0.02136005
#
#
# $`chow_fast-HY__77`
# $`chow_fast-HY__77`$pvalue
# get(group_col)fast
#          0.0628667
#
# $`chow_fast-HY__77`$coef
# get(group_col)fast
#        -0.08550764
#
#
# $`chow_fast-HY__78`
# $`chow_fast-HY__78`$pvalue
# get(group_col)fast
#         0.05186829
#
# $`chow_fast-HY__78`$coef
# get(group_col)fast
#        -0.05797393
#
#
# $`chow_fast-HY__79`
# $`chow_fast-HY__79`$pvalue
# get(group_col)fast
#          0.1630163
#
# $`chow_fast-HY__79`$coef
# get(group_col)fast
#        -0.01848964
#
#
# $`chow_fast-IC__01`
# $`chow_fast-IC__01`$pvalue
# get(group_col)fast
#          0.3730338
#
# $`chow_fast-IC__01`$coef
# get(group_col)fast
#        -0.01520699
#
#
# $`chow_fast-IC__02`
# $`chow_fast-IC__02`$pvalue
# get(group_col)fast
#          0.9815776
#
# $`chow_fast-IC__02`$coef
# get(group_col)fast
#        0.000364322
#
#
# $`chow_fast-IC__03`
# $`chow_fast-IC__03`$pvalue
# get(group_col)fast
#         0.01831034
#
# $`chow_fast-IC__03`$coef
# get(group_col)fast
#        -0.06344306
#
#
# $`chow_fast-IC__04`
# $`chow_fast-IC__04`$pvalue
# get(group_col)fast
#          0.1897012
#
# $`chow_fast-IC__04`$coef
# get(group_col)fast
#        -0.05043305
#
#
# $`chow_fast-IC__05`
# $`chow_fast-IC__05`$pvalue
# get(group_col)fast
#          0.2612268
#
# $`chow_fast-IC__05`$coef
# get(group_col)fast
#        -0.05184597
#
#
# $`chow_fast-IC__06`
# $`chow_fast-IC__06`$pvalue
# get(group_col)fast
#          0.5207637
#
# $`chow_fast-IC__06`$coef
# get(group_col)fast
#         0.02124291
#
#
# $`chow_fast-IC__07`
# $`chow_fast-IC__07`$pvalue
# get(group_col)fast
#       0.0001511013
#
# $`chow_fast-IC__07`$coef
# get(group_col)fast
#         -0.1033702
#
#
# $`chow_fast-IC__08`
# $`chow_fast-IC__08`$pvalue
# get(group_col)fast
#       5.889459e-05
#
# $`chow_fast-IC__08`$coef
# get(group_col)fast
#          0.1177089
#
#
# $`chow_fast-IC__09`
# $`chow_fast-IC__09`$pvalue
# get(group_col)fast
#          0.7146604
#
# $`chow_fast-IC__09`$coef
# get(group_col)fast
#        -0.01104206
#
#
# $`chow_fast-IC__10`
# $`chow_fast-IC__10`$pvalue
# get(group_col)fast
#          0.8647943
#
# $`chow_fast-IC__10`$coef
# get(group_col)fast
#        0.008088467
#
#
# $`chow_fast-IC__11`
# $`chow_fast-IC__11`$pvalue
# get(group_col)fast
#          0.5528168
#
# $`chow_fast-IC__11`$coef
# get(group_col)fast
#       -0.003305399
#
#
# $`chow_fast-IC__12`
# $`chow_fast-IC__12`$pvalue
# get(group_col)fast
#          0.9860038
#
# $`chow_fast-IC__12`$coef
# get(group_col)fast
#      -0.0004065541
#
#
# $`chow_fast-IC__13`
# $`chow_fast-IC__13`$pvalue
# get(group_col)fast
#         0.03775275
#
# $`chow_fast-IC__13`$coef
# get(group_col)fast
#         0.02509261
#
#
# $`chow_fast-IC__14`
# $`chow_fast-IC__14`$pvalue
# get(group_col)fast
#          0.5547022
#
# $`chow_fast-IC__14`$coef
# get(group_col)fast
#         0.01851355
#
#
# $`chow_fast-IC__15`
# $`chow_fast-IC__15`$pvalue
# get(group_col)fast
#        4.10355e-05
#
# $`chow_fast-IC__15`$coef
# get(group_col)fast
#          0.1275406
#
#
# $`chow_fast-IC__16`
# $`chow_fast-IC__16`$pvalue
# get(group_col)fast
#          0.3204879
#
# $`chow_fast-IC__16`$coef
# get(group_col)fast
#         0.02535187
#
#
# $`chow_fast-IC__17`
# $`chow_fast-IC__17`$pvalue
# get(group_col)fast
#        0.003436221
#
# $`chow_fast-IC__17`$coef
# get(group_col)fast
#        -0.06582372
#
#
# $`chow_fast-IC__18`
# $`chow_fast-IC__18`$pvalue
# get(group_col)fast
#          0.5707695
#
# $`chow_fast-IC__18`$coef
# get(group_col)fast
#         0.03335187
#
#
# $`chow_fast-IC__19`
# $`chow_fast-IC__19`$pvalue
# get(group_col)fast
#          0.7619275
#
# $`chow_fast-IC__19`$coef
# get(group_col)fast
#       -0.002506571
#
#
# $`chow_fast-IC__20`
# $`chow_fast-IC__20`$pvalue
# get(group_col)fast
#          0.3631352
#
# $`chow_fast-IC__20`$coef
# get(group_col)fast
#        -0.02569169
#
#
# $`chow_fast-IC__21`
# $`chow_fast-IC__21`$pvalue
# get(group_col)fast
#          0.4684818
#
# $`chow_fast-IC__21`$coef
# get(group_col)fast
#       -0.009392833
#
#
# $`chow_fast-IC__22`
# $`chow_fast-IC__22`$pvalue
# get(group_col)fast
#          0.3783034
#
# $`chow_fast-IC__22`$coef
# get(group_col)fast
#         0.05483122
#
#
# $`chow_fast-IC__23`
# $`chow_fast-IC__23`$pvalue
# get(group_col)fast
#          0.7407214
#
# $`chow_fast-IC__23`$coef
# get(group_col)fast
#         0.01610574
#
#
# $`chow_fast-IC__24`
# $`chow_fast-IC__24`$pvalue
# get(group_col)fast
#          0.9595431
#
# $`chow_fast-IC__24`$coef
# get(group_col)fast
#       -0.002456076
#
#
# $`chow_fast-IC__25`
# $`chow_fast-IC__25`$pvalue
# get(group_col)fast
#           0.588137
#
# $`chow_fast-IC__25`$coef
# get(group_col)fast
#        -0.02131238
#
#
# $`chow_fast-IC__26`
# $`chow_fast-IC__26`$pvalue
# get(group_col)fast
#          0.6763929
#
# $`chow_fast-IC__26`$coef
# get(group_col)fast
#       -0.002895627
#
#
# $`chow_fast-IC__27`
# $`chow_fast-IC__27`$pvalue
# get(group_col)fast
#          0.7056342
#
# $`chow_fast-IC__27`$coef
# get(group_col)fast
#        -0.01788429
#
#
# $`chow_fast-IC__28`
# $`chow_fast-IC__28`$pvalue
# get(group_col)fast
#          0.5032876
#
# $`chow_fast-IC__28`$coef
# get(group_col)fast
#        0.008177336
#
#
# $`chow_fast-IC__29`
# $`chow_fast-IC__29`$pvalue
# get(group_col)fast
#          0.7500961
#
# $`chow_fast-IC__29`$coef
# get(group_col)fast
#         0.01808818
#
#
# $`chow_fast-IC__30`
# $`chow_fast-IC__30`$pvalue
# get(group_col)fast
#          0.5777487
#
# $`chow_fast-IC__30`$coef
# get(group_col)fast
#        -0.02181469
#
#
# $`chow_fast-IC__31`
# $`chow_fast-IC__31`$pvalue
# get(group_col)fast
#          0.4100524
#
# $`chow_fast-IC__31`$coef
# get(group_col)fast
#         0.03891711
#
#
# $`chow_fast-IC__32`
# $`chow_fast-IC__32`$pvalue
# get(group_col)fast
#       9.705456e-05
#
# $`chow_fast-IC__32`$coef
# get(group_col)fast
#           -0.11862
#
#
# $`chow_fast-IC__33`
# $`chow_fast-IC__33`$pvalue
# get(group_col)fast
#          0.6916273
#
# $`chow_fast-IC__33`$coef
# get(group_col)fast
#        0.004689306
#
#
# $`chow_fast-IC__34`
# $`chow_fast-IC__34`$pvalue
# get(group_col)fast
#        0.007355828
#
# $`chow_fast-IC__34`$coef
# get(group_col)fast
#         -0.1009264
#
#
# $`chow_fast-IC__35`
# $`chow_fast-IC__35`$pvalue
# get(group_col)fast
#          0.3992867
#
# $`chow_fast-IC__35`$coef
# get(group_col)fast
#       -0.009618889
#
#
# $`chow_fast-IC__36`
# $`chow_fast-IC__36`$pvalue
# get(group_col)fast
#          0.9556116
#
# $`chow_fast-IC__36`$coef
# get(group_col)fast
#        0.001909351
#
#
# $`chow_fast-IC__37`
# $`chow_fast-IC__37`$pvalue
# get(group_col)fast
#          0.8640098
#
# $`chow_fast-IC__37`$coef
# get(group_col)fast
#       -0.009728566
#
#
# $`chow_fast-IC__38`
# $`chow_fast-IC__38`$pvalue
# get(group_col)fast
#          0.4581186
#
# $`chow_fast-IC__38`$coef
# get(group_col)fast
#        -0.03358711
#
#
# $`chow_fast-IC__39`
# $`chow_fast-IC__39`$pvalue
# get(group_col)fast
#          0.9583674
#
# $`chow_fast-IC__39`$coef
# get(group_col)fast
#      -0.0006753306
#
#
# $`chow_fast-IC__40`
# $`chow_fast-IC__40`$pvalue
# get(group_col)fast
#          0.5107115
#
# $`chow_fast-IC__40`$coef
# get(group_col)fast
#        -0.02332472
#
#
# $`chow_fast-IC__41`
# $`chow_fast-IC__41`$pvalue
# get(group_col)fast
#          0.6398014
#
# $`chow_fast-IC__41`$coef
# get(group_col)fast
#          0.0228311
#
#
# $`chow_fast-IC__42`
# $`chow_fast-IC__42`$pvalue
# get(group_col)fast
#          0.4787526
#
# $`chow_fast-IC__42`$coef
# get(group_col)fast
#        -0.03705283
#
#
# $`chow_fast-IC__43`
# $`chow_fast-IC__43`$pvalue
# get(group_col)fast
#          0.5129538
#
# $`chow_fast-IC__43`$coef
# get(group_col)fast
#        -0.03398729
#
#
# $`chow_fast-IC__44`
# $`chow_fast-IC__44`$pvalue
# get(group_col)fast
#          0.5906069
#
# $`chow_fast-IC__44`$coef
# get(group_col)fast
#        -0.01841041
#
#
# $`chow_fast-IC__45`
# $`chow_fast-IC__45`$pvalue
# get(group_col)fast
#          0.1748057
#
# $`chow_fast-IC__45`$coef
# get(group_col)fast
#         0.06553782
#
#
# $`chow_fast-IC__46`
# $`chow_fast-IC__46`$pvalue
# get(group_col)fast
#           0.646465
#
# $`chow_fast-IC__46`$coef
# get(group_col)fast
#         0.02802792
#
#
# $`chow_fast-IC__47`
# $`chow_fast-IC__47`$pvalue
# get(group_col)fast
#          0.8745398
#
# $`chow_fast-IC__47`$coef
# get(group_col)fast
#        0.006731136
#
#
# $`chow_fast-SC__01`
# $`chow_fast-SC__01`$pvalue
# get(group_col)fast
#          0.2486064
#
# $`chow_fast-SC__01`$coef
# get(group_col)fast
#        -0.05719016
#
#
# $`chow_fast-SC__02`
# $`chow_fast-SC__02`$pvalue
# get(group_col)fast
#          0.6263444
#
# $`chow_fast-SC__02`$coef
# get(group_col)fast
#        -0.01923356
#
#
# $`chow_fast-SC__03`
# $`chow_fast-SC__03`$pvalue
# get(group_col)fast
#          0.3111473
#
# $`chow_fast-SC__03`$coef
# get(group_col)fast
#       -0.007944204
#
#
# $`chow_fast-SC__04`
# $`chow_fast-SC__04`$pvalue
# get(group_col)fast
#          0.5809757
#
# $`chow_fast-SC__04`$coef
# get(group_col)fast
#         0.02793279
#
#
# $`chow_fast-SC__05`
# $`chow_fast-SC__05`$pvalue
# get(group_col)fast
#          0.3687136
#
# $`chow_fast-SC__05`$coef
# get(group_col)fast
#         0.03571122
#
#
# $`chow_fast-SC__06`
# $`chow_fast-SC__06`$pvalue
# get(group_col)fast
#          0.2384592
#
# $`chow_fast-SC__06`$coef
# get(group_col)fast
#         0.00886108
#
#
# $`chow_fast-SC__07`
# $`chow_fast-SC__07`$pvalue
# get(group_col)fast
#          0.4726479
#
# $`chow_fast-SC__07`$coef
# get(group_col)fast
#         0.01471234
#
#
# $`chow_fast-SC__08`
# $`chow_fast-SC__08`$pvalue
# get(group_col)fast
#         0.01290508
#
# $`chow_fast-SC__08`$coef
# get(group_col)fast
#         0.05414504
#
#
# $`chow_fast-SC__09`
# $`chow_fast-SC__09`$pvalue
# get(group_col)fast
#          0.9511311
#
# $`chow_fast-SC__09`$coef
# get(group_col)fast
#        0.003388855
#
#
# $`chow_fast-SC__10`
# $`chow_fast-SC__10`$pvalue
# get(group_col)fast
#          0.1412938
#
# $`chow_fast-SC__10`$coef
# get(group_col)fast
#         0.07442538
#
#
# $`chow_fast-SC__11`
# $`chow_fast-SC__11`$pvalue
# get(group_col)fast
#         0.08239858
#
# $`chow_fast-SC__11`$coef
# get(group_col)fast
#          0.1038703
#
#
# $`chow_fast-SC__12`
# $`chow_fast-SC__12`$pvalue
# get(group_col)fast
#          0.2132601
#
# $`chow_fast-SC__12`$coef
# get(group_col)fast
#         0.04075454
#
#
# $`chow_fast-SC__13`
# $`chow_fast-SC__13`$pvalue
# get(group_col)fast
#          0.3313612
#
# $`chow_fast-SC__13`$coef
# get(group_col)fast
#         0.03647873
#
#
# $`chow_fast-SC__14`
# $`chow_fast-SC__14`$pvalue
# get(group_col)fast
#          0.9311542
#
# $`chow_fast-SC__14`$coef
# get(group_col)fast
#       -0.005935233
#
#
# $`chow_fast-SC__15`
# $`chow_fast-SC__15`$pvalue
# get(group_col)fast
#           0.917836
#
# $`chow_fast-SC__15`$coef
# get(group_col)fast
#        0.003675256
#
#
# $`chow_fast-SC__16`
# $`chow_fast-SC__16`$pvalue
# get(group_col)fast
#          0.7286275
#
# $`chow_fast-SC__16`$coef
# get(group_col)fast
#        -0.02410356
#
#
# $`chow_fast-SC__17`
# $`chow_fast-SC__17`$pvalue
# get(group_col)fast
#          0.8011434
#
# $`chow_fast-SC__17`$coef
# get(group_col)fast
#        -0.01805149
#
#
# $`chow_fast-SC__18`
# $`chow_fast-SC__18`$pvalue
# get(group_col)fast
#          0.1782338
#
# $`chow_fast-SC__18`$coef
# get(group_col)fast
#         0.02939498
#
#
# $`chow_fast-SC__19`
# $`chow_fast-SC__19`$pvalue
# get(group_col)fast
#            0.44287
#
# $`chow_fast-SC__19`$coef
# get(group_col)fast
#        -0.01373449
#
#
# $`chow_fast-SC__20`
# $`chow_fast-SC__20`$pvalue
# get(group_col)fast
#          0.2288833
#
# $`chow_fast-SC__20`$coef
# get(group_col)fast
#        -0.06470262
#
#
# $`chow_fast-SC__21`
# $`chow_fast-SC__21`$pvalue
# get(group_col)fast
#           0.448438
#
# $`chow_fast-SC__21`$coef
# get(group_col)fast
#         0.00844623
#
#
# $`chow_fast-SC__22`
# $`chow_fast-SC__22`$pvalue
# get(group_col)fast
#          0.5053198
#
# $`chow_fast-SC__22`$coef
# get(group_col)fast
#        -0.04189566
#
#
# $`chow_fast-SC__23`
# $`chow_fast-SC__23`$pvalue
# get(group_col)fast
#          0.2042653
#
# $`chow_fast-SC__23`$coef
# get(group_col)fast
#         0.01474481
#
#
# $`chow_fast-SC__24`
# $`chow_fast-SC__24`$pvalue
# get(group_col)fast
#          0.4374365
#
# $`chow_fast-SC__24`$coef
# get(group_col)fast
#        -0.01948564
#
#
# $`chow_fast-SC__25`
# $`chow_fast-SC__25`$pvalue
# get(group_col)fast
#          0.4728438
#
# $`chow_fast-SC__25`$coef
# get(group_col)fast
#         0.03457297
#
#
# $`chow_fast-SC__26`
# $`chow_fast-SC__26`$pvalue
# get(group_col)fast
#          0.8797187
#
# $`chow_fast-SC__26`$coef
# get(group_col)fast
#        0.009272457
#
#
# $`chow_fast-SC__27`
# $`chow_fast-SC__27`$pvalue
# get(group_col)fast
#       0.0001678408
#
# $`chow_fast-SC__27`$coef
# get(group_col)fast
#        -0.04701637
#
#
# $`chow_fast-SC__28`
# $`chow_fast-SC__28`$pvalue
# get(group_col)fast
#          0.0727979
#
# $`chow_fast-SC__28`$coef
# get(group_col)fast
#         -0.1346986
#
#
# $`chow_fast-SC__29`
# $`chow_fast-SC__29`$pvalue
# get(group_col)fast
#          0.5804159
#
# $`chow_fast-SC__29`$coef
# get(group_col)fast
#        -0.03120205
#
#
# $`chow_fast-SC__30`
# $`chow_fast-SC__30`$pvalue
# get(group_col)fast
#          0.1366061
#
# $`chow_fast-SC__30`$coef
# get(group_col)fast
#        -0.03302211
#
#
# $`chow_fast-SC__31`
# $`chow_fast-SC__31`$pvalue
# get(group_col)fast
#          0.6616188
#
# $`chow_fast-SC__31`$coef
# get(group_col)fast
#         0.01490581
#
#
# $`chow_fast-SC__32`
# $`chow_fast-SC__32`$pvalue
# get(group_col)fast
#       0.0001889656
#
# $`chow_fast-SC__32`$coef
# get(group_col)fast
#         -0.1277611
#
#
# $`chow_fast-SC__33`
# $`chow_fast-SC__33`$pvalue
# get(group_col)fast
#          0.8017167
#
# $`chow_fast-SC__33`$coef
# get(group_col)fast
#        -0.01567803
#
#
# $`chow_fast-SC__34`
# $`chow_fast-SC__34`$pvalue
# get(group_col)fast
#          0.1904354
#
# $`chow_fast-SC__34`$coef
# get(group_col)fast
#         0.06017014
#
#
# $`chow_fast-SC__35`
# $`chow_fast-SC__35`$pvalue
# get(group_col)fast
#          0.3085999
#
# $`chow_fast-SC__35`$coef
# get(group_col)fast
#         0.03908078
#
#
# $`chow_fast-SC__36`
# $`chow_fast-SC__36`$pvalue
# get(group_col)fast
#          0.3682181
#
# $`chow_fast-SC__36`$coef
# get(group_col)fast
#          0.0111734
#
#
# $`chow_fast-SC__37`
# $`chow_fast-SC__37`$pvalue
# get(group_col)fast
#          0.2102488
#
# $`chow_fast-SC__37`$coef
# get(group_col)fast
#         0.01622427
#
#
# $`chow_fast-SC__38`
# $`chow_fast-SC__38`$pvalue
# get(group_col)fast
#          0.9190393
#
# $`chow_fast-SC__38`$coef
# get(group_col)fast
#         0.00603215
#
#
# $`chow_fast-SC__39`
# $`chow_fast-SC__39`$pvalue
# get(group_col)fast
#          0.9105515
#
# $`chow_fast-SC__39`$coef
# get(group_col)fast
#        0.001958631
#
#
# $`chow_fast-SC__40`
# $`chow_fast-SC__40`$pvalue
# get(group_col)fast
#          0.9114403
#
# $`chow_fast-SC__40`$coef
# get(group_col)fast
#        0.001983856
#
#
# $`chow_fast-SC__41`
# $`chow_fast-SC__41`$pvalue
# get(group_col)fast
#          0.9405626
#
# $`chow_fast-SC__41`$coef
# get(group_col)fast
#        0.001648082
#
#
# $`chow_fast-SC__42`
# $`chow_fast-SC__42`$pvalue
# get(group_col)fast
#          0.6356385
#
# $`chow_fast-SC__42`$coef
# get(group_col)fast
#        -0.02667847
#
#
# $`chow_fast-SC__43`
# $`chow_fast-SC__43`$pvalue
# get(group_col)fast
#          0.3352865
#
# $`chow_fast-SC__43`$coef
# get(group_col)fast
#         0.06290984
#
#
# $`chow_fast-SC__44`
# $`chow_fast-SC__44`$pvalue
# get(group_col)fast
#           0.773862
#
# $`chow_fast-SC__44`$coef
# get(group_col)fast
#        -0.01423113
#
#
# $`chow_fast-SC__45`
# $`chow_fast-SC__45`$pvalue
# get(group_col)fast
#         0.03095039
#
# $`chow_fast-SC__45`$coef
# get(group_col)fast
#         0.02864743
#
#
# $`chow_fast-SC__46`
# $`chow_fast-SC__46`$pvalue
# get(group_col)fast
#          0.4669534
#
# $`chow_fast-SC__46`$coef
# get(group_col)fast
#       -0.009229609
#
#
# $`chow_fast-SC__47`
# $`chow_fast-SC__47`$pvalue
# get(group_col)fast
#          0.9752765
#
# $`chow_fast-SC__47`$coef
# get(group_col)fast
#      -0.0006334617
#
#
# $`chow_fast-SC__48`
# $`chow_fast-SC__48`$pvalue
# get(group_col)fast
#          0.7461151
#
# $`chow_fast-SC__48`$coef
# get(group_col)fast
#           -0.01299
#
#
# $`chow_fast-SC__49`
# $`chow_fast-SC__49`$pvalue
# get(group_col)fast
#          0.5794893
#
# $`chow_fast-SC__49`$coef
# get(group_col)fast
#         0.02686274
#
#
# $`chow_fast-SC__50`
# $`chow_fast-SC__50`$pvalue
# get(group_col)fast
#          0.3893298
#
# $`chow_fast-SC__50`$coef
# get(group_col)fast
#         0.01811466
#
#
# $`chow_fast-SC__51`
# $`chow_fast-SC__51`$pvalue
# get(group_col)fast
#         0.08062661
#
# $`chow_fast-SC__51`$coef
# get(group_col)fast
#         -0.1332533
#
#
# $`chow_fast-SC__52`
# $`chow_fast-SC__52`$pvalue
# get(group_col)fast
#         0.07300341
#
# $`chow_fast-SC__52`$coef
# get(group_col)fast
#         0.07521108
#
#
# $`chow_fast-SC__53`
# $`chow_fast-SC__53`$pvalue
# get(group_col)fast
#          0.6878435
#
# $`chow_fast-SC__53`$coef
# get(group_col)fast
#         0.01261814
#
#
# $`chow_fast-SC__54`
# $`chow_fast-SC__54`$pvalue
# get(group_col)fast
#           0.275343
#
# $`chow_fast-SC__54`$coef
# get(group_col)fast
#          0.0100779
#
#
# $`chow_fast-SC__55`
# $`chow_fast-SC__55`$pvalue
# get(group_col)fast
#          0.5754751
#
# $`chow_fast-SC__55`$coef
# get(group_col)fast
#       -0.009833763
#
#
# $`chow_fast-SC__56`
# $`chow_fast-SC__56`$pvalue
# get(group_col)fast
#          0.7541632
#
# $`chow_fast-SC__56`$coef
# get(group_col)fast
#       -0.005119496
#
#
# $`chow_fast-SC__57`
# $`chow_fast-SC__57`$pvalue
# get(group_col)fast
#          0.6949099
#
# $`chow_fast-SC__57`$coef
# get(group_col)fast
#       -0.007046917
#
#
# $`chow_fast-SC__58`
# $`chow_fast-SC__58`$pvalue
# get(group_col)fast
#          0.4458016
#
# $`chow_fast-SC__58`$coef
# get(group_col)fast
#       -0.003330503
#
#
# $`chow_fast-SC__59`
# $`chow_fast-SC__59`$pvalue
# get(group_col)fast
#          0.7025117
#
# $`chow_fast-SC__59`$coef
# get(group_col)fast
#         -0.0118189
#
#
# $`chow_fast-SC__60`
# $`chow_fast-SC__60`$pvalue
# get(group_col)fast
#         0.03875003
#
# $`chow_fast-SC__60`$coef
# get(group_col)fast
#         0.04754333
#
#
# $`chow_fast-SC__61`
# $`chow_fast-SC__61`$pvalue
# get(group_col)fast
#           0.337351
#
# $`chow_fast-SC__61`$coef
# get(group_col)fast
#         0.04638807
#
#
# $`chow_fast-SC__62`
# $`chow_fast-SC__62`$pvalue
# get(group_col)fast
#          0.4660407
#
# $`chow_fast-SC__62`$coef
# get(group_col)fast
#        -0.03301844
#
#
# $`chow_fast-SC__63`
# $`chow_fast-SC__63`$pvalue
# get(group_col)fast
#          0.6700356
#
# $`chow_fast-SC__63`$coef
# get(group_col)fast
#         0.03287062
#
#
# $`chow_fast-SC__64`
# $`chow_fast-SC__64`$pvalue
# get(group_col)fast
#          0.8804218
#
# $`chow_fast-SC__64`$coef
# get(group_col)fast
#       -0.004858879
#
#
# $`chow_fast-SC__65`
# $`chow_fast-SC__65`$pvalue
# get(group_col)fast
#          0.4830897
#
# $`chow_fast-SC__65`$coef
# get(group_col)fast
#        -0.02589704
#
#
# $`chow_fast-SC__66`
# $`chow_fast-SC__66`$pvalue
# get(group_col)fast
#           0.523011
#
# $`chow_fast-SC__66`$coef
# get(group_col)fast
#         0.01735611
#
#
# $`chow_fast-SC__67`
# $`chow_fast-SC__67`$pvalue
# get(group_col)fast
#        0.003957168
#
# $`chow_fast-SC__67`$coef
# get(group_col)fast
#          0.0867883
#
#
# $`chow_fast-SC__68`
# $`chow_fast-SC__68`$pvalue
# get(group_col)fast
#          0.1572378
#
# $`chow_fast-SC__68`$coef
# get(group_col)fast
#        -0.03689241
#
#
# $`chow_fast-SC__69`
# $`chow_fast-SC__69`$pvalue
# get(group_col)fast
#          0.7428909
#
# $`chow_fast-SC__69`$coef
# get(group_col)fast
#        0.009457657
#
#
# $`chow_fast-SC__70`
# $`chow_fast-SC__70`$pvalue
# get(group_col)fast
#          0.7239009
#
# $`chow_fast-SC__70`$coef
# get(group_col)fast
#          0.0183092
#
#
# $`chow_fast-SC__71`
# $`chow_fast-SC__71`$pvalue
# get(group_col)fast
#          0.1970475
#
# $`chow_fast-SC__71`$coef
# get(group_col)fast
#        -0.06340498
#
#
# $`chow_fast-SC__72`
# $`chow_fast-SC__72`$pvalue
# get(group_col)fast
#            0.26814
#
# $`chow_fast-SC__72`$coef
# get(group_col)fast
#         0.01556574
#
#
# $`chow_fast-SC__73`
# $`chow_fast-SC__73`$pvalue
# get(group_col)fast
#          0.5103914
#
# $`chow_fast-SC__73`$coef
# get(group_col)fast
#        -0.01626077
#
#
# $`chow_fast-SC__74`
# $`chow_fast-SC__74`$pvalue
# get(group_col)fast
#          0.9277983
#
# $`chow_fast-SC__74`$coef
# get(group_col)fast
#       -0.002094173
#
#
# $`chow_fast-SC__75`
# $`chow_fast-SC__75`$pvalue
# get(group_col)fast
#          0.6718681
#
# $`chow_fast-SC__75`$coef
# get(group_col)fast
#        0.009537407
#
#
# $`chow_fast-SC__76`
# $`chow_fast-SC__76`$pvalue
# get(group_col)fast
#          0.0972722
#
# $`chow_fast-SC__76`$coef
# get(group_col)fast
#         -0.1160704
#
#
# $`chow_fast-SC__77`
# $`chow_fast-SC__77`$pvalue
# get(group_col)fast
#          0.2098917
#
# $`chow_fast-SC__77`$coef
# get(group_col)fast
#        -0.01199802
#
#
# $`chow_fast-SC__78`
# $`chow_fast-SC__78`$pvalue
# get(group_col)fast
#       0.0001588508
#
# $`chow_fast-SC__78`$coef
# get(group_col)fast
#          0.1274073
#
#
# $`chow_fast-SC__79`
# $`chow_fast-SC__79`$pvalue
# get(group_col)fast
#          0.5659539
#
# $`chow_fast-SC__79`$coef
# get(group_col)fast
#        -0.01309599
#
#
# $`chow_fast-SC__80`
# $`chow_fast-SC__80`$pvalue
# get(group_col)fast
#          0.1209378
#
# $`chow_fast-SC__80`$coef
# get(group_col)fast
#        -0.09387516
#
#
# $`chow_fast-SC__81`
# $`chow_fast-SC__81`$pvalue
# get(group_col)fast
#          0.5135755
#
# $`chow_fast-SC__81`$coef
# get(group_col)fast
#        -0.02491346
#
#
# $`chow_fast-SC__82`
# $`chow_fast-SC__82`$pvalue
# get(group_col)fast
#          0.9775025
#
# $`chow_fast-SC__82`$coef
# get(group_col)fast
#       0.0007316214
#
#
# $`chow_fast-SC__83`
# $`chow_fast-SC__83`$pvalue
# get(group_col)fast
#          0.2785729
#
# $`chow_fast-SC__83`$coef
# get(group_col)fast
#         0.07669395
#
#
# $`chow_fast-SC__84`
# $`chow_fast-SC__84`$pvalue
# get(group_col)fast
#          0.4254429
#
# $`chow_fast-SC__84`$coef
# get(group_col)fast
#        -0.03916783
#
#
# $`chow_fast-SC__85`
# $`chow_fast-SC__85`$pvalue
# get(group_col)fast
#         0.09783013
#
# $`chow_fast-SC__85`$coef
# get(group_col)fast
#         0.01489483
#
#
# $`chow_fast-SC__86`
# $`chow_fast-SC__86`$pvalue
# get(group_col)fast
#          0.1561827
#
# $`chow_fast-SC__86`$coef
# get(group_col)fast
#         0.09537793
#
#
# $`chow_fast-SC__87`
# $`chow_fast-SC__87`$pvalue
# get(group_col)fast
#          0.4279488
#
# $`chow_fast-SC__87`$coef
# get(group_col)fast
#         0.02814636
#
#
# $`chow_fast-SC__88`
# $`chow_fast-SC__88`$pvalue
# get(group_col)fast
#          0.3042291
#
# $`chow_fast-SC__88`$coef
# get(group_col)fast
#         -0.0669851
#
#
# $`chow_fast-SC__89`
# $`chow_fast-SC__89`$pvalue
# get(group_col)fast
#          0.5211226
#
# $`chow_fast-SC__89`$coef
# get(group_col)fast
#         0.03392559
#
#
# $`chow_fast-SC__90`
# $`chow_fast-SC__90`$pvalue
# get(group_col)fast
#         0.06266441
#
# $`chow_fast-SC__90`$coef
# get(group_col)fast
#         -0.1042469
#
#
# $`chow_fast-SC__91`
# $`chow_fast-SC__91`$pvalue
# get(group_col)fast
#          0.9047406
#
# $`chow_fast-SC__91`$coef
# get(group_col)fast
#       -0.003151775
#
#
# $`chow_fast-SC__92`
# $`chow_fast-SC__92`$pvalue
# get(group_col)fast
#          0.2624223
#
# $`chow_fast-SC__92`$coef
# get(group_col)fast
#         0.03559865
#
#
# $`chow_HFD-HPF__01`
# $`chow_HFD-HPF__01`$pvalue
# get(group_col)HFD
#         0.8452925
#
# $`chow_HFD-HPF__01`$coef
# get(group_col)HFD
#       -0.00942889
#
#
# $`chow_HFD-HPF__02`
# $`chow_HFD-HPF__02`$pvalue
# get(group_col)HFD
#          0.994865
#
# $`chow_HFD-HPF__02`$coef
# get(group_col)HFD
#     -0.0005670502
#
#
# $`chow_HFD-HPF__03`
# $`chow_HFD-HPF__03`$pvalue
# get(group_col)HFD
#         0.8102671
#
# $`chow_HFD-HPF__03`$coef
# get(group_col)HFD
#       -0.01117116
#
#
# $`chow_HFD-HPF__04`
# $`chow_HFD-HPF__04`$pvalue
# get(group_col)HFD
#         0.5521405
#
# $`chow_HFD-HPF__04`$coef
# get(group_col)HFD
#       -0.03352485
#
#
# $`chow_HFD-HPF__05`
# $`chow_HFD-HPF__05`$pvalue
# get(group_col)HFD
#       0.002018092
#
# $`chow_HFD-HPF__05`$coef
# get(group_col)HFD
#        -0.1236181
#
#
# $`chow_HFD-HPF__06`
# $`chow_HFD-HPF__06`$pvalue
# get(group_col)HFD
#         0.4394343
#
# $`chow_HFD-HPF__06`$coef
# get(group_col)HFD
#        0.03658356
#
#
# $`chow_HFD-HPF__07`
# $`chow_HFD-HPF__07`$pvalue
# get(group_col)HFD
#         0.7210605
#
# $`chow_HFD-HPF__07`$coef
# get(group_col)HFD
#       -0.01321865
#
#
# $`chow_HFD-HPF__08`
# $`chow_HFD-HPF__08`$pvalue
# get(group_col)HFD
#         0.2406574
#
# $`chow_HFD-HPF__08`$coef
# get(group_col)HFD
#        -0.1173893
#
#
# $`chow_HFD-HPF__09`
# $`chow_HFD-HPF__09`$pvalue
# get(group_col)HFD
#         0.8635982
#
# $`chow_HFD-HPF__09`$coef
# get(group_col)HFD
#      -0.008127961
#
#
# $`chow_HFD-HPF__10`
# $`chow_HFD-HPF__10`$pvalue
# get(group_col)HFD
#         0.3188898
#
# $`chow_HFD-HPF__10`$coef
# get(group_col)HFD
#        -0.1150548
#
#
# $`chow_HFD-HPF__11`
# $`chow_HFD-HPF__11`$pvalue
# get(group_col)HFD
#       0.009650647
#
# $`chow_HFD-HPF__11`$coef
# get(group_col)HFD
#         0.0942344
#
#
# $`chow_HFD-HPF__12`
# $`chow_HFD-HPF__12`$pvalue
# get(group_col)HFD
#         0.8784016
#
# $`chow_HFD-HPF__12`$coef
# get(group_col)HFD
#      -0.007407445
#
#
# $`chow_HFD-HPF__13`
# $`chow_HFD-HPF__13`$pvalue
# get(group_col)HFD
#         0.3152812
#
# $`chow_HFD-HPF__13`$coef
# get(group_col)HFD
#       -0.02111006
#
#
# $`chow_HFD-HPF__14`
# $`chow_HFD-HPF__14`$pvalue
# get(group_col)HFD
#         0.3819081
#
# $`chow_HFD-HPF__14`$coef
# get(group_col)HFD
#        0.07443903
#
#
# $`chow_HFD-HPF__15`
# $`chow_HFD-HPF__15`$pvalue
# get(group_col)HFD
#         0.3959468
#
# $`chow_HFD-HPF__15`$coef
# get(group_col)HFD
#        0.04516724
#
#
# $`chow_HFD-HPF__16`
# $`chow_HFD-HPF__16`$pvalue
# get(group_col)HFD
#          0.417337
#
# $`chow_HFD-HPF__16`$coef
# get(group_col)HFD
#       -0.04517021
#
#
# $`chow_HFD-HPF__17`
# $`chow_HFD-HPF__17`$pvalue
# get(group_col)HFD
#      0.0008164698
#
# $`chow_HFD-HPF__17`$coef
# get(group_col)HFD
#       -0.03989605
#
#
# $`chow_HFD-HPF__18`
# $`chow_HFD-HPF__18`$pvalue
# get(group_col)HFD
#         0.8413783
#
# $`chow_HFD-HPF__18`$coef
# get(group_col)HFD
#       -0.01876807
#
#
# $`chow_HFD-HPF__19`
# $`chow_HFD-HPF__19`$pvalue
# get(group_col)HFD
#         0.6666802
#
# $`chow_HFD-HPF__19`$coef
# get(group_col)HFD
#       0.008135806
#
#
# $`chow_HFD-HPF__20`
# $`chow_HFD-HPF__20`$pvalue
# get(group_col)HFD
#       0.004848487
#
# $`chow_HFD-HPF__20`$coef
# get(group_col)HFD
#        0.07164293
#
#
# $`chow_HFD-HPF__21`
# $`chow_HFD-HPF__21`$pvalue
# get(group_col)HFD
#         0.8739871
#
# $`chow_HFD-HPF__21`$coef
# get(group_col)HFD
#       0.006096713
#
#
# $`chow_HFD-HPF__22`
# $`chow_HFD-HPF__22`$pvalue
# get(group_col)HFD
#         0.7092636
#
# $`chow_HFD-HPF__22`$coef
# get(group_col)HFD
#         0.0241631
#
#
# $`chow_HFD-HPF__23`
# $`chow_HFD-HPF__23`$pvalue
# get(group_col)HFD
#         0.9707867
#
# $`chow_HFD-HPF__23`$coef
# get(group_col)HFD
#      -0.003328063
#
#
# $`chow_HFD-HPF__24`
# $`chow_HFD-HPF__24`$pvalue
# get(group_col)HFD
#        0.01500191
#
# $`chow_HFD-HPF__24`$coef
# get(group_col)HFD
#        0.07527915
#
#
# $`chow_HFD-HPF__25`
# $`chow_HFD-HPF__25`$pvalue
# get(group_col)HFD
#        0.05836302
#
# $`chow_HFD-HPF__25`$coef
# get(group_col)HFD
#       -0.06682325
#
#
# $`chow_HFD-HPF__26`
# $`chow_HFD-HPF__26`$pvalue
# get(group_col)HFD
#       0.005012552
#
# $`chow_HFD-HPF__26`$coef
# get(group_col)HFD
#       -0.09576957
#
#
# $`chow_HFD-HPF__27`
# $`chow_HFD-HPF__27`$pvalue
# get(group_col)HFD
#        0.02193783
#
# $`chow_HFD-HPF__27`$coef
# get(group_col)HFD
#         -0.106424
#
#
# $`chow_HFD-HPF__28`
# $`chow_HFD-HPF__28`$pvalue
# get(group_col)HFD
#          0.915687
#
# $`chow_HFD-HPF__28`$coef
# get(group_col)HFD
#       0.005151252
#
#
# $`chow_HFD-HPF__29`
# $`chow_HFD-HPF__29`$pvalue
# get(group_col)HFD
#         0.6688686
#
# $`chow_HFD-HPF__29`$coef
# get(group_col)HFD
#       -0.02518057
#
#
# $`chow_HFD-HPF__30`
# $`chow_HFD-HPF__30`$pvalue
# get(group_col)HFD
#        0.06404966
#
# $`chow_HFD-HPF__30`$coef
# get(group_col)HFD
#       -0.03240629
#
#
# $`chow_HFD-HPF__31`
# $`chow_HFD-HPF__31`$pvalue
# get(group_col)HFD
#         0.4822313
#
# $`chow_HFD-HPF__31`$coef
# get(group_col)HFD
#        0.03336947
#
#
# $`chow_HFD-HPF__32`
# $`chow_HFD-HPF__32`$pvalue
# get(group_col)HFD
#        0.01520251
#
# $`chow_HFD-HPF__32`$coef
# get(group_col)HFD
#        0.06501477
#
#
# $`chow_HFD-HPF__33`
# $`chow_HFD-HPF__33`$pvalue
# get(group_col)HFD
#       0.006827636
#
# $`chow_HFD-HPF__33`$coef
# get(group_col)HFD
#       -0.08177073
#
#
# $`chow_HFD-HPF__34`
# $`chow_HFD-HPF__34`$pvalue
# get(group_col)HFD
#         0.6134957
#
# $`chow_HFD-HPF__34`$coef
# get(group_col)HFD
#        0.02285314
#
#
# $`chow_HFD-HPF__35`
# $`chow_HFD-HPF__35`$pvalue
# get(group_col)HFD
#         0.2555591
#
# $`chow_HFD-HPF__35`$coef
# get(group_col)HFD
#        -0.1047757
#
#
# $`chow_HFD-HPF__36`
# $`chow_HFD-HPF__36`$pvalue
# get(group_col)HFD
#         0.6888179
#
# $`chow_HFD-HPF__36`$coef
# get(group_col)HFD
#       0.005904342
#
#
# $`chow_HFD-HPF__37`
# $`chow_HFD-HPF__37`$pvalue
# get(group_col)HFD
#         0.4206245
#
# $`chow_HFD-HPF__37`$coef
# get(group_col)HFD
#       -0.06094408
#
#
# $`chow_HFD-HPF__38`
# $`chow_HFD-HPF__38`$pvalue
# get(group_col)HFD
#       0.003094419
#
# $`chow_HFD-HPF__38`$coef
# get(group_col)HFD
#        0.09316462
#
#
# $`chow_HFD-HY__01`
# $`chow_HFD-HY__01`$pvalue
# get(group_col)HFD
#         0.6739896
#
# $`chow_HFD-HY__01`$coef
# get(group_col)HFD
#        -0.0216693
#
#
# $`chow_HFD-HY__02`
# $`chow_HFD-HY__02`$pvalue
# get(group_col)HFD
#         0.9639267
#
# $`chow_HFD-HY__02`$coef
# get(group_col)HFD
#     -0.0001856015
#
#
# $`chow_HFD-HY__03`
# $`chow_HFD-HY__03`$pvalue
# get(group_col)HFD
#          0.243239
#
# $`chow_HFD-HY__03`$coef
# get(group_col)HFD
#       -0.03003629
#
#
# $`chow_HFD-HY__04`
# $`chow_HFD-HY__04`$pvalue
# get(group_col)HFD
#         0.8668331
#
# $`chow_HFD-HY__04`$coef
# get(group_col)HFD
#       0.001967645
#
#
# $`chow_HFD-HY__05`
# $`chow_HFD-HY__05`$pvalue
# get(group_col)HFD
#        0.03400616
#
# $`chow_HFD-HY__05`$coef
# get(group_col)HFD
#        0.08976408
#
#
# $`chow_HFD-HY__06`
# $`chow_HFD-HY__06`$pvalue
# get(group_col)HFD
#         0.6430772
#
# $`chow_HFD-HY__06`$coef
# get(group_col)HFD
#        0.03047896
#
#
# $`chow_HFD-HY__07`
# $`chow_HFD-HY__07`$pvalue
# get(group_col)HFD
#         0.5191271
#
# $`chow_HFD-HY__07`$coef
# get(group_col)HFD
#      -0.009244748
#
#
# $`chow_HFD-HY__08`
# $`chow_HFD-HY__08`$pvalue
# get(group_col)HFD
#          0.661273
#
# $`chow_HFD-HY__08`$coef
# get(group_col)HFD
#       0.009937971
#
#
# $`chow_HFD-HY__09`
# $`chow_HFD-HY__09`$pvalue
# get(group_col)HFD
#          0.283334
#
# $`chow_HFD-HY__09`$coef
# get(group_col)HFD
#        0.05841956
#
#
# $`chow_HFD-HY__10`
# $`chow_HFD-HY__10`$pvalue
# get(group_col)HFD
#         0.5408919
#
# $`chow_HFD-HY__10`$coef
# get(group_col)HFD
#        0.00888001
#
#
# $`chow_HFD-HY__11`
# $`chow_HFD-HY__11`$pvalue
# get(group_col)HFD
#         0.9682002
#
# $`chow_HFD-HY__11`$coef
# get(group_col)HFD
#      -0.003923216
#
#
# $`chow_HFD-HY__12`
# $`chow_HFD-HY__12`$pvalue
# get(group_col)HFD
#         0.4977946
#
# $`chow_HFD-HY__12`$coef
# get(group_col)HFD
#      -0.005253291
#
#
# $`chow_HFD-HY__13`
# $`chow_HFD-HY__13`$pvalue
# get(group_col)HFD
#         0.6941024
#
# $`chow_HFD-HY__13`$coef
# get(group_col)HFD
#       -0.03389063
#
#
# $`chow_HFD-HY__14`
# $`chow_HFD-HY__14`$pvalue
# get(group_col)HFD
#         0.7381165
#
# $`chow_HFD-HY__14`$coef
# get(group_col)HFD
#       -0.03522883
#
#
# $`chow_HFD-HY__15`
# $`chow_HFD-HY__15`$pvalue
# get(group_col)HFD
#         0.0888808
#
# $`chow_HFD-HY__15`$coef
# get(group_col)HFD
#         0.1073067
#
#
# $`chow_HFD-HY__16`
# $`chow_HFD-HY__16`$pvalue
# get(group_col)HFD
#         0.9545904
#
# $`chow_HFD-HY__16`$coef
# get(group_col)HFD
#       0.004801549
#
#
# $`chow_HFD-HY__17`
# $`chow_HFD-HY__17`$pvalue
# get(group_col)HFD
#         0.2646069
#
# ...
#
#
# $`chow_HFD-IC__32`
# $`chow_HFD-IC__32`$pvalue
# get(group_col)HFD
#         0.7391088
#
# $`chow_HFD-IC__32`$coef
# get(group_col)HFD
#       0.009710585
#
#
# $`chow_HFD-IC__33`
# $`chow_HFD-IC__33`$pvalue
# get(group_col)HFD
#       0.005833586
#
# $`chow_HFD-IC__33`$coef
# get(group_col)HFD
#       -0.04577813
#
#
# $`chow_HFD-IC__34`
# $`chow_HFD-IC__34`$pvalue
# get(group_col)HFD
#         0.9620349
#
# $`chow_HFD-IC__34`$coef
# get(group_col)HFD
#       0.002999384
#
#
# $`chow_HFD-IC__35`
# $`chow_HFD-IC__35`$pvalue
# get(group_col)HFD
#         0.9747901
#
# $`chow_HFD-IC__35`$coef
# get(group_col)HFD
#      0.0005750013
#
#
# $`chow_HFD-IC__36`
# $`chow_HFD-IC__36`$pvalue
# get(group_col)HFD
#         0.6770372
#
# $`chow_HFD-IC__36`$coef
# get(group_col)HFD
#       -0.01232241
#
#
# $`chow_HFD-IC__37`
# $`chow_HFD-IC__37`$pvalue
# get(group_col)HFD
#         0.1195846
#
# $`chow_HFD-IC__37`$coef
# get(group_col)HFD
#       -0.08944249
#
#
# $`chow_HFD-IC__38`
# $`chow_HFD-IC__38`$pvalue
# get(group_col)HFD
#         0.6592987
#
# $`chow_HFD-IC__38`$coef
# get(group_col)HFD
#       -0.01849904
#
#
# $`chow_HFD-IC__39`
# $`chow_HFD-IC__39`$pvalue
# get(group_col)HFD
#         0.4282871
#
# $`chow_HFD-IC__39`$coef
# get(group_col)HFD
#       -0.01279207
#
#
# $`chow_HFD-IC__40`
# $`chow_HFD-IC__40`$pvalue
# get(group_col)HFD
#         0.2926633
#
# $`chow_HFD-IC__40`$coef
# get(group_col)HFD
#       -0.06102277
#
#
# $`chow_HFD-IC__41`
# $`chow_HFD-IC__41`$pvalue
# get(group_col)HFD
#         0.4859725
#
# $`chow_HFD-IC__41`$coef
# get(group_col)HFD
#        0.04041876
#
#
# $`chow_HFD-IC__42`
# $`chow_HFD-IC__42`$pvalue
# get(group_col)HFD
#          0.991962
#
# $`chow_HFD-IC__42`$coef
# get(group_col)HFD
#      0.0007446563
#
#
# $`chow_HFD-IC__43`
# $`chow_HFD-IC__43`$pvalue
# get(group_col)HFD
#         0.5023889
#
# $`chow_HFD-IC__43`$coef
# get(group_col)HFD
#        -0.0249842
#
#
# $`chow_HFD-IC__44`
# $`chow_HFD-IC__44`$pvalue
# get(group_col)HFD
#         0.4878451
#
# $`chow_HFD-IC__44`$coef
# get(group_col)HFD
#       -0.03135948
#
#
# $`chow_HFD-IC__45`
# $`chow_HFD-IC__45`$pvalue
# get(group_col)HFD
#         0.2288261
#
# $`chow_HFD-IC__45`$coef
# get(group_col)HFD
#       -0.05036774
#
#
# $`chow_HFD-IC__46`
# $`chow_HFD-IC__46`$pvalue
# get(group_col)HFD
#         0.1133729
#
# $`chow_HFD-IC__46`$coef
# get(group_col)HFD
#       -0.07992411
#
#
# $`chow_HFD-IC__47`
# $`chow_HFD-IC__47`$pvalue
# get(group_col)HFD
#        0.06151566
#
# $`chow_HFD-IC__47`$coef
# get(group_col)HFD
#       -0.08546393
#
#
# $`chow_HFD-SC__01`
# $`chow_HFD-SC__01`$pvalue
# get(group_col)HFD
#          0.338174
#
# $`chow_HFD-SC__01`$coef
# get(group_col)HFD
#        0.05581124
#
#
# $`chow_HFD-SC__02`
# $`chow_HFD-SC__02`$pvalue
# get(group_col)HFD
#         0.1782709
#
# $`chow_HFD-SC__02`$coef
# get(group_col)HFD
#        0.09216485
#
#
# $`chow_HFD-SC__03`
# $`chow_HFD-SC__03`$pvalue
# get(group_col)HFD
#         0.9163224
#
# $`chow_HFD-SC__03`$coef
# get(group_col)HFD
#      0.0008793786
#
#
# $`chow_HFD-SC__04`
# $`chow_HFD-SC__04`$pvalue
# get(group_col)HFD
#         0.8017181
#
# $`chow_HFD-SC__04`$coef
# get(group_col)HFD
#       -0.01764887
#
#
# $`chow_HFD-SC__05`
# $`chow_HFD-SC__05`$pvalue
# get(group_col)HFD
#         0.1346038
#
# $`chow_HFD-SC__05`$coef
# get(group_col)HFD
#        0.07915867
#
#
# $`chow_HFD-SC__06`
# $`chow_HFD-SC__06`$pvalue
# get(group_col)HFD
#         0.2147111
#
# $`chow_HFD-SC__06`$coef
# get(group_col)HFD
#        0.01276351
#
#
# $`chow_HFD-SC__07`
# $`chow_HFD-SC__07`$pvalue
# get(group_col)HFD
#         0.3178659
#
# $`chow_HFD-SC__07`$coef
# get(group_col)HFD
#        0.02759158
#
#
# $`chow_HFD-SC__08`
# $`chow_HFD-SC__08`$pvalue
# get(group_col)HFD
#         0.1512531
#
# $`chow_HFD-SC__08`$coef
# get(group_col)HFD
#        0.04549362
#
#
# $`chow_HFD-SC__09`
# $`chow_HFD-SC__09`$pvalue
# get(group_col)HFD
#         0.3868913
#
# $`chow_HFD-SC__09`$coef
# get(group_col)HFD
#        0.07922025
#
#
# $`chow_HFD-SC__10`
# $`chow_HFD-SC__10`$pvalue
# get(group_col)HFD
#         0.2422247
#
# $`chow_HFD-SC__10`$coef
# get(group_col)HFD
#       -0.08679492
#
#
# $`chow_HFD-SC__11`
# $`chow_HFD-SC__11`$pvalue
# get(group_col)HFD
#         0.1123523
#
# $`chow_HFD-SC__11`$coef
# get(group_col)HFD
#         0.1333783
#
#
# $`chow_HFD-SC__12`
# $`chow_HFD-SC__12`$pvalue
# get(group_col)HFD
#         0.4026201
#
# $`chow_HFD-SC__12`$coef
# get(group_col)HFD
#       -0.03981326
#
#
# $`chow_HFD-SC__13`
# $`chow_HFD-SC__13`$pvalue
# get(group_col)HFD
#         0.7599696
#
# $`chow_HFD-SC__13`$coef
# get(group_col)HFD
#        0.01383809
#
#
# $`chow_HFD-SC__14`
# $`chow_HFD-SC__14`$pvalue
# get(group_col)HFD
#         0.5141708
#
# $`chow_HFD-SC__14`$coef
# get(group_col)HFD
#        0.05438672
#
#
# $`chow_HFD-SC__15`
# $`chow_HFD-SC__15`$pvalue
# get(group_col)HFD
#        0.03673438
#
# $`chow_HFD-SC__15`$coef
# get(group_col)HFD
#         0.1030393
#
#
# $`chow_HFD-SC__16`
# $`chow_HFD-SC__16`$pvalue
# get(group_col)HFD
#         0.6741252
#
# $`chow_HFD-SC__16`$coef
# get(group_col)HFD
#        -0.0373176
#
#
# $`chow_HFD-SC__17`
# $`chow_HFD-SC__17`$pvalue
# get(group_col)HFD
#         0.7123905
#
# $`chow_HFD-SC__17`$coef
# get(group_col)HFD
#       -0.03097691
#
#
# $`chow_HFD-SC__18`
# $`chow_HFD-SC__18`$pvalue
# get(group_col)HFD
#         0.5006256
#
# $`chow_HFD-SC__18`$coef
# get(group_col)HFD
#         0.0222981
#
#
# $`chow_HFD-SC__19`
# $`chow_HFD-SC__19`$pvalue
# get(group_col)HFD
#         0.1844846
#
# $`chow_HFD-SC__19`$coef
# get(group_col)HFD
#       -0.02945989
#
#
# $`chow_HFD-SC__20`
# $`chow_HFD-SC__20`$pvalue
# get(group_col)HFD
#         0.8252056
#
# $`chow_HFD-SC__20`$coef
# get(group_col)HFD
#        0.01969694
#
#
# $`chow_HFD-SC__21`
# $`chow_HFD-SC__21`$pvalue
# get(group_col)HFD
#         0.1496935
#
# $`chow_HFD-SC__21`$coef
# get(group_col)HFD
#       -0.02247777
#
#
# $`chow_HFD-SC__22`
# $`chow_HFD-SC__22`$pvalue
# get(group_col)HFD
#         0.6135279
#
# $`chow_HFD-SC__22`$coef
# get(group_col)HFD
#       -0.04200591
#
#
# $`chow_HFD-SC__23`
# $`chow_HFD-SC__23`$pvalue
# get(group_col)HFD
#         0.5230419
#
# $`chow_HFD-SC__23`$coef
# get(group_col)HFD
#          0.010172
#
#
# $`chow_HFD-SC__24`
# $`chow_HFD-SC__24`$pvalue
# get(group_col)HFD
#         0.7562381
#
# $`chow_HFD-SC__24`$coef
# get(group_col)HFD
#        0.01314043
#
#
# $`chow_HFD-SC__25`
# $`chow_HFD-SC__25`$pvalue
# get(group_col)HFD
#         0.6224715
#
# $`chow_HFD-SC__25`$coef
# get(group_col)HFD
#        -0.0365561
#
#
# $`chow_HFD-SC__26`
# $`chow_HFD-SC__26`$pvalue
# get(group_col)HFD
#         0.8246485
#
# $`chow_HFD-SC__26`$coef
# get(group_col)HFD
#       -0.02036358
#
#
# $`chow_HFD-SC__27`
# $`chow_HFD-SC__27`$pvalue
# get(group_col)HFD
#         0.3263425
#
# $`chow_HFD-SC__27`$coef
# get(group_col)HFD
#       -0.01189822
#
#
# $`chow_HFD-SC__28`
# $`chow_HFD-SC__28`$pvalue
# get(group_col)HFD
#         0.1583895
#
# $`chow_HFD-SC__28`$coef
# get(group_col)HFD
#        -0.1433696
#
#
# $`chow_HFD-SC__29`
# $`chow_HFD-SC__29`$pvalue
# get(group_col)HFD
#         0.4867236
#
# $`chow_HFD-SC__29`$coef
# get(group_col)HFD
#        0.06467503
#
#
# $`chow_HFD-SC__30`
# $`chow_HFD-SC__30`$pvalue
# get(group_col)HFD
#        0.09369176
#
# $`chow_HFD-SC__30`$coef
# get(group_col)HFD
#       -0.04796463
#
#
# $`chow_HFD-SC__31`
# $`chow_HFD-SC__31`$pvalue
# get(group_col)HFD
#         0.9688067
#
# $`chow_HFD-SC__31`$coef
# get(group_col)HFD
#      -0.001627509
#
#
# $`chow_HFD-SC__32`
# $`chow_HFD-SC__32`$pvalue
# get(group_col)HFD
#         0.5962812
#
# $`chow_HFD-SC__32`$coef
# get(group_col)HFD
#        0.01805525
#
#
# $`chow_HFD-SC__33`
# $`chow_HFD-SC__33`$pvalue
# get(group_col)HFD
#         0.5666137
#
# $`chow_HFD-SC__33`$coef
# get(group_col)HFD
#       -0.04094279
#
#
# $`chow_HFD-SC__34`
# $`chow_HFD-SC__34`$pvalue
# get(group_col)HFD
#         0.3347085
#
# $`chow_HFD-SC__34`$coef
# get(group_col)HFD
#        0.05163837
#
#
# $`chow_HFD-SC__35`
# $`chow_HFD-SC__35`$pvalue
# get(group_col)HFD
#         0.3030059
#
# $`chow_HFD-SC__35`$coef
# get(group_col)HFD
#        0.05619132
#
#
# $`chow_HFD-SC__36`
# $`chow_HFD-SC__36`$pvalue
# get(group_col)HFD
#         0.9528061
#
# $`chow_HFD-SC__36`$coef
# get(group_col)HFD
#      -0.001034829
#
#
# $`chow_HFD-SC__37`
# $`chow_HFD-SC__37`$pvalue
# get(group_col)HFD
#         0.1477772
#
# $`chow_HFD-SC__37`$coef
# get(group_col)HFD
#        -0.0334735
#
#
# $`chow_HFD-SC__38`
# $`chow_HFD-SC__38`$pvalue
# get(group_col)HFD
#         0.5557349
#
# $`chow_HFD-SC__38`$coef
# get(group_col)HFD
#       -0.04438534
#
#
# $`chow_HFD-SC__39`
# $`chow_HFD-SC__39`$pvalue
# get(group_col)HFD
#         0.8218849
#
# $`chow_HFD-SC__39`$coef
# get(group_col)HFD
#       0.006047438
#
#
# $`chow_HFD-SC__40`
# $`chow_HFD-SC__40`$pvalue
# get(group_col)HFD
#         0.5701041
#
# $`chow_HFD-SC__40`$coef
# get(group_col)HFD
#        -0.0112037
#
#
# $`chow_HFD-SC__41`
# $`chow_HFD-SC__41`$pvalue
# get(group_col)HFD
#         0.9352538
#
# $`chow_HFD-SC__41`$coef
# get(group_col)HFD
#      -0.002076067
#
#
# $`chow_HFD-SC__42`
# $`chow_HFD-SC__42`$pvalue
# get(group_col)HFD
#         0.8590884
#
# $`chow_HFD-SC__42`$coef
# get(group_col)HFD
#       -0.01315006
#
#
# $`chow_HFD-SC__43`
# $`chow_HFD-SC__43`$pvalue
# get(group_col)HFD
#         0.2084711
#
# $`chow_HFD-SC__43`$coef
# get(group_col)HFD
#        0.09612606
#
#
# $`chow_HFD-SC__44`
# $`chow_HFD-SC__44`$pvalue
# get(group_col)HFD
#         0.4601861
#
# $`chow_HFD-SC__44`$coef
# get(group_col)HFD
#       -0.02866333
#
#
# $`chow_HFD-SC__45`
# $`chow_HFD-SC__45`$pvalue
# get(group_col)HFD
#        0.03149028
#
# $`chow_HFD-SC__45`$coef
# get(group_col)HFD
#        0.03784771
#
#
# $`chow_HFD-SC__46`
# $`chow_HFD-SC__46`$pvalue
# get(group_col)HFD
#         0.9406793
#
# $`chow_HFD-SC__46`$coef
# get(group_col)HFD
#      0.0009250793
#
#
# $`chow_HFD-SC__47`
# $`chow_HFD-SC__47`$pvalue
# get(group_col)HFD
#         0.3962621
#
# $`chow_HFD-SC__47`$coef
# get(group_col)HFD
#        -0.0208279
#
#
# $`chow_HFD-SC__48`
# $`chow_HFD-SC__48`$pvalue
# get(group_col)HFD
#        0.09729595
#
# $`chow_HFD-SC__48`$coef
# get(group_col)HFD
#         0.1255604
#
#
# $`chow_HFD-SC__49`
# $`chow_HFD-SC__49`$pvalue
# get(group_col)HFD
#         0.6293046
#
# $`chow_HFD-SC__49`$coef
# get(group_col)HFD
#       -0.03212399
#
#
# $`chow_HFD-SC__50`
# $`chow_HFD-SC__50`$pvalue
# get(group_col)HFD
#         0.8568481
#
# $`chow_HFD-SC__50`$coef
# get(group_col)HFD
#        0.00507025
#
#
# $`chow_HFD-SC__51`
# $`chow_HFD-SC__51`$pvalue
# get(group_col)HFD
#         0.1119372
#
# $`chow_HFD-SC__51`$coef
# get(group_col)HFD
#        -0.1593642
#
#
# $`chow_HFD-SC__52`
# $`chow_HFD-SC__52`$pvalue
# get(group_col)HFD
#         0.8516031
#
# $`chow_HFD-SC__52`$coef
# get(group_col)HFD
#        0.01051419
#
#
# $`chow_HFD-SC__53`
# $`chow_HFD-SC__53`$pvalue
# get(group_col)HFD
#         0.1364204
#
# $`chow_HFD-SC__53`$coef
# get(group_col)HFD
#       -0.07118726
#
#
# $`chow_HFD-SC__54`
# $`chow_HFD-SC__54`$pvalue
# get(group_col)HFD
#         0.4981322
#
# $`chow_HFD-SC__54`$coef
# get(group_col)HFD
#      -0.007243316
#
#
# $`chow_HFD-SC__55`
# $`chow_HFD-SC__55`$pvalue
# get(group_col)HFD
#         0.9080702
#
# $`chow_HFD-SC__55`$coef
# get(group_col)HFD
#      -0.002701049
#
#
# $`chow_HFD-SC__56`
# $`chow_HFD-SC__56`$pvalue
# get(group_col)HFD
#         0.3788154
#
# $`chow_HFD-SC__56`$coef
# get(group_col)HFD
#       -0.01953118
#
#
# $`chow_HFD-SC__57`
# $`chow_HFD-SC__57`$pvalue
# get(group_col)HFD
#         0.5773916
#
# $`chow_HFD-SC__57`$coef
# get(group_col)HFD
#        -0.0148939
#
#
# $`chow_HFD-SC__58`
# $`chow_HFD-SC__58`$pvalue
# get(group_col)HFD
#         0.4417451
#
# $`chow_HFD-SC__58`$coef
# get(group_col)HFD
#      -0.003056252
#
#
# $`chow_HFD-SC__59`
# $`chow_HFD-SC__59`$pvalue
# get(group_col)HFD
#         0.8286634
#
# $`chow_HFD-SC__59`$coef
# get(group_col)HFD
#      -0.006939509
#
#
# $`chow_HFD-SC__60`
# $`chow_HFD-SC__60`$pvalue
# get(group_col)HFD
#        0.03067219
#
# $`chow_HFD-SC__60`$coef
# get(group_col)HFD
#        0.02226423
#
#
# $`chow_HFD-SC__61`
# $`chow_HFD-SC__61`$pvalue
# get(group_col)HFD
#         0.1495417
#
# $`chow_HFD-SC__61`$coef
# get(group_col)HFD
#          0.114991
#
#
# $`chow_HFD-SC__62`
# $`chow_HFD-SC__62`$pvalue
# get(group_col)HFD
#        0.08794896
#
# $`chow_HFD-SC__62`$coef
# get(group_col)HFD
#       -0.09311114
#
#
# $`chow_HFD-SC__63`
# $`chow_HFD-SC__63`$pvalue
# get(group_col)HFD
#         0.2817496
#
# $`chow_HFD-SC__63`$coef
# get(group_col)HFD
#       -0.08645742
#
#
# $`chow_HFD-SC__64`
# $`chow_HFD-SC__64`$pvalue
# get(group_col)HFD
#         0.4845538
#
# $`chow_HFD-SC__64`$coef
# get(group_col)HFD
#       -0.02613007
#
#
# $`chow_HFD-SC__65`
# $`chow_HFD-SC__65`$pvalue
# get(group_col)HFD
#         0.2987897
#
# $`chow_HFD-SC__65`$coef
# get(group_col)HFD
#       -0.03520558
#
#
# $`chow_HFD-SC__66`
# $`chow_HFD-SC__66`$pvalue
# get(group_col)HFD
#         0.2836581
#
# $`chow_HFD-SC__66`$coef
# get(group_col)HFD
#        0.03377341
#
#
# $`chow_HFD-SC__67`
# $`chow_HFD-SC__67`$pvalue
# get(group_col)HFD
#         0.4487252
#
# $`chow_HFD-SC__67`$coef
# get(group_col)HFD
#       -0.03257498
#
#
# $`chow_HFD-SC__68`
# $`chow_HFD-SC__68`$pvalue
# get(group_col)HFD
#         0.1963968
#
# $`chow_HFD-SC__68`$coef
# get(group_col)HFD
#        0.04865443
#
#
# $`chow_HFD-SC__69`
# $`chow_HFD-SC__69`$pvalue
# get(group_col)HFD
#         0.2911177
#
# $`chow_HFD-SC__69`$coef
# get(group_col)HFD
#        0.04502403
#
#
# $`chow_HFD-SC__70`
# $`chow_HFD-SC__70`$pvalue
# get(group_col)HFD
#         0.6742177
#
# $`chow_HFD-SC__70`$coef
# get(group_col)HFD
#        0.03308424
#
#
# $`chow_HFD-SC__71`
# $`chow_HFD-SC__71`$pvalue
# get(group_col)HFD
#         0.8896875
#
# $`chow_HFD-SC__71`$coef
# get(group_col)HFD
#      -0.009635559
#
#
# $`chow_HFD-SC__72`
# $`chow_HFD-SC__72`$pvalue
# get(group_col)HFD
#         0.5837925
#
# $`chow_HFD-SC__72`$coef
# get(group_col)HFD
#       -0.00559187
#
#
# $`chow_HFD-SC__73`
# $`chow_HFD-SC__73`$pvalue
# get(group_col)HFD
#          0.685428
#
# $`chow_HFD-SC__73`$coef
# get(group_col)HFD
#        0.01056246
#
#
# $`chow_HFD-SC__74`
# $`chow_HFD-SC__74`$pvalue
# get(group_col)HFD
#         0.5591686
#
# $`chow_HFD-SC__74`$coef
# get(group_col)HFD
#       -0.02042103
#
#
# $`chow_HFD-SC__75`
# $`chow_HFD-SC__75`$pvalue
# get(group_col)HFD
#         0.5470751
#
# $`chow_HFD-SC__75`$coef
# get(group_col)HFD
#        0.01620997
#
#
# $`chow_HFD-SC__76`
# $`chow_HFD-SC__76`$pvalue
# get(group_col)HFD
#         0.7117719
#
# $`chow_HFD-SC__76`$coef
# get(group_col)HFD
#       -0.02960189
#
#
# $`chow_HFD-SC__77`
# $`chow_HFD-SC__77`$pvalue
# get(group_col)HFD
#         0.6394224
#
# $`chow_HFD-SC__77`$coef
# get(group_col)HFD
#       0.005226346
#
#
# $`chow_HFD-SC__78`
# $`chow_HFD-SC__78`$pvalue
# get(group_col)HFD
#         0.5066059
#
# $`chow_HFD-SC__78`$coef
# get(group_col)HFD
#        -0.0177667
#
#
# $`chow_HFD-SC__79`
# $`chow_HFD-SC__79`$pvalue
# get(group_col)HFD
#         0.1406261
#
# $`chow_HFD-SC__79`$coef
# get(group_col)HFD
#        0.04389814
#
#
# $`chow_HFD-SC__80`
# $`chow_HFD-SC__80`$pvalue
# get(group_col)HFD
#         0.6986185
#
# $`chow_HFD-SC__80`$coef
# get(group_col)HFD
#       -0.03833394
#
#
# $`chow_HFD-SC__81`
# $`chow_HFD-SC__81`$pvalue
# get(group_col)HFD
#        0.08791624
#
# $`chow_HFD-SC__81`$coef
# get(group_col)HFD
#       -0.08191537
#
#
# $`chow_HFD-SC__82`
# $`chow_HFD-SC__82`$pvalue
# get(group_col)HFD
#         0.2960058
#
# $`chow_HFD-SC__82`$coef
# get(group_col)HFD
#       -0.05065165
#
#
# $`chow_HFD-SC__83`
# $`chow_HFD-SC__83`$pvalue
# get(group_col)HFD
#         0.3248017
#
# $`chow_HFD-SC__83`$coef
# get(group_col)HFD
#        0.07524632
#
#
# $`chow_HFD-SC__84`
# $`chow_HFD-SC__84`$pvalue
# get(group_col)HFD
#         0.3649069
#
# $`chow_HFD-SC__84`$coef
# get(group_col)HFD
#       -0.06543086
#
#
# $`chow_HFD-SC__85`
# $`chow_HFD-SC__85`$pvalue
# get(group_col)HFD
#         0.7486766
#
# $`chow_HFD-SC__85`$coef
# get(group_col)HFD
#      -0.006216501
#
#
# $`chow_HFD-SC__86`
# $`chow_HFD-SC__86`$pvalue
# get(group_col)HFD
#         0.5593075
#
# $`chow_HFD-SC__86`$coef
# get(group_col)HFD
#        0.04285645
#
#
# $`chow_HFD-SC__87`
# $`chow_HFD-SC__87`$pvalue
# get(group_col)HFD
#         0.6937649
#
# $`chow_HFD-SC__87`$coef
# get(group_col)HFD
#        -0.0180051
#
#
# $`chow_HFD-SC__88`
# $`chow_HFD-SC__88`$pvalue
# get(group_col)HFD
#         0.8336055
#
# $`chow_HFD-SC__88`$coef
# get(group_col)HFD
#        0.01728193
#
#
# $`chow_HFD-SC__89`
# $`chow_HFD-SC__89`$pvalue
# get(group_col)HFD
#         0.5616059
#
# $`chow_HFD-SC__89`$coef
# get(group_col)HFD
#        0.03632537
#
#
# $`chow_HFD-SC__90`
# $`chow_HFD-SC__90`$pvalue
# get(group_col)HFD
#         0.6434294
#
# $`chow_HFD-SC__90`$coef
# get(group_col)HFD
#        0.03712203
#
#
# $`chow_HFD-SC__91`
# $`chow_HFD-SC__91`$pvalue
# get(group_col)HFD
#         0.4735115
#
# $`chow_HFD-SC__91`$coef
# get(group_col)HFD
#        0.02673606
#
#
# $`chow_HFD-SC__92`
# $`chow_HFD-SC__92`$pvalue
# get(group_col)HFD
#         0.1669636
#
# $`chow_HFD-SC__92`$coef
# get(group_col)HFD
#        0.06284362

# %%
# convert to tibble and save as csv
df <- ym_export %>%
  imap(function(value, name) {
    tibble(
      test_name = name,
      coef = value$coef,
      pvalue = value$pvalue
    )
  }) %>%
  bind_rows() %>% 
  arrange(pvalue) %>% 
  mutate(pvalue_bh = p.adjust(pvalue, method = "BH")) %>% 
  arrange(pvalue_bh) %>%
  separate('test_name', into = c('comparison', 'module'), sep='-') %>%
  mutate(comparison = str_replace(comparison, fixed('_'), '.vs.'))

df %>% head(10)
df %>% write_csv(significant_modules)
# Out:
#    comparison   module  coef        pvalue       pvalue_bh
# 1  chow.vs.fast HY__50   0.13361297 4.625723e-06 0.002368370
# 2  chow.vs.fast HY__71  -0.09588819 3.188199e-05 0.007003392
# 3  chow.vs.fast IC__15   0.12754064 4.103550e-05 0.007003392
# 4  chow.vs.fast IC__08   0.11770891 5.889459e-05 0.007538507
# 5  chow.vs.fast IC__32  -0.11861996 9.705456e-05 0.009938387
# 6  chow.vs.fast IC__07  -0.10337021 1.511013e-04 0.010741812
# 7  chow.vs.fast SC__78   0.12740735 1.588508e-04 0.010741812
# 8  chow.vs.fast SC__27  -0.04701637 1.678408e-04 0.010741812
# 9  chow.vs.fast SC__32  -0.12776112 1.889656e-04 0.010750041
# 10 chow.vs.HFD  HPF__17 -0.03989605 8.164698e-04 0.041803256

# %%
sessionInfo()
# Out:
# R version 4.2.2 (2022-10-31)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux
#
# Matrix products: default
# BLAS/LAPACK: /nfsdata/tools/anaconda/envs/nmq407/dmb/lib/libopenblasp-r0.3.21.so
#
# locale:
#  [1] LC_CTYPE=en_GB.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_GB.UTF-8        LC_COLLATE=en_GB.UTF-8
#  [5] LC_MONETARY=en_GB.UTF-8    LC_MESSAGES=en_GB.UTF-8
#  [7] LC_PAPER=en_GB.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_GB.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats4    stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
#  [1] lubridate_1.9.2             stringr_1.5.0
#  [3] purrr_1.0.1                 readr_2.1.4
#  [5] tibble_3.2.1                tidyverse_2.0.0
#  [7] furrr_0.3.1                 future_1.32.0
#  [9] fitdistrplus_1.1-11         survival_3.5-5
# [11] MASS_7.3-60                 gratia_0.8.1
# [13] SingleCellExperiment_1.20.1 SummarizedExperiment_1.28.0
# [15] Biobase_2.58.0              GenomicRanges_1.50.2
# [17] GenomeInfoDb_1.34.9         IRanges_2.32.0
# [19] S4Vectors_0.36.2            BiocGenerics_0.44.0
# [21] MatrixGenerics_1.10.0       matrixStats_1.0.0
# [23] SeuratObject_4.1.3          Seurat_4.3.0
# [25] tidyr_1.3.0                 forcats_1.0.0
# [27] dplyr_1.1.2                 vroom_1.6.3
# [29] ggplot2_3.4.2               lme4_1.1-33
# [31] Matrix_1.5-4.1              mgcv_1.8-42
# [33] nlme_3.1-162
#
# loaded via a namespace (and not attached):
#   [1] uuid_1.1-0             plyr_1.8.8             igraph_1.5.0
#   [4] repr_1.1.6             lazyeval_0.2.2         sp_2.0-0
#   [7] splines_4.2.2          listenv_0.9.0          scattermore_1.2
#  [10] digest_0.6.31          htmltools_0.5.5        fansi_1.0.4
#  [13] magrittr_2.0.3         tensor_1.5             cluster_2.1.4
#  [16] ROCR_1.0-11            tzdb_0.4.0             globals_0.16.2
#  [19] timechange_0.2.0       spatstat.sparse_3.0-2  colorspace_2.1-0
#  [22] ggrepel_0.9.3          crayon_1.5.2           RCurl_1.98-1.12
#  [25] jsonlite_1.8.5         progressr_0.13.0       spatstat.data_3.0-1
#  [28] zoo_1.8-12             glue_1.6.2             polyclip_1.10-4
#  [31] gtable_0.3.3           zlibbioc_1.44.0        XVector_0.38.0
#  [34] leiden_0.4.3           DelayedArray_0.24.0    future.apply_1.11.0
#  [37] abind_1.4-5            scales_1.2.1           spatstat.random_3.1-5
#  [40] miniUI_0.1.1.1         Rcpp_1.0.10            viridisLite_0.4.2
#  [43] xtable_1.8-4           reticulate_1.30        bit_4.0.5
#  [46] htmlwidgets_1.6.2      httr_1.4.6             RColorBrewer_1.1-3
#  [49] ellipsis_0.3.2         ica_1.0-3              pkgconfig_2.0.3
#  [52] uwot_0.1.14            deldir_1.0-9           utf8_1.2.3
#  [55] tidyselect_1.2.0       rlang_1.1.1            reshape2_1.4.4
#  [58] later_1.3.1            munsell_0.5.0          tools_4.2.2
#  [61] cli_3.6.1              generics_0.1.3         ggridges_0.5.4
#  [64] evaluate_0.21          fastmap_1.1.1          goftest_1.2-3
#  [67] bit64_4.0.5            RANN_2.6.1             pbapply_1.7-0
#  [70] mime_0.12              mvnfast_0.2.8          compiler_4.2.2
#  [73] plotly_4.10.2          png_0.1-8              spatstat.utils_3.0-3
#  [76] stringi_1.7.12         lattice_0.21-8         IRdisplay_1.1
#  [79] nloptr_2.0.3           vctrs_0.6.2            pillar_1.9.0
#  [82] lifecycle_1.0.3        spatstat.geom_3.2-1    lmtest_0.9-40
#  [85] RcppAnnoy_0.0.20       data.table_1.14.8      cowplot_1.1.1
#  [88] bitops_1.0-7           irlba_2.3.5.1          httpuv_1.6.11
#  [91] patchwork_1.1.2.9000   R6_2.5.1               promises_1.2.0.1
#  [94] renv_0.15.5            KernSmooth_2.23-21     gridExtra_2.3
#  [97] parallelly_1.36.0      codetools_0.2-19       boot_1.3-28.1
# [100] withr_2.5.0            sctransform_0.3.5      GenomeInfoDbData_1.2.9
# [103] hms_1.1.3              parallel_4.2.2         grid_4.2.2
# [106] IRkernel_1.3.2         minqa_1.2.5            Rtsne_0.16
# [109] pbdZMQ_0.3-9           spatstat.explore_3.2-1 shiny_1.7.4
# [112] base64enc_0.1-3
