# %% [markdown]
# # Testing for modules impacted by diet

# %%
#load packages
pkgs <- c("mgcv", "lme4", "ggplot2", "vroom", "dplyr", "forcats", "tidyr", "Seurat", "SingleCellExperiment", "gratia", "MASS", "fitdistrplus", "furrr", "tidyverse")
vapply(pkgs, library, logical(1), character.only = TRUE, logical.return = TRUE,
       quietly = TRUE)
# Out:
# This is mgcv 1.8-42. For overview type 'help("mgcv-package")'.
#
#
# Attaching package: ‘lme4’
#
#
# The following object is masked from ‘package:nlme’:
#
#     lmList
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following object is masked from ‘package:nlme’:
#
#     collapse
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘tidyr’
#
#
# The following objects are masked from ‘package:Matrix’:
#
#     expand, pack, unpack
#
#
# The legacy packages maptools, rgdal, and rgeos, underpinning the sp package,
# which was just loaded, will retire in October 2023.
# Please refer to R-spatial evolution reports for details, especially
# https://r-spatial.org/r/2023/05/15/evolution4.html.
# It may be desirable to make the sf package available;
# package maintainers should consider adding sf to Suggests:.
# The sp package is now running under evolution status 2
#      (status 2 uses the sf package in place of rgdal)
#
# Attaching SeuratObject
#
#
# Attaching package: ‘matrixStats’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     count
#
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     expand
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     first, rename
#
#
# The following objects are masked from ‘package:Matrix’:
#
#     expand, unname
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
#
# Attaching package: ‘IRanges’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     collapse, desc, slice
#
#
# The following object is masked from ‘package:nlme’:
#
#     collapse
#
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘Biobase’
#
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
#
#
# Attaching package: ‘SummarizedExperiment’
#
#
# The following object is masked from ‘package:SeuratObject’:
#
#     Assays
#
#
# The following object is masked from ‘package:Seurat’:
#
#     Assays
#
#
#
# Attaching package: ‘MASS’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     select
#
#
#
# Attaching package: ‘future’
#
#
# The following object is masked from ‘package:survival’:
#
#     cluster
#
#
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ lubridate 1.9.2     ✔ stringr   1.5.0
# ✔ purrr     1.0.1     ✔ tibble    3.2.1
# ✔ readr     2.1.4
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ lubridate::%within%()    masks IRanges::%within%()
# ✖ readr::col_character()   masks vroom::col_character()
# ✖ readr::col_date()        masks vroom::col_date()
# ✖ readr::col_datetime()    masks vroom::col_datetime()
# ✖ readr::col_double()      masks vroom::col_double()
# ✖ readr::col_factor()      masks vroom::col_factor()
# ✖ readr::col_guess()       masks vroom::col_guess()
# ✖ readr::col_integer()     masks vroom::col_integer()
# ✖ readr::col_logical()     masks vroom::col_logical()
# ✖ readr::col_number()      masks vroom::col_number()
# ✖ readr::col_skip()        masks vroom::col_skip()
# ✖ readr::col_time()        masks vroom::col_time()
# ✖ IRanges::collapse()      masks dplyr::collapse(), nlme::collapse()
# ✖ readr::cols()            masks vroom::cols()
# ✖ Biobase::combine()       masks BiocGenerics::combine(), dplyr::combine()
# ✖ matrixStats::count()     masks dplyr::count()
# ✖ readr::date_names_lang() masks vroom::date_names_lang()
# ✖ readr::default_locale()  masks vroom::default_locale()
# ✖ IRanges::desc()          masks dplyr::desc()
# ✖ S4Vectors::expand()      masks tidyr::expand(), Matrix::expand()
# ✖ dplyr::filter()          masks stats::filter()
# ✖ S4Vectors::first()       masks dplyr::first()
# ✖ readr::fwf_cols()        masks vroom::fwf_cols()
# ✖ readr::fwf_empty()       masks vroom::fwf_empty()
# ✖ readr::fwf_positions()   masks vroom::fwf_positions()
# ✖ readr::fwf_widths()      masks vroom::fwf_widths()
# ✖ dplyr::lag()             masks stats::lag()
# ✖ readr::locale()          masks vroom::locale()
# ✖ readr::output_column()   masks vroom::output_column()
# ✖ tidyr::pack()            masks Matrix::pack()
# ✖ BiocGenerics::Position() masks ggplot2::Position(), base::Position()
# ✖ readr::problems()        masks vroom::problems()
# ✖ purrr::reduce()          masks GenomicRanges::reduce(), IRanges::reduce()
# ✖ S4Vectors::rename()      masks dplyr::rename()
# ✖ lubridate::second()      masks S4Vectors::second()
# ✖ lubridate::second<-()    masks S4Vectors::second<-()
# ✖ MASS::select()           masks dplyr::select()
# ✖ IRanges::slice()         masks dplyr::slice()
# ✖ tidyr::unpack()          masks Matrix::unpack()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#                 mgcv                 lme4              ggplot2
#                 TRUE                 TRUE                 TRUE
#                vroom                dplyr              forcats
#                 TRUE                 TRUE                 TRUE
#                tidyr               Seurat SingleCellExperiment
#                 TRUE                 TRUE                 TRUE
#               gratia                 MASS         fitdistrplus
#                 TRUE                 TRUE                 TRUE
#                furrr            tidyverse
#                 TRUE                 TRUE

# %%
# settings for the run
me_dir <- 'wgcna_output/renamed_tables/' #where to find the WGCNA MEs
run_name <- 'ds4_mcs20_pF_kME_cellModEmbed_24h' #the run prefix
group_col <- "diet" # group that will be modelled
cluster_col <- "region" # sample region
mgcv_dir <- paste0(me_dir, 'mgcv/') # where to save the mgcv results
dir.create(mgcv_dir, recursive = TRUE) # creates the mgcv results folder if it doesn't exist
summaries_path <- paste0(mgcv_dir, run_name, '_summaries_f.rds') #save summaries here
models_path <- paste0(mgcv_dir, run_name, '_models.rds') #save models here
memfs_path <- paste0(mgcv_dir, run_name, '_memfs.rds') #save intermediate memfs objects here (only for debugging)
significant_modules <- paste0(mgcv_dir, run_name, '_significant_modules.csv')#where to save the table summarizing significant modules
# Out:
# Warning message in dir.create(mgcv_dir, recursive = TRUE):
# “'wgcna_output/renamed_tables/mgcv' already exists”

# %%
me = read_csv(paste0(me_dir, 'kME_cellModEmbed.csv')) #read the MEs and inspect them
me %>% head
# Out:
# Rows: 144 Columns: 386
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr   (3): data, region, sample
# dbl (383): HPF__01, HPF__02, HPF__03, HPF__04, HPF__05, HPF__06, HPF__07, HP...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   data region sample           HPF__01    HPF__02    HPF__03   HPF__04
# 1 dmb  HY     S0010_01_chow_HY 0.05197933 0.03023810 0.1824172 0.1229980
# 2 dmb  HY     S0010_02_chow_HY 0.08876762 0.08017922 0.1459963 0.1170462
# 3 dmb  HY     S0010_03_chow_HY 0.07109426 0.02853630 0.1832191 0.1384336
# 4 dmb  HY     S0010_04_chow_HY 0.02948085 0.06371331 0.1535754 0.1107229
# 5 dmb  HY     S0010_05_chow_HY 0.11411558 0.03807216 0.1615871 0.1345847
# 6 dmb  HY     S0010_06_chow_HY 0.02021261 0.07189122 0.1562818 0.1019575
#   HPF__05     HPF__06      HPF__07     ⋯ ZI__39      ZI__40     ZI__41
# 1 -0.05775205  0.019439584 -0.06125762 ⋯ -0.08595527 0.05252190 -0.05822008
# 2 -0.03252780 -0.004745673 -0.05191100 ⋯ -0.11281907 0.02927096 -0.02412367
# 3 -0.06336754 -0.032457115 -0.06025051 ⋯ -0.10252465 0.06811403 -0.04506138
# 4 -0.03764149  0.025134355 -0.05945944 ⋯ -0.05751049 0.03972461 -0.01765908
# 5 -0.06702112  0.007702094 -0.05492529 ⋯ -0.15425467 0.03670603 -0.01827709
# 6 -0.03508683 -0.025868732 -0.07505565 ⋯ -0.09517898 0.05157318 -0.02545144
#   ZI__42     ZI__43       ZI__44        ZI__45     ZI__46     ZI__47
# 1 0.06567769  0.036785185  0.0102144634 0.10537119 0.11220870 -0.04791984
# 2 0.02603893  0.007287426 -0.0017344272 0.10817653 0.11961064 -0.04316019
# 3 0.01064958  0.021634418 -0.0002412614 0.07374108 0.10598614 -0.02872247
# 4 0.05303416 -0.004217487  0.0049177488 0.06565093 0.01816232 -0.03737867
# 5 0.01769293 -0.020943932 -0.0073797921 0.09252465 0.09507013 -0.02601267
# 6 0.02872648 -0.025390663  0.0255168968 0.07634631 0.05995981 -0.04782112
#   ZI__48
# 1 0.020875004
# 2 0.006892997
# 3 0.025098740
# 4 0.014236332
# 5 0.019362943
# 6 0.008990742

# %%
meta = read_csv('vsd_meta.csv') # read the metadata and reformat some columns
meta = meta %>%
mutate(diet = factor(diet, levels=c('chow', 'HFD', 'fast'))) %>%
mutate(animal_id = as.character(animal_id)) %>%
mutate(region = factor(region, levels=c("HY", 'HPF', 'SC', 'IC', 'PFC', 'ZI'))) %>%
filter(seq_run %in% c('0037')) %>% #filter down to 24h study
mutate(seq_run = factor(seq_run, levels=c('0037'))) 

meta %>% head
# Out:
# Rows: 144 Columns: 26
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr   (9): name, filename, seq_run, seq_sample, diet, region, hemisphere, no...
# dbl  (15): rna_conc_qbit, box_id, animal_id, diet_kcal, experiment_duration,...
# dttm  (2): experiment_start, time_of_euthanasia
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   name               filename           seq_run seq_sample rna_conc_qbit box_id
# 1 S0037_1431_chow_HY 143_1_Hyp_chow_S7  0037    S7         330.0         1431
# 2 S0037_1432_chow_HY 143_2_Hyp_chow_S25 0037    S25        312.0         1432
# 3 S0037_1442_chow_HY 144_2_Hyp_chow_S2  0037    S2         233.4         1442
# 4 S0037_1452_chow_HY 145_2_Hyp_chow_S41 0037    S41         92.4         1452
# 5 S0037_1423_chow_HY 142_3_Hyp_chow_S38 0037    S38        366.0         1423
# 6 S0037_1443_chow_HY 144_3_Hyp_chow_S40 0037    S40        171.0         1443
#   animal_id diet diet_kcal region ⋯ bw_f bw_change bw_change_pct
# 1 1431      chow 3227      HY     ⋯ 23.0  0.3       0.013215859
# 2 1432      chow 3227      HY     ⋯ 25.5  0.4       0.015936255
# 3 1442      chow 3227      HY     ⋯ 28.4 -0.1      -0.003508772
# 4 1452      chow 3227      HY     ⋯ 26.7  0.1       0.003759398
# 5 1423      chow 3227      HY     ⋯ 25.8 -0.1      -0.003861004
# 6 1443      chow 3227      HY     ⋯ 24.8  0.0       0.000000000
#   bw_change_pct_ph fw_i  fw_f  kcal_intake power_intake
# 1  0.0005506608    663.5 660.1 10971.8     457.1583
# 2  0.0006640106    634.2 630.0 13553.4     564.7250
# 3 -0.0001461988    656.7 652.4 13876.1     578.1708
# 4  0.0001566416    683.0 679.5 11294.5     470.6042
# 5 -0.0001608752    593.1 589.1 12908.0     537.8333
# 6  0.0000000000    642.8 638.7 13230.7     551.2792
#   notes                                      qc
# 1 NA                                         ok
# 2 NA                                         ok
# 3 NA                                         ok
# 4 NA                                         ok
# 5 Sup. Colliculus for 142.3 is in tube 145.4 ok
# 6 NA                                         ok

# %%
# filters the meta down
# meta is the meta dataframe
# group_col is the perturbation column e.g. - Diet
# groups is a vector with conditions for comparison e.g. - c("chow", "HFD")
# cluster_col is the column encoding clusters in the meta. e.g. - region
# clusters is a vector with clusters to filter to. e.g. - HY
filter_meta <- function (meta, group_col, groups, cluster_col, clusters){
    meta_f <- meta %>% 
        filter(
            get(group_col) %in% groups,
            get(cluster_col) %in% clusters
        )
    return (meta_f)
}

# %%
make_sp <- function (me_df) {
    sp <- stringr::str_split_fixed(colnames(me)[4:length(colnames(me))], pattern='__', n=2)
    sp <- as.data.frame(sp)
    sp <- apply(sp, 1, function(x) as.vector(c(x[1], x[2], paste0(x[1], '__', x[2]))))
    sp <- t(sp)
    sp <- as.data.frame(sp)
    colnames(sp)[colnames(sp) == 'V1'] <- 'cluster'
    colnames(sp)[colnames(sp) == 'V2'] <- 'module'
    colnames(sp)[colnames(sp) == 'V3'] <- 'ME_col'
    return (sp)
}

# %%
# a simple model
# models the diet (group_col)
fit_mgcv <- function(memf){
    model <- bam(ME ~ get(group_col),
                 data = memf, method = "fREML", discrete = T
                )
    return (model)
}


# a more complex model
# accounts for sequencing run as a random effect
# fit_mgcv <- function(memf){
#     model <- bam(ME ~ get(group_col) +
#                  s(seq_run, bs = "re"), # could also model cages if known
#                  data = memf, method = "fREML", discrete = T
#                 )
#     return (model)
# }

safe_fit_mgcv <- purrr::safely(fit_mgcv) #necessary for parallelization, in case we hit errors

# %%
# this is what make_sp produces
sp <- make_sp(me)
head(sp)
# Out:
#   cluster module ME_col
# 1 HPF     01     HPF__01
# 2 HPF     02     HPF__02
# 3 HPF     03     HPF__03
# 4 HPF     04     HPF__04
# 5 HPF     05     HPF__05
# 6 HPF     06     HPF__06

# %%
#this is what filter_meta produces
filter_meta(meta, "diet", c('chow', 'fast'), "region", c("HY"))
# Out:
#    name               filename           seq_run seq_sample rna_conc_qbit
# 1  S0037_1431_chow_HY 143_1_Hyp_chow_S7  0037    S7         330.0
# 2  S0037_1432_chow_HY 143_2_Hyp_chow_S25 0037    S25        312.0
# 3  S0037_1442_chow_HY 144_2_Hyp_chow_S2  0037    S2         233.4
# 4  S0037_1452_chow_HY 145_2_Hyp_chow_S41 0037    S41         92.4
# 5  S0037_1423_chow_HY 142_3_Hyp_chow_S38 0037    S38        366.0
# 6  S0037_1443_chow_HY 144_3_Hyp_chow_S40 0037    S40        171.0
# 7  S0037_1424_fast_HY 142_4_Hyp_fast_S53 0037    S53        497.0
# 8  S0037_1425_fast_HY 142_5_Hyp_fast_S69 0037    S69        300.0
# 9  S0037_1433_fast_HY 143_3_Hyp_fast_S23 0037    S23        168.6
# 10 S0037_1434_fast_HY 143_4_Hyp_fast_S16 0037    S16        348.0
# 11 S0037_1444_fast_HY 144_4_Hyp_fast_S13 0037    S13        264.6
# 12 S0037_1453_fast_HY 145_3_Hyp_fast_S57 0037    S57        498.0
# 13 S0037_1454_fast_HY 145_4_Hyp_fast_S29 0037    S29        474.0
#    box_id animal_id diet diet_kcal region ⋯ bw_f bw_change bw_change_pct
# 1  1431   1431      chow 3227      HY     ⋯ 23.0  0.3       0.013215859
# 2  1432   1432      chow 3227      HY     ⋯ 25.5  0.4       0.015936255
# 3  1442   1442      chow 3227      HY     ⋯ 28.4 -0.1      -0.003508772
# 4  1452   1452      chow 3227      HY     ⋯ 26.7  0.1       0.003759398
# 5  1423   1423      chow 3227      HY     ⋯ 25.8 -0.1      -0.003861004
# 6  1443   1443      chow 3227      HY     ⋯ 24.8  0.0       0.000000000
# 7  1424   1424      fast    0      HY     ⋯ 20.2 -4.9      -0.195219124
# 8  1425   1425      fast    0      HY     ⋯ 20.9 -4.3      -0.170634921
# 9  1433   1433      fast    0      HY     ⋯ 20.5 -5.1      -0.199218750
# 10 1434   1434      fast    0      HY     ⋯ 20.0 -5.1      -0.203187251
# 11 1444   1444      fast    0      HY     ⋯ 19.9 -5.2      -0.207171315
# 12 1453   1453      fast    0      HY     ⋯ 18.8 -4.3      -0.186147186
# 13 1454   1454      fast    0      HY     ⋯ 19.5 -5.3      -0.213709677
#    bw_change_pct_ph fw_i  fw_f  kcal_intake power_intake
# 1   0.0005506608    663.5 660.1 10971.8     457.1583
# 2   0.0006640106    634.2 630.0 13553.4     564.7250
# 3  -0.0001461988    656.7 652.4 13876.1     578.1708
# 4   0.0001566416    683.0 679.5 11294.5     470.6042
# 5  -0.0001608752    593.1 589.1 12908.0     537.8333
# 6   0.0000000000    642.8 638.7 13230.7     551.2792
# 7  -0.0081341301      0.0   0.0     0.0       0.0000
# 8  -0.0071097884      0.0   0.0     0.0       0.0000
# 9  -0.0083007812      0.0   0.0     0.0       0.0000
# 10 -0.0084661355      0.0   0.0     0.0       0.0000
# 11 -0.0086321381      0.0   0.0     0.0       0.0000
# 12 -0.0077561328      0.0   0.0     0.0       0.0000
# 13 -0.0089045699      0.0   0.0     0.0       0.0000
#    notes                                      qc
# 1  NA                                         ok
# 2  NA                                         ok
# 3  NA                                         ok
# 4  NA                                         ok
# 5  Sup. Colliculus for 142.3 is in tube 145.4 ok
# 6  NA                                         ok
# 7  NA                                         ok
# 8  NA                                         ok
# 9  Slightly apathetic                         ok
# 10 NA                                         ok
# 11 NA                                         ok
# 12 NA                                         ok
# 13 Sup. Colliculus for 145.4 is in tube 142.3 ok

# %%
# creating splits of the data for parallelization

splits <- list(c('chow', 'fast'))

memfs <- c()

for (s in splits){
    for (i in 1:nrow(sp)){
        cluster <- sp[i,]$cluster
        module <- sp[i,]$module
        me_col <- sp[i,]$ME_col
        me_keep_cols <- c('sample', me_col)
        me_f <- me[me_keep_cols]
        colnames(me_f)[2] <- 'ME'
        mf <- filter_meta(meta, group_col, s, cluster_col, c(cluster))
        mf$sample <- mf$name #need to give this same column as data
        mf_cols <- c('sample', 'diet', 'region', 'seq_run') 
        mf_f <- mf[mf_cols]
        mf_f <- mf_f %>%
            mutate(
                diet = droplevels(diet),
                region = droplevels(region),
                seq_run = droplevels(seq_run)
            )
        memf <- plyr::join(me_f, mf_f, by = c('sample'), type='right')
        memf_name <- paste0(s[1], '_', s[2], '-', me_col)
        memfs[[memf_name]] <- memf
    }
}

# %%
# what the splicts look like
memfs[1]
# Out:
# $`chow_fast-HPF__01`
#                 sample          ME diet region seq_run
# 1  S0037_1422_chow_HPF -0.02005092 chow    HPF    0037
# 2  S0037_1432_chow_HPF -0.09387324 chow    HPF    0037
# 3  S0037_1442_chow_HPF -0.04276030 chow    HPF    0037
# 4  S0037_1423_chow_HPF  0.09008606 chow    HPF    0037
# 5  S0037_1443_chow_HPF -0.04758924 chow    HPF    0037
# 6  S0037_1433_fast_HPF -0.06603858 fast    HPF    0037
# 7  S0037_1434_fast_HPF  0.04890475 fast    HPF    0037
# 8  S0037_1435_fast_HPF -0.41309828 fast    HPF    0037
# 9  S0037_1445_fast_HPF  0.10889821 fast    HPF    0037
# 10 S0037_1453_fast_HPF -0.04332955 fast    HPF    0037
# 11 S0037_1454_fast_HPF -0.01641091 fast    HPF    0037
# 12 S0037_1455_fast_HPF -0.06293127 fast    HPF    0037

# %%
# saveRDS(memfs, memfs_path)

# %%
# This does run in parallel! adjust workers accordingly
plan(multisession, workers = 20)
models <- future_map(memfs, ~safe_fit_mgcv(.x), .options = furrr_options(seed = T))
# Out:
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”
# Warning message in bam(ME ~ get(group_col), data = memf, method = "fREML", discrete = T):
# “no smooths, ignoring `discrete=TRUE'”

# %%
# function to drop models that error
filter_errored_models <- function(models){
    models_f <- c()
    models_error <-c()
    for (m in names(models)){
        model <- models[[m]]
        if (is.null(model$error)){
            models_f[[m]] <- model$result
        }
        else {
            models_error[[m]] <- model
        }
    }
    return (models_f)
}

# %%
# filter down models
models <- filter_errored_models(models)
length(models)
# Out:
# [1] 304

# %%
# lets see what models look like
models[1]
# Out:
# $`chow_fast-HPF__01`
#
# Family: gaussian
# Link function: identity
#
# Formula:
# ME ~ get(group_col)
# Total model degrees of freedom 2
#
# REML score: -3.955344

# %%
# summarize models
plan(multisession, workers = 20)
summaries <- future_map(models, ~summary(.x))

# %%
length(summaries)
# Out:
# [1] 304

# %%
# make a vector of summaries
mgcv_summaries_f <- c()
for (s in names(summaries)){
    summary <- summaries[[s]]
    p.pv <- summary$p.pv[[2]]
    mgcv_summaries_f[[s]] <-summary
}

# %%
# save vector just in case
saveRDS(mgcv_summaries_f, summaries_path)

# %%
# save models
saveRDS(models, models_path)

# %%
# data structure for export
ym_export <- c()
for (n in names(mgcv_summaries_f)){
    s <- mgcv_summaries_f[[n]]
    pval <- s$p.pv[2]
    coef <- s$p.coeff[2]
    ym_export[[n]] <- list('pvalue' = pval, "coef" = coef)
}

# %%
# what does it look like
ym_export
# Out:
# $`chow_fast-HPF__01`
# $`chow_fast-HPF__01`$pvalue
# get(group_col)fast
#          0.6222822
#
# $`chow_fast-HPF__01`$coef
# get(group_col)fast
#        -0.04059185
#
#
# $`chow_fast-HPF__02`
# $`chow_fast-HPF__02`$pvalue
# get(group_col)fast
#          0.3572571
#
# $`chow_fast-HPF__02`$coef
# get(group_col)fast
#         0.09558561
#
#
# $`chow_fast-HPF__03`
# $`chow_fast-HPF__03`$pvalue
# get(group_col)fast
#          0.1907902
#
# $`chow_fast-HPF__03`$coef
# get(group_col)fast
#         0.03185054
#
#
# $`chow_fast-HPF__04`
# $`chow_fast-HPF__04`$pvalue
# get(group_col)fast
#          0.8279528
#
# $`chow_fast-HPF__04`$coef
# get(group_col)fast
#        -0.01743792
#
#
# $`chow_fast-HPF__05`
# $`chow_fast-HPF__05`$pvalue
# get(group_col)fast
#         0.08960888
#
# $`chow_fast-HPF__05`$coef
# get(group_col)fast
#          0.1301847
#
#
# $`chow_fast-HPF__06`
# $`chow_fast-HPF__06`$pvalue
# get(group_col)fast
#          0.8966645
#
# $`chow_fast-HPF__06`$coef
# get(group_col)fast
#       -0.006745312
#
#
# $`chow_fast-HPF__07`
# $`chow_fast-HPF__07`$pvalue
# get(group_col)fast
#          0.5695811
#
# $`chow_fast-HPF__07`$coef
# get(group_col)fast
#        -0.02513145
#
#
# $`chow_fast-HPF__08`
# $`chow_fast-HPF__08`$pvalue
# get(group_col)fast
#          0.6411432
#
# $`chow_fast-HPF__08`$coef
# get(group_col)fast
#        -0.05030854
#
#
# $`chow_fast-HPF__09`
# $`chow_fast-HPF__09`$pvalue
# get(group_col)fast
#          0.5317764
#
# $`chow_fast-HPF__09`$coef
# get(group_col)fast
#         0.03953805
#
#
# $`chow_fast-HPF__10`
# $`chow_fast-HPF__10`$pvalue
# get(group_col)fast
#          0.5815772
#
# $`chow_fast-HPF__10`$coef
# get(group_col)fast
#         -0.0849058
#
#
# $`chow_fast-HPF__11`
# $`chow_fast-HPF__11`$pvalue
# get(group_col)fast
#         0.05022004
#
# $`chow_fast-HPF__11`$coef
# get(group_col)fast
#         -0.1582766
#
#
# $`chow_fast-HPF__12`
# $`chow_fast-HPF__12`$pvalue
# get(group_col)fast
#         0.03516842
#
# $`chow_fast-HPF__12`$coef
# get(group_col)fast
#         -0.1907627
#
#
# $`chow_fast-HPF__13`
# $`chow_fast-HPF__13`$pvalue
# get(group_col)fast
#          0.2960976
#
# $`chow_fast-HPF__13`$coef
# get(group_col)fast
#         0.03757696
#
#
# $`chow_fast-HPF__14`
# $`chow_fast-HPF__14`$pvalue
# get(group_col)fast
#          0.2293215
#
# $`chow_fast-HPF__14`$coef
# get(group_col)fast
#          0.1123299
#
#
# $`chow_fast-HPF__15`
# $`chow_fast-HPF__15`$pvalue
# get(group_col)fast
#          0.7946458
#
# $`chow_fast-HPF__15`$coef
# get(group_col)fast
#         0.01659048
#
#
# $`chow_fast-HPF__16`
# $`chow_fast-HPF__16`$pvalue
# get(group_col)fast
#          0.4879808
#
# $`chow_fast-HPF__16`$coef
# get(group_col)fast
#        -0.04747908
#
#
# $`chow_fast-HPF__17`
# $`chow_fast-HPF__17`$pvalue
# get(group_col)fast
#          0.5563658
#
# $`chow_fast-HPF__17`$coef
# get(group_col)fast
#        -0.01145683
#
#
# $`chow_fast-HPF__18`
# $`chow_fast-HPF__18`$pvalue
# get(group_col)fast
#          0.6853056
#
# $`chow_fast-HPF__18`$coef
# get(group_col)fast
#        -0.04896207
#
#
# $`chow_fast-HPF__19`
# $`chow_fast-HPF__19`$pvalue
# get(group_col)fast
#          0.3294426
#
# $`chow_fast-HPF__19`$coef
# get(group_col)fast
#          0.0308794
#
#
# $`chow_fast-HPF__20`
# $`chow_fast-HPF__20`$pvalue
# get(group_col)fast
#          0.8187146
#
# $`chow_fast-HPF__20`$coef
# get(group_col)fast
#       -0.008554401
#
#
# $`chow_fast-HPF__21`
# $`chow_fast-HPF__21`$pvalue
# get(group_col)fast
#           0.799502
#
# $`chow_fast-HPF__21`$coef
# get(group_col)fast
#        -0.01268629
#
#
# $`chow_fast-HPF__22`
# $`chow_fast-HPF__22`$pvalue
# get(group_col)fast
#          0.2753177
#
# $`chow_fast-HPF__22`$coef
# get(group_col)fast
#         0.06320383
#
#
# $`chow_fast-HPF__23`
# $`chow_fast-HPF__23`$pvalue
# get(group_col)fast
#          0.3081543
#
# $`chow_fast-HPF__23`$coef
# get(group_col)fast
#         0.07986156
#
#
# $`chow_fast-HPF__24`
# $`chow_fast-HPF__24`$pvalue
# get(group_col)fast
#         0.08404223
#
# $`chow_fast-HPF__24`$coef
# get(group_col)fast
#        -0.04787939
#
#
# $`chow_fast-HPF__25`
# $`chow_fast-HPF__25`$pvalue
# get(group_col)fast
#         0.04211365
#
# $`chow_fast-HPF__25`$coef
# get(group_col)fast
#        -0.08966411
#
#
# $`chow_fast-HPF__26`
# $`chow_fast-HPF__26`$pvalue
# get(group_col)fast
#          0.3978419
#
# $`chow_fast-HPF__26`$coef
# get(group_col)fast
#        -0.03905248
#
#
# $`chow_fast-HPF__27`
# $`chow_fast-HPF__27`$pvalue
# get(group_col)fast
#           0.290334
#
# $`chow_fast-HPF__27`$coef
# get(group_col)fast
#          0.0401549
#
#
# $`chow_fast-HPF__28`
# $`chow_fast-HPF__28`$pvalue
# get(group_col)fast
#          0.3361421
#
# $`chow_fast-HPF__28`$coef
# get(group_col)fast
#         0.05123442
#
#
# $`chow_fast-HPF__29`
# $`chow_fast-HPF__29`$pvalue
# get(group_col)fast
#          0.2305365
#
# $`chow_fast-HPF__29`$coef
# get(group_col)fast
#          0.1305156
#
#
# $`chow_fast-HPF__30`
# $`chow_fast-HPF__30`$pvalue
# get(group_col)fast
#          0.3269849
#
# $`chow_fast-HPF__30`$coef
# get(group_col)fast
#        -0.02214105
#
#
# $`chow_fast-HPF__31`
# $`chow_fast-HPF__31`$pvalue
# get(group_col)fast
#          0.5615918
#
# $`chow_fast-HPF__31`$coef
# get(group_col)fast
#         0.03229967
#
#
# $`chow_fast-HPF__32`
# $`chow_fast-HPF__32`$pvalue
# get(group_col)fast
#           0.542945
#
# $`chow_fast-HPF__32`$coef
# get(group_col)fast
#         0.02477924
#
#
# $`chow_fast-HPF__33`
# $`chow_fast-HPF__33`$pvalue
# get(group_col)fast
#       0.0002737492
#
# $`chow_fast-HPF__33`$coef
# get(group_col)fast
#          0.1270162
#
#
# $`chow_fast-HPF__34`
# $`chow_fast-HPF__34`$pvalue
# get(group_col)fast
#          0.3888759
#
# $`chow_fast-HPF__34`$coef
# get(group_col)fast
#         0.05300542
#
#
# $`chow_fast-HPF__35`
# $`chow_fast-HPF__35`$pvalue
# get(group_col)fast
#          0.6731614
#
# $`chow_fast-HPF__35`$coef
# get(group_col)fast
#        -0.04616595
#
#
# $`chow_fast-HPF__36`
# $`chow_fast-HPF__36`$pvalue
# get(group_col)fast
#         0.09612292
#
# $`chow_fast-HPF__36`$coef
# get(group_col)fast
#         0.06846284
#
#
# $`chow_fast-HPF__37`
# $`chow_fast-HPF__37`$pvalue
# get(group_col)fast
#          0.5552645
#
# $`chow_fast-HPF__37`$coef
# get(group_col)fast
#         0.03595706
#
#
# $`chow_fast-HPF__38`
# $`chow_fast-HPF__38`$pvalue
# get(group_col)fast
#          0.1655215
#
# $`chow_fast-HPF__38`$coef
# get(group_col)fast
#        -0.07788578
#
#
# $`chow_fast-HY__01`
# $`chow_fast-HY__01`$pvalue
# get(group_col)fast
#          0.4099806
#
# $`chow_fast-HY__01`$coef
# get(group_col)fast
#         0.03439576
#
#
# $`chow_fast-HY__02`
# $`chow_fast-HY__02`$pvalue
# get(group_col)fast
#          0.1833871
#
# $`chow_fast-HY__02`$coef
# get(group_col)fast
#       -0.007902663
#
#
# $`chow_fast-HY__03`
# $`chow_fast-HY__03`$pvalue
# get(group_col)fast
#          0.3890553
#
# $`chow_fast-HY__03`$coef
# get(group_col)fast
#         -0.0129442
#
#
# $`chow_fast-HY__04`
# $`chow_fast-HY__04`$pvalue
# get(group_col)fast
#          0.5777759
#
# $`chow_fast-HY__04`$coef
# get(group_col)fast
#        0.009186821
#
#
# $`chow_fast-HY__05`
# $`chow_fast-HY__05`$pvalue
# get(group_col)fast
#          0.8319448
#
# $`chow_fast-HY__05`$coef
# get(group_col)fast
#       -0.007321675
#
#
# $`chow_fast-HY__06`
# $`chow_fast-HY__06`$pvalue
# get(group_col)fast
#          0.1625834
#
# $`chow_fast-HY__06`$coef
# get(group_col)fast
#          0.0769152
#
#
# $`chow_fast-HY__07`
# $`chow_fast-HY__07`$pvalue
# get(group_col)fast
#          0.3750354
#
# $`chow_fast-HY__07`$coef
# get(group_col)fast
#        -0.01795253
#
#
# $`chow_fast-HY__08`
# $`chow_fast-HY__08`$pvalue
# get(group_col)fast
#          0.7162577
#
# $`chow_fast-HY__08`$coef
# get(group_col)fast
#        0.008282373
#
#
# $`chow_fast-HY__09`
# $`chow_fast-HY__09`$pvalue
# get(group_col)fast
#          0.4477916
#
# $`chow_fast-HY__09`$coef
# get(group_col)fast
#        -0.03608685
#
#
# $`chow_fast-HY__10`
# $`chow_fast-HY__10`$pvalue
# get(group_col)fast
#          0.7328797
#
# $`chow_fast-HY__10`$coef
# get(group_col)fast
#        0.006209306
#
#
# $`chow_fast-HY__11`
# $`chow_fast-HY__11`$pvalue
# get(group_col)fast
#          0.4353091
#
# $`chow_fast-HY__11`$coef
# get(group_col)fast
#         0.04187067
#
#
# $`chow_fast-HY__12`
# $`chow_fast-HY__12`$pvalue
# get(group_col)fast
#          0.1057304
#
# $`chow_fast-HY__12`$coef
# get(group_col)fast
#         0.02383383
#
#
# $`chow_fast-HY__13`
# $`chow_fast-HY__13`$pvalue
# get(group_col)fast
#          0.8996832
#
# $`chow_fast-HY__13`$coef
# get(group_col)fast
#       -0.006217854
#
#
# $`chow_fast-HY__14`
# $`chow_fast-HY__14`$pvalue
# get(group_col)fast
#          0.7142533
#
# $`chow_fast-HY__14`$coef
# get(group_col)fast
#        -0.04468995
#
#
# $`chow_fast-HY__15`
# $`chow_fast-HY__15`$pvalue
# get(group_col)fast
#          0.6838473
#
# $`chow_fast-HY__15`$coef
# get(group_col)fast
#         0.02035811
#
#
# $`chow_fast-HY__16`
# $`chow_fast-HY__16`$pvalue
# get(group_col)fast
#          0.1049382
#
# $`chow_fast-HY__16`$coef
# get(group_col)fast
#          0.0590011
#
#
# $`chow_fast-HY__17`
# $`chow_fast-HY__17`$pvalue
# get(group_col)fast
#          0.8367093
#
# $`chow_fast-HY__17`$coef
# get(group_col)fast
#       -0.007864225
#
#
# $`chow_fast-HY__18`
# $`chow_fast-HY__18`$pvalue
# get(group_col)fast
#          0.4481556
#
# $`chow_fast-HY__18`$coef
# get(group_col)fast
#         0.02807473
#
#
# $`chow_fast-HY__19`
# $`chow_fast-HY__19`$pvalue
# get(group_col)fast
#         0.05780137
#
# $`chow_fast-HY__19`$coef
# get(group_col)fast
#          0.1284107
#
#
# $`chow_fast-HY__20`
# $`chow_fast-HY__20`$pvalue
# get(group_col)fast
#          0.1402337
#
# $`chow_fast-HY__20`$coef
# get(group_col)fast
#         0.01493018
#
#
# $`chow_fast-HY__21`
# $`chow_fast-HY__21`$pvalue
# get(group_col)fast
#           0.248754
#
# $`chow_fast-HY__21`$coef
# get(group_col)fast
#          0.0602408
#
#
# $`chow_fast-HY__22`
# $`chow_fast-HY__22`$pvalue
# get(group_col)fast
#          0.9654581
#
# $`chow_fast-HY__22`$coef
# get(group_col)fast
#      -0.0004212148
#
#
# $`chow_fast-HY__23`
# $`chow_fast-HY__23`$pvalue
# get(group_col)fast
#           0.372138
#
# $`chow_fast-HY__23`$coef
# get(group_col)fast
#         0.04190193
#
#
# $`chow_fast-HY__24`
# $`chow_fast-HY__24`$pvalue
# get(group_col)fast
#          0.9502797
#
# $`chow_fast-HY__24`$coef
# get(group_col)fast
#       -0.001847754
#
#
# $`chow_fast-HY__25`
# $`chow_fast-HY__25`$pvalue
# get(group_col)fast
#         0.02168485
#
# $`chow_fast-HY__25`$coef
# get(group_col)fast
#         0.08467323
#
#
# $`chow_fast-HY__26`
# $`chow_fast-HY__26`$pvalue
# get(group_col)fast
#          0.9011499
#
# $`chow_fast-HY__26`$coef
# get(group_col)fast
#       -0.004878086
#
#
# $`chow_fast-HY__27`
# $`chow_fast-HY__27`$pvalue
# get(group_col)fast
#          0.5836279
#
# $`chow_fast-HY__27`$coef
# get(group_col)fast
#       -0.009359146
#
#
# $`chow_fast-HY__28`
# $`chow_fast-HY__28`$pvalue
# get(group_col)fast
#          0.9286548
#
# $`chow_fast-HY__28`$coef
# get(group_col)fast
#       -0.001252124
#
#
# $`chow_fast-HY__29`
# $`chow_fast-HY__29`$pvalue
# get(group_col)fast
#          0.5151696
#
# $`chow_fast-HY__29`$coef
# get(group_col)fast
#        -0.01931877
#
#
# $`chow_fast-HY__30`
# $`chow_fast-HY__30`$pvalue
# get(group_col)fast
#          0.3424994
#
# $`chow_fast-HY__30`$coef
# get(group_col)fast
#         0.05650788
#
#
# $`chow_fast-HY__31`
# $`chow_fast-HY__31`$pvalue
# get(group_col)fast
#         0.07617565
#
# $`chow_fast-HY__31`$coef
# get(group_col)fast
#          0.1403532
#
#
# $`chow_fast-HY__32`
# $`chow_fast-HY__32`$pvalue
# get(group_col)fast
#           0.730481
#
# $`chow_fast-HY__32`$coef
# get(group_col)fast
#        0.003723827
#
#
# $`chow_fast-HY__33`
# $`chow_fast-HY__33`$pvalue
# get(group_col)fast
#          0.8756493
#
# $`chow_fast-HY__33`$coef
# get(group_col)fast
#        0.001446451
#
#
# $`chow_fast-HY__34`
# $`chow_fast-HY__34`$pvalue
# get(group_col)fast
#        0.003073856
#
# $`chow_fast-HY__34`$coef
# get(group_col)fast
#         0.03783314
#
#
# $`chow_fast-HY__35`
# $`chow_fast-HY__35`$pvalue
# get(group_col)fast
#         0.09889134
#
# $`chow_fast-HY__35`$coef
# get(group_col)fast
#           0.126794
#
#
# $`chow_fast-HY__36`
# $`chow_fast-HY__36`$pvalue
# get(group_col)fast
#          0.6593697
#
# $`chow_fast-HY__36`$coef
# get(group_col)fast
#         0.01886911
#
#
# $`chow_fast-HY__37`
# $`chow_fast-HY__37`$pvalue
# get(group_col)fast
#          0.5185312
#
# $`chow_fast-HY__37`$coef
# get(group_col)fast
#        -0.01267532
#
#
# $`chow_fast-HY__38`
# $`chow_fast-HY__38`$pvalue
# get(group_col)fast
#          0.6281775
#
# $`chow_fast-HY__38`$coef
# get(group_col)fast
#       -0.007136795
#
#
# $`chow_fast-HY__39`
# $`chow_fast-HY__39`$pvalue
# get(group_col)fast
#           0.402434
#
# $`chow_fast-HY__39`$coef
# get(group_col)fast
#         0.02304305
#
#
# $`chow_fast-HY__40`
# $`chow_fast-HY__40`$pvalue
# get(group_col)fast
#          0.6494612
#
# $`chow_fast-HY__40`$coef
# get(group_col)fast
#         0.03027562
#
#
# $`chow_fast-HY__41`
# $`chow_fast-HY__41`$pvalue
# get(group_col)fast
#          0.5229503
#
# $`chow_fast-HY__41`$coef
# get(group_col)fast
#       -0.006519077
#
#
# $`chow_fast-HY__42`
# $`chow_fast-HY__42`$pvalue
# get(group_col)fast
#          0.4098635
#
# $`chow_fast-HY__42`$coef
# get(group_col)fast
#         0.03278563
#
#
# $`chow_fast-HY__43`
# $`chow_fast-HY__43`$pvalue
# get(group_col)fast
#          0.3861612
#
# $`chow_fast-HY__43`$coef
# get(group_col)fast
#        -0.01985978
#
#
# $`chow_fast-HY__44`
# $`chow_fast-HY__44`$pvalue
# get(group_col)fast
#          0.2400989
#
# $`chow_fast-HY__44`$coef
# get(group_col)fast
#        -0.04871775
#
#
# $`chow_fast-HY__45`
# $`chow_fast-HY__45`$pvalue
# get(group_col)fast
#          0.7076584
#
# $`chow_fast-HY__45`$coef
# get(group_col)fast
#        -0.01640984
#
#
# $`chow_fast-HY__46`
# $`chow_fast-HY__46`$pvalue
# get(group_col)fast
#          0.1852264
#
# $`chow_fast-HY__46`$coef
# get(group_col)fast
#        -0.03565355
#
#
# $`chow_fast-HY__47`
# $`chow_fast-HY__47`$pvalue
# get(group_col)fast
#          0.1592821
#
# $`chow_fast-HY__47`$coef
# get(group_col)fast
#        -0.06260838
#
#
# $`chow_fast-HY__48`
# $`chow_fast-HY__48`$pvalue
# get(group_col)fast
#          0.5843697
#
# $`chow_fast-HY__48`$coef
# get(group_col)fast
#         0.01525864
#
#
# $`chow_fast-HY__49`
# $`chow_fast-HY__49`$pvalue
# get(group_col)fast
#          0.5264131
#
# $`chow_fast-HY__49`$coef
# get(group_col)fast
#            0.03336
#
#
# $`chow_fast-HY__50`
# $`chow_fast-HY__50`$pvalue
# get(group_col)fast
#        4.13857e-06
#
# $`chow_fast-HY__50`$coef
# get(group_col)fast
#          0.2078882
#
#
# $`chow_fast-HY__51`
# $`chow_fast-HY__51`$pvalue
# get(group_col)fast
#          0.4225493
#
# $`chow_fast-HY__51`$coef
# get(group_col)fast
#         0.03048007
#
#
# $`chow_fast-HY__52`
# $`chow_fast-HY__52`$pvalue
# get(group_col)fast
#          0.2516182
#
# $`chow_fast-HY__52`$coef
# get(group_col)fast
#        -0.02477525
#
#
# $`chow_fast-HY__53`
# $`chow_fast-HY__53`$pvalue
# get(group_col)fast
#          0.5827246
#
# $`chow_fast-HY__53`$coef
# get(group_col)fast
#         0.01536903
#
#
# $`chow_fast-HY__54`
# $`chow_fast-HY__54`$pvalue
# get(group_col)fast
#          0.4798132
#
# $`chow_fast-HY__54`$coef
# get(group_col)fast
#        -0.05214022
#
#
# $`chow_fast-HY__55`
# $`chow_fast-HY__55`$pvalue
# get(group_col)fast
#          0.8490936
#
# $`chow_fast-HY__55`$coef
# get(group_col)fast
#        0.002122575
#
#
# $`chow_fast-HY__56`
# $`chow_fast-HY__56`$pvalue
# get(group_col)fast
#         0.05274047
#
# $`chow_fast-HY__56`$coef
# get(group_col)fast
#        -0.07544847
#
#
# $`chow_fast-HY__57`
# $`chow_fast-HY__57`$pvalue
# get(group_col)fast
#          0.7024016
#
# $`chow_fast-HY__57`$coef
# get(group_col)fast
#         0.01346625
#
#
# $`chow_fast-HY__58`
# $`chow_fast-HY__58`$pvalue
# get(group_col)fast
#         0.06318808
#
# $`chow_fast-HY__58`$coef
# get(group_col)fast
#          0.0582056
#
#
# $`chow_fast-HY__59`
# $`chow_fast-HY__59`$pvalue
# get(group_col)fast
#          0.0562054
#
# $`chow_fast-HY__59`$coef
# get(group_col)fast
#         0.05283802
#
#
# $`chow_fast-HY__60`
# $`chow_fast-HY__60`$pvalue
# get(group_col)fast
#          0.4855571
#
# $`chow_fast-HY__60`$coef
# get(group_col)fast
#         0.03387391
#
#
# $`chow_fast-HY__61`
# $`chow_fast-HY__61`$pvalue
# get(group_col)fast
#          0.7063943
#
# $`chow_fast-HY__61`$coef
# get(group_col)fast
#        -0.01852626
#
#
# $`chow_fast-HY__62`
# $`chow_fast-HY__62`$pvalue
# get(group_col)fast
#           0.546602
#
# $`chow_fast-HY__62`$coef
# get(group_col)fast
#        -0.01115886
#
#
# $`chow_fast-HY__63`
# $`chow_fast-HY__63`$pvalue
# get(group_col)fast
#           0.321455
#
# $`chow_fast-HY__63`$coef
# get(group_col)fast
#         0.09434461
#
#
# $`chow_fast-HY__64`
# $`chow_fast-HY__64`$pvalue
# get(group_col)fast
#          0.8773098
#
# $`chow_fast-HY__64`$coef
# get(group_col)fast
#       -0.001594863
#
#
# $`chow_fast-HY__65`
# $`chow_fast-HY__65`$pvalue
# get(group_col)fast
#          0.6254274
#
# $`chow_fast-HY__65`$coef
# get(group_col)fast
#         0.02394204
#
#
# $`chow_fast-HY__66`
# $`chow_fast-HY__66`$pvalue
# get(group_col)fast
#          0.8199667
#
# $`chow_fast-HY__66`$coef
# get(group_col)fast
#       -0.001969818
#
#
# $`chow_fast-HY__67`
# $`chow_fast-HY__67`$pvalue
# get(group_col)fast
#         0.09137975
#
# $`chow_fast-HY__67`$coef
# get(group_col)fast
#         0.05135705
#
#
# $`chow_fast-HY__68`
# $`chow_fast-HY__68`$pvalue
# get(group_col)fast
#          0.1277197
#
# $`chow_fast-HY__68`$coef
# get(group_col)fast
#         0.09670236
#
#
# $`chow_fast-HY__69`
# $`chow_fast-HY__69`$pvalue
# get(group_col)fast
#          0.6236648
#
# $`chow_fast-HY__69`$coef
# get(group_col)fast
#         0.01540827
#
#
# $`chow_fast-HY__70`
# $`chow_fast-HY__70`$pvalue
# get(group_col)fast
#          0.7492207
#
# $`chow_fast-HY__70`$coef
# get(group_col)fast
#        0.006697695
#
#
# $`chow_fast-HY__71`
# $`chow_fast-HY__71`$pvalue
# get(group_col)fast
#       5.928408e-05
#
# $`chow_fast-HY__71`$coef
# get(group_col)fast
#          -0.151608
#
#
# $`chow_fast-HY__72`
# $`chow_fast-HY__72`$pvalue
# get(group_col)fast
#          0.7363842
#
# $`chow_fast-HY__72`$coef
# get(group_col)fast
#        0.009700413
#
#
# $`chow_fast-HY__73`
# $`chow_fast-HY__73`$pvalue
# get(group_col)fast
#          0.5554084
#
# $`chow_fast-HY__73`$coef
# get(group_col)fast
#          0.0176343
#
#
# $`chow_fast-HY__74`
# $`chow_fast-HY__74`$pvalue
# get(group_col)fast
#          0.4290166
#
# $`chow_fast-HY__74`$coef
# get(group_col)fast
#        -0.01862035
#
#
# $`chow_fast-HY__75`
# $`chow_fast-HY__75`$pvalue
# get(group_col)fast
#          0.3466511
#
# $`chow_fast-HY__75`$coef
# get(group_col)fast
#         0.09688662
#
#
# $`chow_fast-HY__76`
# $`chow_fast-HY__76`$pvalue
# get(group_col)fast
#          0.3003237
#
# $`chow_fast-HY__76`$coef
# get(group_col)fast
#        -0.05006118
#
#
# $`chow_fast-HY__77`
# $`chow_fast-HY__77`$pvalue
# get(group_col)fast
#          0.3272147
#
# $`chow_fast-HY__77`$coef
# get(group_col)fast
#        -0.06791701
#
#
# $`chow_fast-HY__78`
# $`chow_fast-HY__78`$pvalue
# get(group_col)fast
#          0.6368929
#
# $`chow_fast-HY__78`$coef
# get(group_col)fast
#         -0.0180645
#
#
# $`chow_fast-HY__79`
# $`chow_fast-HY__79`$pvalue
# get(group_col)fast
#          0.6712384
#
# $`chow_fast-HY__79`$coef
# get(group_col)fast
#       -0.007921882
#
#
# $`chow_fast-IC__01`
# $`chow_fast-IC__01`$pvalue
# get(group_col)fast
#          0.5597213
#
# $`chow_fast-IC__01`$coef
# get(group_col)fast
#        -0.01169124
#
#
# $`chow_fast-IC__02`
# $`chow_fast-IC__02`$pvalue
# get(group_col)fast
#          0.8168377
#
# $`chow_fast-IC__02`$coef
# get(group_col)fast
#         0.00615686
#
#
# $`chow_fast-IC__03`
# $`chow_fast-IC__03`$pvalue
# get(group_col)fast
#          0.2546824
#
# $`chow_fast-IC__03`$coef
# get(group_col)fast
#        -0.04608494
#
#
# $`chow_fast-IC__04`
# $`chow_fast-IC__04`$pvalue
# get(group_col)fast
#          0.1501354
#
# $`chow_fast-IC__04`$coef
# get(group_col)fast
#        -0.09367582
#
#
# $`chow_fast-IC__05`
# $`chow_fast-IC__05`$pvalue
# get(group_col)fast
#          0.1675666
#
# $`chow_fast-IC__05`$coef
# get(group_col)fast
#         -0.1063883
#
#
# $`chow_fast-IC__06`
# $`chow_fast-IC__06`$pvalue
# get(group_col)fast
#          0.6678352
#
# $`chow_fast-IC__06`$coef
# get(group_col)fast
#        -0.01494916
#
#
# $`chow_fast-IC__07`
# $`chow_fast-IC__07`$pvalue
# get(group_col)fast
#       0.0006374605
#
# $`chow_fast-IC__07`$coef
# get(group_col)fast
#          -0.146187
#
#
# $`chow_fast-IC__08`
# $`chow_fast-IC__08`$pvalue
# get(group_col)fast
#        0.001321558
#
# $`chow_fast-IC__08`$coef
# get(group_col)fast
#          0.1497774
#
#
# $`chow_fast-IC__09`
# $`chow_fast-IC__09`$pvalue
# get(group_col)fast
#          0.4932958
#
# $`chow_fast-IC__09`$coef
# get(group_col)fast
#        -0.03012133
#
#
# $`chow_fast-IC__10`
# $`chow_fast-IC__10`$pvalue
# get(group_col)fast
#          0.5495954
#
# $`chow_fast-IC__10`$coef
# get(group_col)fast
#        -0.04249546
#
#
# $`chow_fast-IC__11`
# $`chow_fast-IC__11`$pvalue
# get(group_col)fast
#           0.245622
#
# $`chow_fast-IC__11`$coef
# get(group_col)fast
#       -0.007581668
#
#
# $`chow_fast-IC__12`
# $`chow_fast-IC__12`$pvalue
# get(group_col)fast
#          0.9182957
#
# $`chow_fast-IC__12`$coef
# get(group_col)fast
#       -0.004177336
#
#
# $`chow_fast-IC__13`
# $`chow_fast-IC__13`$pvalue
# get(group_col)fast
#          0.2555869
#
# $`chow_fast-IC__13`$coef
# get(group_col)fast
#          0.0192023
#
#
# $`chow_fast-IC__14`
# $`chow_fast-IC__14`$pvalue
# get(group_col)fast
#          0.6493078
#
# $`chow_fast-IC__14`$coef
# get(group_col)fast
#          0.0245654
#
#
# $`chow_fast-IC__15`
# $`chow_fast-IC__15`$pvalue
# get(group_col)fast
#       0.0001400258
#
# $`chow_fast-IC__15`$coef
# get(group_col)fast
#          0.1866957
#
#
# $`chow_fast-IC__16`
# $`chow_fast-IC__16`$pvalue
# get(group_col)fast
#          0.2295766
#
# $`chow_fast-IC__16`$coef
# get(group_col)fast
#         0.05018517
#
#
# $`chow_fast-IC__17`
# $`chow_fast-IC__17`$pvalue
# get(group_col)fast
#          0.1541432
#
# $`chow_fast-IC__17`$coef
# get(group_col)fast
#        -0.03839942
#
#
# $`chow_fast-IC__18`
# $`chow_fast-IC__18`$pvalue
# get(group_col)fast
#          0.7774959
#
# $`chow_fast-IC__18`$coef
# get(group_col)fast
#         0.02239939
#
#
# $`chow_fast-IC__19`
# $`chow_fast-IC__19`$pvalue
# get(group_col)fast
#          0.4414453
#
# $`chow_fast-IC__19`$coef
# get(group_col)fast
#        -0.00895853
#
#
# $`chow_fast-IC__20`
# $`chow_fast-IC__20`$pvalue
# get(group_col)fast
#          0.1931219
#
# $`chow_fast-IC__20`$coef
# get(group_col)fast
#        -0.05921714
#
#
# $`chow_fast-IC__21`
# $`chow_fast-IC__21`$pvalue
# get(group_col)fast
#          0.1413725
#
# $`chow_fast-IC__21`$coef
# get(group_col)fast
#         -0.0266041
#
#
# $`chow_fast-IC__22`
# $`chow_fast-IC__22`$pvalue
# get(group_col)fast
#          0.6339039
#
# $`chow_fast-IC__22`$coef
# get(group_col)fast
#         0.02577522
#
#
# $`chow_fast-IC__23`
# $`chow_fast-IC__23`$pvalue
# get(group_col)fast
#          0.8559622
#
# $`chow_fast-IC__23`$coef
# get(group_col)fast
#          0.0150804
#
#
# $`chow_fast-IC__24`
# $`chow_fast-IC__24`$pvalue
# get(group_col)fast
#          0.7983619
#
# $`chow_fast-IC__24`$coef
# get(group_col)fast
#        -0.01292294
#
#
# $`chow_fast-IC__25`
# $`chow_fast-IC__25`$pvalue
# get(group_col)fast
#          0.1704793
#
# $`chow_fast-IC__25`$coef
# get(group_col)fast
#        -0.08083222
#
#
# $`chow_fast-IC__26`
# $`chow_fast-IC__26`$pvalue
# get(group_col)fast
#          0.4643639
#
# $`chow_fast-IC__26`$coef
# get(group_col)fast
#       -0.006982872
#
#
# $`chow_fast-IC__27`
# $`chow_fast-IC__27`$pvalue
# get(group_col)fast
#          0.9692282
#
# $`chow_fast-IC__27`$coef
# get(group_col)fast
#       -0.002881075
#
#
# $`chow_fast-IC__28`
# $`chow_fast-IC__28`$pvalue
# get(group_col)fast
#          0.3100264
#
# $`chow_fast-IC__28`$coef
# get(group_col)fast
#         0.01926666
#
#
# $`chow_fast-IC__29`
# $`chow_fast-IC__29`$pvalue
# get(group_col)fast
#          0.9606673
#
# $`chow_fast-IC__29`$coef
# get(group_col)fast
#        0.002727183
#
#
# $`chow_fast-IC__30`
# $`chow_fast-IC__30`$pvalue
# get(group_col)fast
#          0.7385863
#
# $`chow_fast-IC__30`$coef
# get(group_col)fast
#        -0.02038559
#
#
# $`chow_fast-IC__31`
# $`chow_fast-IC__31`$pvalue
# get(group_col)fast
#          0.6748223
#
# $`chow_fast-IC__31`$coef
# get(group_col)fast
#        -0.02353832
#
#
# $`chow_fast-IC__32`
# $`chow_fast-IC__32`$pvalue
# get(group_col)fast
#       0.0002418786
#
# $`chow_fast-IC__32`$coef
# get(group_col)fast
#          -0.176828
#
#
# $`chow_fast-IC__33`
# $`chow_fast-IC__33`$pvalue
# get(group_col)fast
#          0.7613067
#
# $`chow_fast-IC__33`$coef
# get(group_col)fast
#        0.005196771
#
#
# $`chow_fast-IC__34`
# $`chow_fast-IC__34`$pvalue
# get(group_col)fast
#        0.005432757
#
# $`chow_fast-IC__34`$coef
# get(group_col)fast
#         -0.1579322
#
#
# $`chow_fast-IC__35`
# $`chow_fast-IC__35`$pvalue
# get(group_col)fast
#          0.4950184
#
# $`chow_fast-IC__35`$coef
# get(group_col)fast
#        -0.01216821
#
#
# $`chow_fast-IC__36`
# $`chow_fast-IC__36`$pvalue
# get(group_col)fast
#          0.5038215
#
# $`chow_fast-IC__36`$coef
# get(group_col)fast
#        -0.02886175
#
#
# $`chow_fast-IC__37`
# $`chow_fast-IC__37`$pvalue
# get(group_col)fast
#          0.7509799
#
# $`chow_fast-IC__37`$coef
# get(group_col)fast
#         0.02421401
#
#
# $`chow_fast-IC__38`
# $`chow_fast-IC__38`$pvalue
# get(group_col)fast
#          0.4555091
#
# $`chow_fast-IC__38`$coef
# get(group_col)fast
#        -0.04632939
#
#
# $`chow_fast-IC__39`
# $`chow_fast-IC__39`$pvalue
# get(group_col)fast
#          0.6492334
#
# $`chow_fast-IC__39`$coef
# get(group_col)fast
#       -0.009409211
#
#
# $`chow_fast-IC__40`
# $`chow_fast-IC__40`$pvalue
# get(group_col)fast
#           0.331652
#
# $`chow_fast-IC__40`$coef
# get(group_col)fast
#        -0.04854842
#
#
# $`chow_fast-IC__41`
# $`chow_fast-IC__41`$pvalue
# get(group_col)fast
#          0.6690018
#
# $`chow_fast-IC__41`$coef
# get(group_col)fast
#         0.03284107
#
#
# $`chow_fast-IC__42`
# $`chow_fast-IC__42`$pvalue
# get(group_col)fast
#          0.2769606
#
# $`chow_fast-IC__42`$coef
# get(group_col)fast
#        -0.04330534
#
#
# $`chow_fast-IC__43`
# $`chow_fast-IC__43`$pvalue
# get(group_col)fast
#          0.2573545
#
# $`chow_fast-IC__43`$coef
# get(group_col)fast
#        -0.09794439
#
#
# $`chow_fast-IC__44`
# $`chow_fast-IC__44`$pvalue
# get(group_col)fast
#          0.9755293
#
# $`chow_fast-IC__44`$coef
# get(group_col)fast
#        0.001406374
#
#
# $`chow_fast-IC__45`
# $`chow_fast-IC__45`$pvalue
# get(group_col)fast
#          0.3483346
#
# $`chow_fast-IC__45`$coef
# get(group_col)fast
#         0.07436144
#
#
# $`chow_fast-IC__46`
# $`chow_fast-IC__46`$pvalue
# get(group_col)fast
#          0.8610709
#
# $`chow_fast-IC__46`$coef
# get(group_col)fast
#         0.01393458
#
#
# $`chow_fast-IC__47`
# $`chow_fast-IC__47`$pvalue
# get(group_col)fast
#           0.463588
#
# $`chow_fast-IC__47`$coef
# get(group_col)fast
#         0.04734187
#
#
# $`chow_fast-SC__01`
# $`chow_fast-SC__01`$pvalue
# get(group_col)fast
#          0.3046324
#
# $`chow_fast-SC__01`$coef
# get(group_col)fast
#        -0.08648332
#
#
# $`chow_fast-SC__02`
# $`chow_fast-SC__02`$pvalue
# get(group_col)fast
#          0.7766151
#
# $`chow_fast-SC__02`$coef
# get(group_col)fast
#        -0.01955462
#
#
# $`chow_fast-SC__03`
# $`chow_fast-SC__03`$pvalue
# get(group_col)fast
#           0.856269
#
# $`chow_fast-SC__03`$coef
# get(group_col)fast
#        0.001763854
#
#
# $`chow_fast-SC__04`
# $`chow_fast-SC__04`$pvalue
# get(group_col)fast
#          0.8513987
#
# $`chow_fast-SC__04`$coef
# get(group_col)fast
#         0.01357272
#
#
# $`chow_fast-SC__05`
# $`chow_fast-SC__05`$pvalue
# get(group_col)fast
#          0.4324212
#
# $`chow_fast-SC__05`$coef
# get(group_col)fast
#         0.04873313
#
#
# $`chow_fast-SC__06`
# $`chow_fast-SC__06`$pvalue
# get(group_col)fast
#          0.7627002
#
# $`chow_fast-SC__06`$coef
# get(group_col)fast
#        0.001253317
#
#
# $`chow_fast-SC__07`
# $`chow_fast-SC__07`$pvalue
# get(group_col)fast
#          0.5659618
#
# $`chow_fast-SC__07`$coef
# get(group_col)fast
#         0.01038124
#
#
# $`chow_fast-SC__08`
# $`chow_fast-SC__08`$pvalue
# get(group_col)fast
#         0.03567554
#
# $`chow_fast-SC__08`$coef
# get(group_col)fast
#         0.04607535
#
#
# $`chow_fast-SC__09`
# $`chow_fast-SC__09`$pvalue
# get(group_col)fast
#          0.8301699
#
# $`chow_fast-SC__09`$coef
# get(group_col)fast
#         -0.0169615
#
#
# $`chow_fast-SC__10`
# $`chow_fast-SC__10`$pvalue
# get(group_col)fast
#          0.7946461
#
# $`chow_fast-SC__10`$coef
# get(group_col)fast
#         0.01998506
#
#
# $`chow_fast-SC__11`
# $`chow_fast-SC__11`$pvalue
# get(group_col)fast
#           0.101385
#
# $`chow_fast-SC__11`$coef
# get(group_col)fast
#          0.1621282
#
#
# $`chow_fast-SC__12`
# $`chow_fast-SC__12`$pvalue
# get(group_col)fast
#          0.4203534
#
# $`chow_fast-SC__12`$coef
# get(group_col)fast
#         0.04073323
#
#
# $`chow_fast-SC__13`
# $`chow_fast-SC__13`$pvalue
# get(group_col)fast
#         0.06437475
#
# $`chow_fast-SC__13`$coef
# get(group_col)fast
#         0.09415231
#
#
# $`chow_fast-SC__14`
# $`chow_fast-SC__14`$pvalue
# get(group_col)fast
#          0.5927165
#
# $`chow_fast-SC__14`$coef
# get(group_col)fast
#        -0.06085018
#
#
# $`chow_fast-SC__15`
# $`chow_fast-SC__15`$pvalue
# get(group_col)fast
#          0.4101903
#
# $`chow_fast-SC__15`$coef
# get(group_col)fast
#         0.04435476
#
#
# $`chow_fast-SC__16`
# $`chow_fast-SC__16`$pvalue
# get(group_col)fast
#          0.3184867
#
# $`chow_fast-SC__16`$coef
# get(group_col)fast
#         -0.1045633
#
#
# $`chow_fast-SC__17`
# $`chow_fast-SC__17`$pvalue
# get(group_col)fast
#          0.3215313
#
# $`chow_fast-SC__17`$coef
# get(group_col)fast
#        -0.09660437
#
#
# $`chow_fast-SC__18`
# $`chow_fast-SC__18`$pvalue
# get(group_col)fast
#          0.0560398
#
# $`chow_fast-SC__18`$coef
# get(group_col)fast
#         0.06065196
#
#
# $`chow_fast-SC__19`
# $`chow_fast-SC__19`$pvalue
# get(group_col)fast
#          0.3002042
#
# $`chow_fast-SC__19`$coef
# get(group_col)fast
#        -0.01698423
#
#
# $`chow_fast-SC__20`
# $`chow_fast-SC__20`$pvalue
# get(group_col)fast
#          0.8144163
#
# $`chow_fast-SC__20`$coef
# get(group_col)fast
#        -0.01593218
#
#
# $`chow_fast-SC__21`
# $`chow_fast-SC__21`$pvalue
# get(group_col)fast
#          0.5950445
#
# $`chow_fast-SC__21`$coef
# get(group_col)fast
#       -0.008063065
#
#
# $`chow_fast-SC__22`
# $`chow_fast-SC__22`$pvalue
# get(group_col)fast
#            0.83119
#
# $`chow_fast-SC__22`$coef
# get(group_col)fast
#        -0.02301739
#
#
# $`chow_fast-SC__23`
# $`chow_fast-SC__23`$pvalue
# get(group_col)fast
#          0.4287627
#
# $`chow_fast-SC__23`$coef
# get(group_col)fast
#         0.01213314
#
#
# $`chow_fast-SC__24`
# $`chow_fast-SC__24`$pvalue
# get(group_col)fast
#             0.7409
#
# $`chow_fast-SC__24`$coef
# get(group_col)fast
#       -0.008182043
#
#
# $`chow_fast-SC__25`
# $`chow_fast-SC__25`$pvalue
# get(group_col)fast
#          0.6905616
#
# $`chow_fast-SC__25`$coef
# get(group_col)fast
#          0.0302213
#
#
# $`chow_fast-SC__26`
# $`chow_fast-SC__26`$pvalue
# get(group_col)fast
#          0.1540182
#
# $`chow_fast-SC__26`$coef
# get(group_col)fast
#          0.1204537
#
#
# $`chow_fast-SC__27`
# $`chow_fast-SC__27`$pvalue
# get(group_col)fast
#        0.003651346
#
# $`chow_fast-SC__27`$coef
# get(group_col)fast
#        -0.05378538
#
#
# $`chow_fast-SC__28`
# $`chow_fast-SC__28`$pvalue
# get(group_col)fast
#          0.4911041
#
# $`chow_fast-SC__28`$coef
# get(group_col)fast
#        -0.05462446
#
#
# $`chow_fast-SC__29`
# $`chow_fast-SC__29`$pvalue
# get(group_col)fast
#          0.8383923
#
# $`chow_fast-SC__29`$coef
# get(group_col)fast
#         0.01326635
#
#
# $`chow_fast-SC__30`
# $`chow_fast-SC__30`$pvalue
# get(group_col)fast
#          0.7472421
#
# $`chow_fast-SC__30`$coef
# get(group_col)fast
#        -0.01064959
#
#
# $`chow_fast-SC__31`
# $`chow_fast-SC__31`$pvalue
# get(group_col)fast
#          0.5418919
#
# $`chow_fast-SC__31`$coef
# get(group_col)fast
#        -0.03171265
#
#
# $`chow_fast-SC__32`
# $`chow_fast-SC__32`$pvalue
# get(group_col)fast
#        0.001466527
#
# $`chow_fast-SC__32`$coef
# get(group_col)fast
#         -0.1749272
#
#
# $`chow_fast-SC__33`
# $`chow_fast-SC__33`$pvalue
# get(group_col)fast
#           0.735465
#
# $`chow_fast-SC__33`$coef
# get(group_col)fast
#        -0.03008851
#
#
# $`chow_fast-SC__34`
# $`chow_fast-SC__34`$pvalue
# get(group_col)fast
#          0.1800418
#
# $`chow_fast-SC__34`$coef
# get(group_col)fast
#         0.08427887
#
#
# $`chow_fast-SC__35`
# $`chow_fast-SC__35`$pvalue
# get(group_col)fast
#          0.4691306
#
# $`chow_fast-SC__35`$coef
# get(group_col)fast
#        -0.03184892
#
#
# $`chow_fast-SC__36`
# $`chow_fast-SC__36`$pvalue
# get(group_col)fast
#          0.3163487
#
# $`chow_fast-SC__36`$coef
# get(group_col)fast
#         0.01725538
#
#
# $`chow_fast-SC__37`
# $`chow_fast-SC__37`$pvalue
# get(group_col)fast
#          0.6227708
#
# $`chow_fast-SC__37`$coef
# get(group_col)fast
#        0.008112418
#
#
# $`chow_fast-SC__38`
# $`chow_fast-SC__38`$pvalue
# get(group_col)fast
#            0.76637
#
# $`chow_fast-SC__38`$coef
# get(group_col)fast
#         0.02884814
#
#
# $`chow_fast-SC__39`
# $`chow_fast-SC__39`$pvalue
# get(group_col)fast
#          0.4570667
#
# $`chow_fast-SC__39`$coef
# get(group_col)fast
#         0.02054362
#
#
# $`chow_fast-SC__40`
# $`chow_fast-SC__40`$pvalue
# get(group_col)fast
#          0.1654736
#
# $`chow_fast-SC__40`$coef
# get(group_col)fast
#         0.03168693
#
#
# $`chow_fast-SC__41`
# $`chow_fast-SC__41`$pvalue
# get(group_col)fast
#          0.2985442
#
# $`chow_fast-SC__41`$coef
# get(group_col)fast
#         0.02773655
#
#
# $`chow_fast-SC__42`
# $`chow_fast-SC__42`$pvalue
# get(group_col)fast
#          0.2321919
#
# $`chow_fast-SC__42`$coef
# get(group_col)fast
#         -0.1034486
#
#
# $`chow_fast-SC__43`
# $`chow_fast-SC__43`$pvalue
# get(group_col)fast
#          0.6952158
#
# $`chow_fast-SC__43`$coef
# get(group_col)fast
#         0.03908513
#
#
# $`chow_fast-SC__44`
# $`chow_fast-SC__44`$pvalue
# get(group_col)fast
#          0.9485921
#
# $`chow_fast-SC__44`$coef
# get(group_col)fast
#       -0.005414558
#
#
# $`chow_fast-SC__45`
# $`chow_fast-SC__45`$pvalue
# get(group_col)fast
#         0.03331659
#
# $`chow_fast-SC__45`$coef
# get(group_col)fast
#         0.02865004
#
#
# $`chow_fast-SC__46`
# $`chow_fast-SC__46`$pvalue
# get(group_col)fast
#         0.08707369
#
# $`chow_fast-SC__46`$coef
# get(group_col)fast
#        -0.02331326
#
#
# $`chow_fast-SC__47`
# $`chow_fast-SC__47`$pvalue
# get(group_col)fast
#          0.6717152
#
# $`chow_fast-SC__47`$coef
# get(group_col)fast
#         -0.0128099
#
#
# $`chow_fast-SC__48`
# $`chow_fast-SC__48`$pvalue
# get(group_col)fast
#          0.5988137
#
# $`chow_fast-SC__48`$coef
# get(group_col)fast
#         0.03153778
#
#
# $`chow_fast-SC__49`
# $`chow_fast-SC__49`$pvalue
# get(group_col)fast
#           0.495954
#
# $`chow_fast-SC__49`$coef
# get(group_col)fast
#         0.05212642
#
#
# $`chow_fast-SC__50`
# $`chow_fast-SC__50`$pvalue
# get(group_col)fast
#          0.1124965
#
# $`chow_fast-SC__50`$coef
# get(group_col)fast
#         0.04223649
#
#
# $`chow_fast-SC__51`
# $`chow_fast-SC__51`$pvalue
# get(group_col)fast
#          0.3335007
#
# $`chow_fast-SC__51`$coef
# get(group_col)fast
#        -0.09553757
#
#
# $`chow_fast-SC__52`
# $`chow_fast-SC__52`$pvalue
# get(group_col)fast
#          0.3067854
#
# $`chow_fast-SC__52`$coef
# get(group_col)fast
#           0.064083
#
#
# $`chow_fast-SC__53`
# $`chow_fast-SC__53`$pvalue
# get(group_col)fast
#          0.6573485
#
# $`chow_fast-SC__53`$coef
# get(group_col)fast
#        -0.02203282
#
#
# $`chow_fast-SC__54`
# $`chow_fast-SC__54`$pvalue
# get(group_col)fast
#          0.7636165
#
# $`chow_fast-SC__54`$coef
# get(group_col)fast
#         0.00253807
#
#
# $`chow_fast-SC__55`
# $`chow_fast-SC__55`$pvalue
# get(group_col)fast
#          0.2253586
#
# $`chow_fast-SC__55`$coef
# get(group_col)fast
#          -0.030955
#
#
# $`chow_fast-SC__56`
# $`chow_fast-SC__56`$pvalue
# get(group_col)fast
#          0.6996608
#
# $`chow_fast-SC__56`$coef
# get(group_col)fast
#        0.008587338
#
#
# $`chow_fast-SC__57`
# $`chow_fast-SC__57`$pvalue
# get(group_col)fast
#         0.09150356
#
# $`chow_fast-SC__57`$coef
# get(group_col)fast
#        -0.04161326
#
#
# $`chow_fast-SC__58`
# $`chow_fast-SC__58`$pvalue
# get(group_col)fast
#          0.1559798
#
# $`chow_fast-SC__58`$coef
# get(group_col)fast
#       -0.007188392
#
#
# $`chow_fast-SC__59`
# $`chow_fast-SC__59`$pvalue
# get(group_col)fast
#          0.4126522
#
# $`chow_fast-SC__59`$coef
# get(group_col)fast
#        -0.03879808
#
#
# $`chow_fast-SC__60`
# $`chow_fast-SC__60`$pvalue
# get(group_col)fast
#          0.1078146
#
# $`chow_fast-SC__60`$coef
# get(group_col)fast
#         0.04748028
#
#
# $`chow_fast-SC__61`
# $`chow_fast-SC__61`$pvalue
# get(group_col)fast
#          0.3998941
#
# $`chow_fast-SC__61`$coef
# get(group_col)fast
#         0.06518318
#
#
# $`chow_fast-SC__62`
# $`chow_fast-SC__62`$pvalue
# get(group_col)fast
#          0.4990274
#
# $`chow_fast-SC__62`$coef
# get(group_col)fast
#        -0.04513201
#
#
# $`chow_fast-SC__63`
# $`chow_fast-SC__63`$pvalue
# get(group_col)fast
#          0.4161332
#
# $`chow_fast-SC__63`$coef
# get(group_col)fast
#        -0.08462948
#
#
# $`chow_fast-SC__64`
# $`chow_fast-SC__64`$pvalue
# get(group_col)fast
#          0.5087291
#
# $`chow_fast-SC__64`$coef
# get(group_col)fast
#        -0.03547413
#
#
# $`chow_fast-SC__65`
# $`chow_fast-SC__65`$pvalue
# get(group_col)fast
#          0.5848816
#
# $`chow_fast-SC__65`$coef
# get(group_col)fast
#        -0.03472813
#
#
# $`chow_fast-SC__66`
# $`chow_fast-SC__66`$pvalue
# get(group_col)fast
#          0.1081487
#
# $`chow_fast-SC__66`$coef
# get(group_col)fast
#         0.06754245
#
#
# $`chow_fast-SC__67`
# $`chow_fast-SC__67`$pvalue
# get(group_col)fast
#        0.007532937
#
# $`chow_fast-SC__67`$coef
# get(group_col)fast
#          0.1294359
#
#
# $`chow_fast-SC__68`
# $`chow_fast-SC__68`$pvalue
# get(group_col)fast
#           0.231458
#
# $`chow_fast-SC__68`$coef
# get(group_col)fast
#        -0.04563838
#
#
# $`chow_fast-SC__69`
# $`chow_fast-SC__69`$pvalue
# get(group_col)fast
#          0.0757516
#
# $`chow_fast-SC__69`$coef
# get(group_col)fast
#         -0.0362935
#
#
# $`chow_fast-SC__70`
# $`chow_fast-SC__70`$pvalue
# get(group_col)fast
#          0.5223858
#
# $`chow_fast-SC__70`$coef
# get(group_col)fast
#         0.05193602
#
#
# $`chow_fast-SC__71`
# $`chow_fast-SC__71`$pvalue
# get(group_col)fast
#          0.2084469
#
# $`chow_fast-SC__71`$coef
# get(group_col)fast
#         -0.1046643
#
#
# $`chow_fast-SC__72`
# $`chow_fast-SC__72`$pvalue
# get(group_col)fast
#          0.7248162
#
# $`chow_fast-SC__72`$coef
# get(group_col)fast
#        0.006137162
#
#
# $`chow_fast-SC__73`
# $`chow_fast-SC__73`$pvalue
# get(group_col)fast
#          0.2700907
#
# $`chow_fast-SC__73`$coef
# get(group_col)fast
#        -0.03607021
#
#
# $`chow_fast-SC__74`
# $`chow_fast-SC__74`$pvalue
# get(group_col)fast
#          0.4840369
#
# $`chow_fast-SC__74`$coef
# get(group_col)fast
#        -0.01449733
#
#
# $`chow_fast-SC__75`
# $`chow_fast-SC__75`$pvalue
# get(group_col)fast
#          0.2057139
#
# $`chow_fast-SC__75`$coef
# get(group_col)fast
#         0.04124892
#
#
# $`chow_fast-SC__76`
# $`chow_fast-SC__76`$pvalue
# get(group_col)fast
#          0.2014955
#
# $`chow_fast-SC__76`$coef
# get(group_col)fast
#         -0.1512421
#
#
# $`chow_fast-SC__77`
# $`chow_fast-SC__77`$pvalue
# get(group_col)fast
#         0.09565048
#
# $`chow_fast-SC__77`$coef
# get(group_col)fast
#        -0.02246899
#
#
# $`chow_fast-SC__78`
# $`chow_fast-SC__78`$pvalue
# get(group_col)fast
#       0.0002422843
#
# $`chow_fast-SC__78`$coef
# get(group_col)fast
#          0.1892572
#
#
# $`chow_fast-SC__79`
# $`chow_fast-SC__79`$pvalue
# get(group_col)fast
#          0.8872833
#
# $`chow_fast-SC__79`$coef
# get(group_col)fast
#        0.005483791
#
#
# $`chow_fast-SC__80`
# $`chow_fast-SC__80`$pvalue
# get(group_col)fast
#           0.671466
#
# $`chow_fast-SC__80`$coef
# get(group_col)fast
#        -0.02229737
#
#
# $`chow_fast-SC__81`
# $`chow_fast-SC__81`$pvalue
# get(group_col)fast
#          0.2118067
#
# $`chow_fast-SC__81`$coef
# get(group_col)fast
#        -0.06941423
#
#
# $`chow_fast-SC__82`
# $`chow_fast-SC__82`$pvalue
# get(group_col)fast
#          0.1345272
#
# $`chow_fast-SC__82`$coef
# get(group_col)fast
#         0.04124307
#
#
# $`chow_fast-SC__83`
# $`chow_fast-SC__83`$pvalue
# get(group_col)fast
#           0.156665
#
# $`chow_fast-SC__83`$coef
# get(group_col)fast
#          0.1639588
#
#
# $`chow_fast-SC__84`
# $`chow_fast-SC__84`$pvalue
# get(group_col)fast
#           0.689518
#
# $`chow_fast-SC__84`$coef
# get(group_col)fast
#        -0.02917396
#
#
# $`chow_fast-SC__85`
# $`chow_fast-SC__85`$pvalue
# get(group_col)fast
#          0.3987002
#
# $`chow_fast-SC__85`$coef
# get(group_col)fast
#        0.007903866
#
#
# $`chow_fast-SC__86`
# $`chow_fast-SC__86`$pvalue
# get(group_col)fast
#          0.6546612
#
# $`chow_fast-SC__86`$coef
# get(group_col)fast
#         0.03515869
#
#
# $`chow_fast-SC__87`
# $`chow_fast-SC__87`$pvalue
# get(group_col)fast
#          0.2737448
#
# $`chow_fast-SC__87`$coef
# get(group_col)fast
#         0.05377601
#
#
# $`chow_fast-SC__88`
# $`chow_fast-SC__88`$pvalue
# get(group_col)fast
#          0.8676485
#
# $`chow_fast-SC__88`$coef
# get(group_col)fast
#        -0.01814042
#
#
# $`chow_fast-SC__89`
# $`chow_fast-SC__89`$pvalue
# get(group_col)fast
#            0.61494
#
# $`chow_fast-SC__89`$coef
# get(group_col)fast
#         0.02526453
#
#
# $`chow_fast-SC__90`
# $`chow_fast-SC__90`$pvalue
# get(group_col)fast
#          0.3548337
#
# $`chow_fast-SC__90`$coef
# get(group_col)fast
#        -0.07760989
#
#
# $`chow_fast-SC__91`
# $`chow_fast-SC__91`$pvalue
# get(group_col)fast
#           0.587783
#
# $`chow_fast-SC__91`$coef
# get(group_col)fast
#        -0.02101968
#
#
# $`chow_fast-SC__92`
# $`chow_fast-SC__92`$pvalue
# get(group_col)fast
#          0.5086027
#
# $`chow_fast-SC__92`$coef
# get(group_col)fast
#         0.03370411
#
#
# $`chow_fast-ZI__01`
# $`chow_fast-ZI__01`$pvalue
# get(group_col)fast
#          0.4330948
#
# $`chow_fast-ZI__01`$coef
# get(group_col)fast
#       -0.007167811
#
#
# $`chow_fast-ZI__02`
# $`chow_fast-ZI__02`$pvalue
# get(group_col)fast
#          0.9742816
#
# $`chow_fast-ZI__02`$coef
# get(group_col)fast
#      -0.0004803205
#
#
# $`chow_fast-ZI__03`
# $`chow_fast-ZI__03`$pvalue
# get(group_col)fast
#          0.9546144
#
# $`chow_fast-ZI__03`$coef
# get(group_col)fast
#       -0.004035454
#
#
# $`chow_fast-ZI__04`
# $`chow_fast-ZI__04`$pvalue
# get(group_col)fast
#          0.4137513
#
# $`chow_fast-ZI__04`$coef
# get(group_col)fast
#         0.04877711
#
#
# $`chow_fast-ZI__05`
# $`chow_fast-ZI__05`$pvalue
# get(group_col)fast
#          0.7751071
#
# $`chow_fast-ZI__05`$coef
# get(group_col)fast
#         0.01263334
#
#
# $`chow_fast-ZI__06`
# $`chow_fast-ZI__06`$pvalue
# get(group_col)fast
#         0.09832477
#
# $`chow_fast-ZI__06`$coef
# get(group_col)fast
#         0.04641542
#
#
# $`chow_fast-ZI__07`
# $`chow_fast-ZI__07`$pvalue
# get(group_col)fast
#          0.7652633
#
# $`chow_fast-ZI__07`$coef
# get(group_col)fast
#       -0.002539722
#
#
# $`chow_fast-ZI__08`
# $`chow_fast-ZI__08`$pvalue
# get(group_col)fast
#          0.7236602
#
# $`chow_fast-ZI__08`$coef
# get(group_col)fast
#        -0.01085856
#
#
# $`chow_fast-ZI__09`
# $`chow_fast-ZI__09`$pvalue
# get(group_col)fast
#          0.7589914
#
# $`chow_fast-ZI__09`$coef
# get(group_col)fast
#        0.008590575
#
#
# $`chow_fast-ZI__10`
# $`chow_fast-ZI__10`$pvalue
# get(group_col)fast
#          0.6251306
#
# $`chow_fast-ZI__10`$coef
# get(group_col)fast
#         0.01987821
#
#
# $`chow_fast-ZI__11`
# $`chow_fast-ZI__11`$pvalue
# get(group_col)fast
#          0.6023092
#
# $`chow_fast-ZI__11`$coef
# get(group_col)fast
#         0.02312371
#
#
# $`chow_fast-ZI__12`
# $`chow_fast-ZI__12`$pvalue
# get(group_col)fast
#          0.5408792
#
# $`chow_fast-ZI__12`$coef
# get(group_col)fast
#        -0.03628126
#
#
# $`chow_fast-ZI__13`
# $`chow_fast-ZI__13`$pvalue
# get(group_col)fast
#          0.1174199
#
# $`chow_fast-ZI__13`$coef
# get(group_col)fast
#         -0.1059001
#
#
# $`chow_fast-ZI__14`
# $`chow_fast-ZI__14`$pvalue
# get(group_col)fast
#          0.3037608
#
# $`chow_fast-ZI__14`$coef
# get(group_col)fast
#        0.009985462
#
#
# $`chow_fast-ZI__15`
# $`chow_fast-ZI__15`$pvalue
# get(group_col)fast
#          0.9335017
#
# $`chow_fast-ZI__15`$coef
# get(group_col)fast
#        0.001605612
#
#
# $`chow_fast-ZI__16`
# $`chow_fast-ZI__16`$pvalue
# get(group_col)fast
#          0.9386588
#
# $`chow_fast-ZI__16`$coef
# get(group_col)fast
#        0.004657095
#
#
# $`chow_fast-ZI__17`
# $`chow_fast-ZI__17`$pvalue
# get(group_col)fast
#         0.08087864
#
# $`chow_fast-ZI__17`$coef
# get(group_col)fast
#         -0.0813172
#
#
# $`chow_fast-ZI__18`
# $`chow_fast-ZI__18`$pvalue
# get(group_col)fast
#        0.003735325
#
# $`chow_fast-ZI__18`$coef
# get(group_col)fast
#         -0.1345989
#
#
# $`chow_fast-ZI__19`
# $`chow_fast-ZI__19`$pvalue
# get(group_col)fast
#          0.5568588
#
# $`chow_fast-ZI__19`$coef
# get(group_col)fast
#        -0.04240017
#
#
# $`chow_fast-ZI__20`
# $`chow_fast-ZI__20`$pvalue
# get(group_col)fast
#          0.6384895
#
# $`chow_fast-ZI__20`$coef
# get(group_col)fast
#         0.01861207
#
#
# $`chow_fast-ZI__21`
# $`chow_fast-ZI__21`$pvalue
# get(group_col)fast
#          0.4995661
#
# $`chow_fast-ZI__21`$coef
# get(group_col)fast
#        -0.03468892
#
#
# $`chow_fast-ZI__22`
# $`chow_fast-ZI__22`$pvalue
# get(group_col)fast
#         0.06197516
#
# $`chow_fast-ZI__22`$coef
# get(group_col)fast
#         0.04272072
#
#
# $`chow_fast-ZI__23`
# $`chow_fast-ZI__23`$pvalue
# get(group_col)fast
#          0.9446173
#
# $`chow_fast-ZI__23`$coef
# get(group_col)fast
#       -0.002503542
#
#
# $`chow_fast-ZI__24`
# $`chow_fast-ZI__24`$pvalue
# get(group_col)fast
#          0.4228774
#
# $`chow_fast-ZI__24`$coef
# get(group_col)fast
#         0.02992232
#
#
# $`chow_fast-ZI__25`
# $`chow_fast-ZI__25`$pvalue
# get(group_col)fast
#          0.7851474
#
# $`chow_fast-ZI__25`$coef
# get(group_col)fast
#        -0.01167405
#
#
# $`chow_fast-ZI__26`
# $`chow_fast-ZI__26`$pvalue
# get(group_col)fast
#          0.5408878
#
# $`chow_fast-ZI__26`$coef
# get(group_col)fast
#        -0.02232072
#
#
# $`chow_fast-ZI__27`
# $`chow_fast-ZI__27`$pvalue
# get(group_col)fast
#          0.1552268
#
# $`chow_fast-ZI__27`$coef
# get(group_col)fast
#         -0.1145826
#
#
# $`chow_fast-ZI__28`
# $`chow_fast-ZI__28`$pvalue
# get(group_col)fast
#          0.7312881
#
# $`chow_fast-ZI__28`$coef
# get(group_col)fast
#         0.01513772
#
#
# $`chow_fast-ZI__29`
# $`chow_fast-ZI__29`$pvalue
# get(group_col)fast
#          0.2785488
#
# $`chow_fast-ZI__29`$coef
# get(group_col)fast
#         0.03453108
#
#
# $`chow_fast-ZI__30`
# $`chow_fast-ZI__30`$pvalue
# get(group_col)fast
#          0.8660951
#
# $`chow_fast-ZI__30`$coef
# get(group_col)fast
#       -0.002380913
#
#
# $`chow_fast-ZI__31`
# $`chow_fast-ZI__31`$pvalue
# get(group_col)fast
#          0.4363645
#
# $`chow_fast-ZI__31`$coef
# get(group_col)fast
#        -0.04579205
#
#
# $`chow_fast-ZI__32`
# $`chow_fast-ZI__32`$pvalue
# get(group_col)fast
#          0.5593148
#
# $`chow_fast-ZI__32`$coef
# get(group_col)fast
#        -0.02029688
#
#
# $`chow_fast-ZI__33`
# $`chow_fast-ZI__33`$pvalue
# get(group_col)fast
#           0.924129
#
# $`chow_fast-ZI__33`$coef
# get(group_col)fast
#       -0.001725829
#
#
# $`chow_fast-ZI__34`
# $`chow_fast-ZI__34`$pvalue
# get(group_col)fast
#         0.06287781
#
# $`chow_fast-ZI__34`$coef
# get(group_col)fast
#         0.06238625
#
#
# $`chow_fast-ZI__35`
# $`chow_fast-ZI__35`$pvalue
# get(group_col)fast
#          0.5449135
#
# $`chow_fast-ZI__35`$coef
# get(group_col)fast
#         -0.0492963
#
#
# $`chow_fast-ZI__36`
# $`chow_fast-ZI__36`$pvalue
# get(group_col)fast
#         0.05162777
#
# $`chow_fast-ZI__36`$coef
# get(group_col)fast
#         0.03996147
#
#
# $`chow_fast-ZI__37`
# $`chow_fast-ZI__37`$pvalue
# get(group_col)fast
#           0.975544
#
# $`chow_fast-ZI__37`$coef
# get(group_col)fast
#        0.001598581
#
#
# $`chow_fast-ZI__38`
# $`chow_fast-ZI__38`$pvalue
# get(group_col)fast
#          0.9363311
#
# $`chow_fast-ZI__38`$coef
# get(group_col)fast
#        0.005822683
#
#
# $`chow_fast-ZI__39`
# $`chow_fast-ZI__39`$pvalue
# get(group_col)fast
#          0.4660238
#
# $`chow_fast-ZI__39`$coef
# get(group_col)fast
#        0.005178574
#
#
# $`chow_fast-ZI__40`
# $`chow_fast-ZI__40`$pvalue
# get(group_col)fast
#          0.6608276
#
# $`chow_fast-ZI__40`$coef
# get(group_col)fast
#         0.01671743
#
#
# $`chow_fast-ZI__41`
# $`chow_fast-ZI__41`$pvalue
# get(group_col)fast
#          0.2298054
#
# $`chow_fast-ZI__41`$coef
# get(group_col)fast
#        -0.01346476
#
#
# $`chow_fast-ZI__42`
# $`chow_fast-ZI__42`$pvalue
# get(group_col)fast
#          0.4523809
#
# $`chow_fast-ZI__42`$coef
# get(group_col)fast
#        -0.03613792
#
#
# $`chow_fast-ZI__43`
# $`chow_fast-ZI__43`$pvalue
# get(group_col)fast
#          0.7541936
#
# $`chow_fast-ZI__43`$coef
# get(group_col)fast
#        -0.01032547
#
#
# $`chow_fast-ZI__44`
# $`chow_fast-ZI__44`$pvalue
# get(group_col)fast
#         0.02568237
#
# $`chow_fast-ZI__44`$coef
# get(group_col)fast
#          0.1720277
#
#
# $`chow_fast-ZI__45`
# $`chow_fast-ZI__45`$pvalue
# get(group_col)fast
#          0.7089159
#
# $`chow_fast-ZI__45`$coef
# get(group_col)fast
#         0.02559357
#
#
# $`chow_fast-ZI__46`
# $`chow_fast-ZI__46`$pvalue
# get(group_col)fast
#          0.5960269
#
# $`chow_fast-ZI__46`$coef
# get(group_col)fast
#         0.03342052
#
#
# $`chow_fast-ZI__47`
# $`chow_fast-ZI__47`$pvalue
# get(group_col)fast
#          0.1101821
#
# $`chow_fast-ZI__47`$coef
# get(group_col)fast
#        -0.08158317
#
#
# $`chow_fast-ZI__48`
# $`chow_fast-ZI__48`$pvalue
# get(group_col)fast
#          0.4784619
#
# $`chow_fast-ZI__48`$coef
# get(group_col)fast
#        -0.02912267

# %%
# convert to tibble and save as csv
df <- ym_export %>%
  imap(function(value, name) {
    tibble(
      test_name = name,
      coef = value$coef,
      pvalue = value$pvalue
    )
  }) %>%
  bind_rows() %>% 
  arrange(pvalue) %>% 
  mutate(pvalue_bh = p.adjust(pvalue, method = "BH")) %>% 
  arrange(pvalue_bh) %>%
  separate('test_name', into = c('comparison', 'module'), sep='-') %>%
  mutate(comparison = str_replace(comparison, fixed('_'), '.vs.'))

df %>% head(10)
df %>% write_csv(significant_modules)
# Out:
#    comparison   module  coef        pvalue       pvalue_bh
# 1  chow.vs.fast HY__50   0.20788818 4.138570e-06 0.001258125
# 2  chow.vs.fast HY__71  -0.15160800 5.928408e-05 0.009011179
# 3  chow.vs.fast IC__15   0.18669571 1.400258e-04 0.013869961
# 4  chow.vs.fast IC__32  -0.17682802 2.418786e-04 0.013869961
# 5  chow.vs.fast SC__78   0.18925718 2.422843e-04 0.013869961
# 6  chow.vs.fast HPF__33  0.12701618 2.737492e-04 0.013869961
# 7  chow.vs.fast IC__07  -0.14618702 6.374605e-04 0.027684000
# 8  chow.vs.fast IC__08   0.14977742 1.321558e-03 0.049536016
# 9  chow.vs.fast SC__32  -0.17492720 1.466527e-03 0.049536016
# 10 chow.vs.fast HY__34   0.03783314 3.073856e-03 0.093445216

# %%
sessionInfo()
# Out:
# R version 4.2.2 (2022-10-31)
# Platform: x86_64-conda-linux-gnu (64-bit)
# Running under: Red Hat Enterprise Linux
#
# Matrix products: default
# BLAS/LAPACK: /nfsdata/tools/anaconda/envs/nmq407/dmb/lib/libopenblasp-r0.3.21.so
#
# locale:
#  [1] LC_CTYPE=en_GB.UTF-8       LC_NUMERIC=C
#  [3] LC_TIME=en_GB.UTF-8        LC_COLLATE=en_GB.UTF-8
#  [5] LC_MONETARY=en_GB.UTF-8    LC_MESSAGES=en_GB.UTF-8
#  [7] LC_PAPER=en_GB.UTF-8       LC_NAME=C
#  [9] LC_ADDRESS=C               LC_TELEPHONE=C
# [11] LC_MEASUREMENT=en_GB.UTF-8 LC_IDENTIFICATION=C
#
# attached base packages:
# [1] stats4    stats     graphics  grDevices utils     datasets  methods
# [8] base
#
# other attached packages:
#  [1] lubridate_1.9.2             stringr_1.5.0
#  [3] purrr_1.0.1                 readr_2.1.4
#  [5] tibble_3.2.1                tidyverse_2.0.0
#  [7] furrr_0.3.1                 future_1.32.0
#  [9] fitdistrplus_1.1-11         survival_3.5-5
# [11] MASS_7.3-60                 gratia_0.8.1
# [13] SingleCellExperiment_1.20.1 SummarizedExperiment_1.28.0
# [15] Biobase_2.58.0              GenomicRanges_1.50.2
# [17] GenomeInfoDb_1.34.9         IRanges_2.32.0
# [19] S4Vectors_0.36.2            BiocGenerics_0.44.0
# [21] MatrixGenerics_1.10.0       matrixStats_1.0.0
# [23] SeuratObject_4.1.3          Seurat_4.3.0
# [25] tidyr_1.3.0                 forcats_1.0.0
# [27] dplyr_1.1.2                 vroom_1.6.3
# [29] ggplot2_3.4.2               lme4_1.1-33
# [31] Matrix_1.5-4.1              mgcv_1.8-42
# [33] nlme_3.1-162
#
# loaded via a namespace (and not attached):
#   [1] uuid_1.1-0             plyr_1.8.8             igraph_1.5.0
#   [4] repr_1.1.6             lazyeval_0.2.2         sp_2.0-0
#   [7] splines_4.2.2          listenv_0.9.0          scattermore_1.2
#  [10] digest_0.6.31          htmltools_0.5.5        fansi_1.0.4
#  [13] magrittr_2.0.3         tensor_1.5             cluster_2.1.4
#  [16] ROCR_1.0-11            tzdb_0.4.0             globals_0.16.2
#  [19] timechange_0.2.0       spatstat.sparse_3.0-2  colorspace_2.1-0
#  [22] ggrepel_0.9.3          crayon_1.5.2           RCurl_1.98-1.12
#  [25] jsonlite_1.8.5         progressr_0.13.0       spatstat.data_3.0-1
#  [28] zoo_1.8-12             glue_1.6.2             polyclip_1.10-4
#  [31] gtable_0.3.3           zlibbioc_1.44.0        XVector_0.38.0
#  [34] leiden_0.4.3           DelayedArray_0.24.0    future.apply_1.11.0
#  [37] abind_1.4-5            scales_1.2.1           spatstat.random_3.1-5
#  [40] miniUI_0.1.1.1         Rcpp_1.0.10            viridisLite_0.4.2
#  [43] xtable_1.8-4           reticulate_1.30        bit_4.0.5
#  [46] htmlwidgets_1.6.2      httr_1.4.6             RColorBrewer_1.1-3
#  [49] ellipsis_0.3.2         ica_1.0-3              pkgconfig_2.0.3
#  [52] uwot_0.1.14            deldir_1.0-9           utf8_1.2.3
#  [55] tidyselect_1.2.0       rlang_1.1.1            reshape2_1.4.4
#  [58] later_1.3.1            munsell_0.5.0          tools_4.2.2
#  [61] cli_3.6.1              generics_0.1.3         ggridges_0.5.4
#  [64] evaluate_0.21          fastmap_1.1.1          goftest_1.2-3
#  [67] bit64_4.0.5            RANN_2.6.1             pbapply_1.7-0
#  [70] mime_0.12              mvnfast_0.2.8          compiler_4.2.2
#  [73] plotly_4.10.2          png_0.1-8              spatstat.utils_3.0-3
#  [76] stringi_1.7.12         lattice_0.21-8         IRdisplay_1.1
#  [79] nloptr_2.0.3           vctrs_0.6.2            pillar_1.9.0
#  [82] lifecycle_1.0.3        spatstat.geom_3.2-1    lmtest_0.9-40
#  [85] RcppAnnoy_0.0.20       data.table_1.14.8      cowplot_1.1.1
#  [88] bitops_1.0-7           irlba_2.3.5.1          httpuv_1.6.11
#  [91] patchwork_1.1.2.9000   R6_2.5.1               promises_1.2.0.1
#  [94] renv_0.15.5            KernSmooth_2.23-21     gridExtra_2.3
#  [97] parallelly_1.36.0      codetools_0.2-19       boot_1.3-28.1
# [100] withr_2.5.0            sctransform_0.3.5      GenomeInfoDbData_1.2.9
# [103] hms_1.1.3              parallel_4.2.2         grid_4.2.2
# [106] IRkernel_1.3.2         minqa_1.2.5            Rtsne_0.16
# [109] pbdZMQ_0.3-9           spatstat.explore_3.2-1 shiny_1.7.4
# [112] base64enc_0.1-3
